# %%
# !python -m pip install git+https://github.com/greydanus/mnist1d.git@master

# !git clone https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d.git@master
#   Cloning https://github.com/greydanus/mnist1d.git (to revision master) to /tmp/pip-req-build-_lmldltj
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d.git /tmp/pip-req-build-_lmldltj
#   Resolved https://github.com/greydanus/mnist1d.git to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14626 sha256=46112f62d8dfe71b6531f7a88aa1e9dac26822a4ff6c71613ee1a1b1cd251da5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0rxtet2x/wheels/d7/f4/df/433336ddc98ff899ac4db5b8c4230819d9c130d002cc400cd8
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 541, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 541 (delta 67), reused 66 (delta 66), pack-reused 465 (from 1)
# Receiving objects: 100% (541/541), 14.54 MiB | 11.68 MiB/s, done.
# Resolving deltas: 100% (259/259), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.ndimage import gaussian_filter
import torch.optim as optim
import matplotlib.pylab as pl
import torch, os,time
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import mnist1d

# %%
# %matplotlib inline

import pylab as plt
import numpy as np

# %%
from mnist1d.data import get_dataset, get_dataset_args
from mnist1d.utils import set_seed, to_pickle, from_pickle

import sys ; sys.path.append('/content/mnist1d/notebooks')
from train import get_model_args, train_model

# %%
args = get_dataset_args()
data = get_dataset(args=args)
# Out:
# Downloading MNIST1D dataset from https://github.com/greydanus/mnist1d/raw/master/mnist1d_data.pkl
# Saving to ./mnist1d_data.pkl
# Successfully loaded data from ./mnist1d_data.pkl

# %% [markdown]
# # Adding xavier initialization as ablation

# %%
class SparseLinear(torch.nn.Module):
    def __init__(self, x_size, y_size):
        super(SparseLinear, self).__init__()
        self.linear = torch.nn.Linear(x_size, y_size)
        param_vec = torch.cat([p.flatten() for p in self.parameters()])
        self.mask = torch.ones_like(param_vec)
        self.apply_xavier_init()

    def apply_xavier_init(self):
        torch.nn.init.xavier_uniform_(self.linear.weight)

    def forward(self, x, apply_mask=True):
        if apply_mask:
            self.apply_mask()
        return self.linear(x)

    def update_mask(self, new_mask):
        self.mask = new_mask
        self.apply_mask()

    def apply_mask(self):
        self.vec2param(self.param2vec())

    def param2vec(self):
        vec = torch.cat([p.flatten() for p in self.parameters()])
        return self.mask * vec

    def vec2param(self, vec):
        pointer = 0
        for param in self.parameters():
            param_len = np.cumprod(param.shape)[-1]
            new_param = vec[pointer:pointer+param_len].reshape(param.shape)
            param.data = new_param.data
            pointer += param_len

class SparseMLP(torch.nn.Module):
    def __init__(self, input_size, output_size, hidden_size=100):
        super(SparseMLP, self).__init__()
        self.linear1 = SparseLinear(input_size, hidden_size)
        self.linear2 = SparseLinear(hidden_size, hidden_size)
        self.linear3 = SparseLinear(hidden_size, output_size)
        self.layers = [self.linear1, self.linear2, self.linear3]

    def forward(self, x):
        h = torch.relu(self.linear1(x))
        h = h + torch.relu(self.linear2(h))
        h = self.linear3(h)
        return h

    def get_layer_masks(self):
        return [l.mask for l in self.layers]

    def set_layer_masks(self, new_masks):
        for i, l in enumerate(self.layers):
            l.update_mask(new_masks[i])

    def get_layer_vecs(self):
        return [l.param2vec() for l in self.layers]

    def set_layer_vecs(self, vecs):
        for i, l in enumerate(self.layers):
            l.vec2param(vecs[i])

# %%
def get_mask(scores, percent_sparse):

    # Calculate the number of weights to drop
    num_to_drop = int(percent_sparse * scores.numel())

    # Get the indices of weights with the lowest scores
    ixs_to_drop = torch.argsort(scores)[:num_to_drop]  # Sort by score, select lowest `num_to_drop` scores

    # Initialize the mask with ones (retain all initially)
    mask = torch.ones_like(scores)

    # Set indices of lowest-scored weights to 0
    mask[ixs_to_drop] = 0

    return mask

# %%
def find_lottery_ticket(model, dataset, args, sparsity_schedule, criteria_fn=None,
                        prune_print_every=None, **kwargs):
  if prune_print_every is None:
    prune_print_every = np.inf

  if criteria_fn is None:
    print("Using default magnitude-based pruning")
    criteria_fn = lambda init_params, final_params: final_params.abs()

  init_params = model.get_layer_vecs()
  stats = {'train_losses':[], 'test_losses':[], 'train_accs':[], 'test_accs':[]}
  models = []
  for i, percent_sparse in enumerate(sparsity_schedule):

    # layer-wise pruning, where pruning heuristic is determined by criteria_fn
    final_params = model.get_layer_vecs()
    scores = [criteria_fn(ip, fp) for ip, fp in zip(init_params, final_params)]
    masks = [get_mask(s, percent_sparse) for s in scores]

    # update model with mask and init parameters
    model.set_layer_vecs(init_params)
    model.set_layer_masks(masks)

    # training process
    results = train_model(dataset, model, args)
    model = results['checkpoints'][-1]

    # store stats
    stats['train_losses'].append(results['train_losses'])
    stats['test_losses'].append(results['test_losses'])
    stats['train_accs'].append(results['train_acc'])
    stats['test_accs'].append(results['test_acc'])

    # print progress
    if (i+1) % prune_print_every == 0:
      print('\tretrain #{}, sparsity {:.2f}, final_train_loss {:.3e}, max_acc {:.1f}, last_acc {:.1f}, mean_acc {:.1f}'
            .format(i+1, percent_sparse, results['train_losses'][-1], np.max(results['test_acc']),
            results['test_acc'][-1], np.mean(results['test_acc']) ))
      models.append(copy.deepcopy(model))

  stats = {k: np.stack(v) for k, v in stats.items()}
  return models, stats

# %%
# train settings
model_args = get_model_args()
model_args.total_steps = 1501
model_args.hidden_size = 500
model_args.print_every = 5000
model_args.eval_every = 100
model_args.learning_rate = 2e-2


# sparsity settings
num_retrains = 100
sparsity_schedule = np.linspace(0,1.,num_retrains)

# %%
num_trials = 2
trials = {'rand_models': [], 'rand_stats': [], 'lott_models': [], 'lott_stats': []}

# %%
for t in range(num_trials):
  print("############  Trial {}  ############".format(t))
  print("   Random pruning")
  set_seed(model_args.seed+t)
  model = SparseMLP(model_args.input_size, model_args.output_size, hidden_size=model_args.hidden_size)

  def criteria_fn(init_params, final_params):
    mask = (final_params == 0).int()  # if params are already set to zero, keep them set to zero
    return torch.rand(final_params.shape) #* mask
  models, stats = find_lottery_ticket(model, data, model_args, sparsity_schedule,
                                      criteria_fn=criteria_fn, prune_print_every=1)
  trials['rand_models'].append(models)
  trials['rand_stats'].append(stats)

  print("   Magnitude pruning")
  set_seed(model_args.seed+t)
  model = SparseMLP(model_args.input_size, model_args.output_size, hidden_size=model_args.hidden_size)
  criteria_fn = lambda init_params, final_params: final_params.abs()
  models, stats = find_lottery_ticket(model, data, model_args, sparsity_schedule,
                  criteria_fn=criteria_fn, prune_print_every=1)
  trials['lott_models'].append(models)
  trials['lott_stats'].append(stats)
# Out:
# ############  Trial 0  ############
#    Random pruning
# 	retrain #1, sparsity 0.00, final_train_loss 3.169e-01, max_acc 64.5, last_acc 63.2, mean_acc 57.4
# 	retrain #2, sparsity 0.01, final_train_loss 9.877e-02, max_acc 64.8, last_acc 64.2, mean_acc 57.6
# 	retrain #3, sparsity 0.02, final_train_loss 3.814e-01, max_acc 63.9, last_acc 63.9, mean_acc 56.8
# 	retrain #4, sparsity 0.03, final_train_loss 2.059e-01, max_acc 65.9, last_acc 65.7, mean_acc 58.0
# 	retrain #5, sparsity 0.04, final_train_loss 1.694e-01, max_acc 65.1, last_acc 64.8, mean_acc 58.1
# 	retrain #6, sparsity 0.05, final_train_loss 2.515e-01, max_acc 64.0, last_acc 63.8, mean_acc 57.4
# 	retrain #7, sparsity 0.06, final_train_loss 1.878e-01, max_acc 63.6, last_acc 63.6, mean_acc 57.2
# 	retrain #8, sparsity 0.07, final_train_loss 3.240e-01, max_acc 64.8, last_acc 64.8, mean_acc 57.4
# 	retrain #9, sparsity 0.08, final_train_loss 3.263e-01, max_acc 65.7, last_acc 63.2, mean_acc 57.9
# 	retrain #10, sparsity 0.09, final_train_loss 4.437e-01, max_acc 65.2, last_acc 63.3, mean_acc 57.8
# 	retrain #11, sparsity 0.10, final_train_loss 4.379e-01, max_acc 66.1, last_acc 65.1, mean_acc 58.3
# 	retrain #12, sparsity 0.11, final_train_loss 1.132e-01, max_acc 64.5, last_acc 62.6, mean_acc 57.7
# 	retrain #13, sparsity 0.12, final_train_loss 8.312e-02, max_acc 67.5, last_acc 67.5, mean_acc 58.7
# 	retrain #14, sparsity 0.13, final_train_loss 1.442e-01, max_acc 65.9, last_acc 64.0, mean_acc 58.8
# 	retrain #15, sparsity 0.14, final_train_loss 1.793e-01, max_acc 65.9, last_acc 65.7, mean_acc 58.4
# 	retrain #16, sparsity 0.15, final_train_loss 2.254e-01, max_acc 67.0, last_acc 67.0, mean_acc 58.1
# 	retrain #17, sparsity 0.16, final_train_loss 3.682e-01, max_acc 63.8, last_acc 62.3, mean_acc 57.6
# 	retrain #18, sparsity 0.17, final_train_loss 2.932e-01, max_acc 66.8, last_acc 66.8, mean_acc 58.9
# 	retrain #19, sparsity 0.18, final_train_loss 2.187e-01, max_acc 66.5, last_acc 65.0, mean_acc 58.1
# 	retrain #20, sparsity 0.19, final_train_loss 1.236e-01, max_acc 66.9, last_acc 64.7, mean_acc 58.1
# 	retrain #21, sparsity 0.20, final_train_loss 2.109e-01, max_acc 63.8, last_acc 63.8, mean_acc 57.2
# 	retrain #22, sparsity 0.21, final_train_loss 1.360e-01, max_acc 66.3, last_acc 66.3, mean_acc 57.4
# 	retrain #23, sparsity 0.22, final_train_loss 1.261e-01, max_acc 65.6, last_acc 65.6, mean_acc 57.3
# 	retrain #24, sparsity 0.23, final_train_loss 1.078e-01, max_acc 65.6, last_acc 65.6, mean_acc 57.9
# 	retrain #25, sparsity 0.24, final_train_loss 3.778e-01, max_acc 67.4, last_acc 63.6, mean_acc 58.1
# 	retrain #26, sparsity 0.25, final_train_loss 3.392e-01, max_acc 65.6, last_acc 63.9, mean_acc 57.4
# 	retrain #27, sparsity 0.26, final_train_loss 2.803e-01, max_acc 65.3, last_acc 65.3, mean_acc 58.0
# 	retrain #28, sparsity 0.27, final_train_loss 2.703e-01, max_acc 64.8, last_acc 64.8, mean_acc 57.8
# 	retrain #29, sparsity 0.28, final_train_loss 2.191e-01, max_acc 65.7, last_acc 64.8, mean_acc 57.7
# 	retrain #30, sparsity 0.29, final_train_loss 3.274e-01, max_acc 66.3, last_acc 65.3, mean_acc 58.2
# 	retrain #31, sparsity 0.30, final_train_loss 2.245e-01, max_acc 66.3, last_acc 62.8, mean_acc 58.3
# 	retrain #32, sparsity 0.31, final_train_loss 1.745e-01, max_acc 66.3, last_acc 63.4, mean_acc 58.1
# 	retrain #33, sparsity 0.32, final_train_loss 1.251e-01, max_acc 65.7, last_acc 64.4, mean_acc 58.4
# 	retrain #34, sparsity 0.33, final_train_loss 2.791e-01, max_acc 65.4, last_acc 64.1, mean_acc 58.1
# 	retrain #35, sparsity 0.34, final_train_loss 3.301e-01, max_acc 63.9, last_acc 61.8, mean_acc 57.2
# 	retrain #36, sparsity 0.35, final_train_loss 2.954e-01, max_acc 65.7, last_acc 65.4, mean_acc 58.5
# 	retrain #37, sparsity 0.36, final_train_loss 2.860e-01, max_acc 63.2, last_acc 62.3, mean_acc 57.6
# 	retrain #38, sparsity 0.37, final_train_loss 2.217e-01, max_acc 66.6, last_acc 63.6, mean_acc 58.3
# 	retrain #39, sparsity 0.38, final_train_loss 4.717e-02, max_acc 65.1, last_acc 64.9, mean_acc 58.2
# 	retrain #40, sparsity 0.39, final_train_loss 2.240e-01, max_acc 66.6, last_acc 64.8, mean_acc 59.2
# 	retrain #41, sparsity 0.40, final_train_loss 1.814e-01, max_acc 65.2, last_acc 65.2, mean_acc 57.9
# 	retrain #42, sparsity 0.41, final_train_loss 2.835e-01, max_acc 65.9, last_acc 65.5, mean_acc 58.0
# 	retrain #43, sparsity 0.42, final_train_loss 1.116e-01, max_acc 64.2, last_acc 63.4, mean_acc 57.9
# 	retrain #44, sparsity 0.43, final_train_loss 1.282e-01, max_acc 65.6, last_acc 65.6, mean_acc 58.0
# 	retrain #45, sparsity 0.44, final_train_loss 2.517e-01, max_acc 63.6, last_acc 62.7, mean_acc 57.5
# 	retrain #46, sparsity 0.45, final_train_loss 2.807e-01, max_acc 65.3, last_acc 63.6, mean_acc 58.3
# 	retrain #47, sparsity 0.46, final_train_loss 5.854e-01, max_acc 65.2, last_acc 63.6, mean_acc 58.1
# 	retrain #48, sparsity 0.47, final_train_loss 1.150e-01, max_acc 65.0, last_acc 65.0, mean_acc 58.2
# 	retrain #49, sparsity 0.48, final_train_loss 1.180e-01, max_acc 67.1, last_acc 67.1, mean_acc 59.5
# 	retrain #50, sparsity 0.49, final_train_loss 8.580e-02, max_acc 64.7, last_acc 64.7, mean_acc 57.9
# 	retrain #51, sparsity 0.51, final_train_loss 1.619e-01, max_acc 66.6, last_acc 66.5, mean_acc 59.1
# 	retrain #52, sparsity 0.52, final_train_loss 6.472e-01, max_acc 65.2, last_acc 62.6, mean_acc 58.0
# 	retrain #53, sparsity 0.53, final_train_loss 1.819e-01, max_acc 65.7, last_acc 64.3, mean_acc 58.6
# 	retrain #54, sparsity 0.54, final_train_loss 3.035e-01, max_acc 64.7, last_acc 63.8, mean_acc 58.3
# 	retrain #55, sparsity 0.55, final_train_loss 3.373e-01, max_acc 66.1, last_acc 65.6, mean_acc 58.7
# 	retrain #56, sparsity 0.56, final_train_loss 2.079e-01, max_acc 64.7, last_acc 63.1, mean_acc 57.9
# 	retrain #57, sparsity 0.57, final_train_loss 1.049e-01, max_acc 66.8, last_acc 66.8, mean_acc 58.4
# 	retrain #58, sparsity 0.58, final_train_loss 1.907e-01, max_acc 66.1, last_acc 65.4, mean_acc 58.4
# 	retrain #59, sparsity 0.59, final_train_loss 1.447e-01, max_acc 67.6, last_acc 64.4, mean_acc 58.2
# 	retrain #60, sparsity 0.60, final_train_loss 6.135e-01, max_acc 64.4, last_acc 62.0, mean_acc 57.7
# 	retrain #61, sparsity 0.61, final_train_loss 4.253e-01, max_acc 69.1, last_acc 67.4, mean_acc 60.3
# 	retrain #62, sparsity 0.62, final_train_loss 7.737e-02, max_acc 66.0, last_acc 65.6, mean_acc 58.9
# 	retrain #63, sparsity 0.63, final_train_loss 1.535e-01, max_acc 66.0, last_acc 65.0, mean_acc 58.4
# 	retrain #64, sparsity 0.64, final_train_loss 1.425e-01, max_acc 67.8, last_acc 67.8, mean_acc 59.3
# 	retrain #65, sparsity 0.65, final_train_loss 3.501e-01, max_acc 67.1, last_acc 65.9, mean_acc 59.6
# 	retrain #66, sparsity 0.66, final_train_loss 9.856e-02, max_acc 65.7, last_acc 64.5, mean_acc 59.0
# 	retrain #67, sparsity 0.67, final_train_loss 7.004e-02, max_acc 66.5, last_acc 63.7, mean_acc 59.7
# 	retrain #68, sparsity 0.68, final_train_loss 4.637e-01, max_acc 64.7, last_acc 63.8, mean_acc 58.5
# 	retrain #69, sparsity 0.69, final_train_loss 1.844e-01, max_acc 69.1, last_acc 64.9, mean_acc 59.5
# 	retrain #70, sparsity 0.70, final_train_loss 1.985e-01, max_acc 66.8, last_acc 66.8, mean_acc 59.4
# 	retrain #71, sparsity 0.71, final_train_loss 1.182e-02, max_acc 69.1, last_acc 69.1, mean_acc 59.5
# 	retrain #72, sparsity 0.72, final_train_loss 2.997e-01, max_acc 69.5, last_acc 69.1, mean_acc 61.6
# 	retrain #73, sparsity 0.73, final_train_loss 1.804e-01, max_acc 67.0, last_acc 66.5, mean_acc 59.7
# 	retrain #74, sparsity 0.74, final_train_loss 1.567e-01, max_acc 67.3, last_acc 67.3, mean_acc 60.2
# 	retrain #75, sparsity 0.75, final_train_loss 3.254e-02, max_acc 68.4, last_acc 68.4, mean_acc 60.3
# 	retrain #76, sparsity 0.76, final_train_loss 2.531e-01, max_acc 69.5, last_acc 66.1, mean_acc 60.2
# 	retrain #77, sparsity 0.77, final_train_loss 4.299e-02, max_acc 67.8, last_acc 66.5, mean_acc 60.3
# 	retrain #78, sparsity 0.78, final_train_loss 1.077e-01, max_acc 67.2, last_acc 66.7, mean_acc 60.5
# 	retrain #79, sparsity 0.79, final_train_loss 3.650e-02, max_acc 68.7, last_acc 68.2, mean_acc 59.9
# 	retrain #80, sparsity 0.80, final_train_loss 2.296e-01, max_acc 67.4, last_acc 65.9, mean_acc 60.7
# 	retrain #81, sparsity 0.81, final_train_loss 2.358e-01, max_acc 68.7, last_acc 68.7, mean_acc 60.4
# 	retrain #82, sparsity 0.82, final_train_loss 2.000e-02, max_acc 67.7, last_acc 67.7, mean_acc 59.6
# 	retrain #83, sparsity 0.83, final_train_loss 1.467e-01, max_acc 67.4, last_acc 67.3, mean_acc 59.5
# 	retrain #84, sparsity 0.84, final_train_loss 1.608e-01, max_acc 67.3, last_acc 66.9, mean_acc 59.8
# 	retrain #85, sparsity 0.85, final_train_loss 2.629e-01, max_acc 66.7, last_acc 64.5, mean_acc 59.2
# 	retrain #86, sparsity 0.86, final_train_loss 1.346e-01, max_acc 67.1, last_acc 67.1, mean_acc 59.4
# 	retrain #87, sparsity 0.87, final_train_loss 4.565e-03, max_acc 67.1, last_acc 67.1, mean_acc 59.3
# 	retrain #88, sparsity 0.88, final_train_loss 1.463e-01, max_acc 66.6, last_acc 66.6, mean_acc 59.2
# 	retrain #89, sparsity 0.89, final_train_loss 9.343e-02, max_acc 65.6, last_acc 63.8, mean_acc 58.3
# 	retrain #90, sparsity 0.90, final_train_loss 1.687e-01, max_acc 64.0, last_acc 62.4, mean_acc 57.0
# 	retrain #91, sparsity 0.91, final_train_loss 5.460e-02, max_acc 63.7, last_acc 63.7, mean_acc 56.8
# 	retrain #92, sparsity 0.92, final_train_loss 1.613e-01, max_acc 62.4, last_acc 61.9, mean_acc 55.1
# 	retrain #93, sparsity 0.93, final_train_loss 1.927e-01, max_acc 59.5, last_acc 58.0, mean_acc 53.6
# 	retrain #94, sparsity 0.94, final_train_loss 1.977e-01, max_acc 59.1, last_acc 58.5, mean_acc 52.5
# 	retrain #95, sparsity 0.95, final_train_loss 4.401e-01, max_acc 59.3, last_acc 55.8, mean_acc 51.3
# 	retrain #96, sparsity 0.96, final_train_loss 7.074e-01, max_acc 49.8, last_acc 48.5, mean_acc 44.0
# 	retrain #97, sparsity 0.97, final_train_loss 1.138e+00, max_acc 45.0, last_acc 44.3, mean_acc 39.4
# 	retrain #98, sparsity 0.98, final_train_loss 1.635e+00, max_acc 33.4, last_acc 32.7, mean_acc 29.8
# 	retrain #99, sparsity 0.99, final_train_loss 2.120e+00, max_acc 19.2, last_acc 18.6, mean_acc 18.2
# 	retrain #100, sparsity 1.00, final_train_loss 2.303e+00, max_acc 10.2, last_acc 10.2, mean_acc 10.2
#    Magnitude pruning
# 	retrain #1, sparsity 0.00, final_train_loss 1.757e-01, max_acc 66.7, last_acc 66.7, mean_acc 57.4
# 	retrain #2, sparsity 0.01, final_train_loss 1.165e-01, max_acc 65.3, last_acc 65.3, mean_acc 57.6
# 	retrain #3, sparsity 0.02, final_train_loss 1.410e-01, max_acc 66.8, last_acc 66.1, mean_acc 58.2
# 	retrain #4, sparsity 0.03, final_train_loss 3.054e-01, max_acc 65.1, last_acc 64.0, mean_acc 57.7
# 	retrain #5, sparsity 0.04, final_train_loss 4.569e-02, max_acc 65.2, last_acc 65.2, mean_acc 58.1
# 	retrain #6, sparsity 0.05, final_train_loss 3.350e-01, max_acc 64.5, last_acc 63.9, mean_acc 57.8
# 	retrain #7, sparsity 0.06, final_train_loss 2.388e-01, max_acc 65.9, last_acc 64.4, mean_acc 58.6
# 	retrain #8, sparsity 0.07, final_train_loss 1.463e-01, max_acc 65.5, last_acc 65.3, mean_acc 58.9
# 	retrain #9, sparsity 0.08, final_train_loss 2.210e-01, max_acc 66.0, last_acc 64.9, mean_acc 59.2
# 	retrain #10, sparsity 0.09, final_train_loss 1.167e-01, max_acc 65.4, last_acc 64.7, mean_acc 58.8
# 	retrain #11, sparsity 0.10, final_train_loss 8.781e-02, max_acc 65.9, last_acc 64.0, mean_acc 58.8
# 	retrain #12, sparsity 0.11, final_train_loss 1.046e-01, max_acc 65.5, last_acc 65.5, mean_acc 58.7
# 	retrain #13, sparsity 0.12, final_train_loss 8.280e-02, max_acc 66.6, last_acc 66.1, mean_acc 59.9
# 	retrain #14, sparsity 0.13, final_train_loss 2.441e-01, max_acc 65.6, last_acc 64.0, mean_acc 59.0
# 	retrain #15, sparsity 0.14, final_train_loss 2.998e-01, max_acc 67.2, last_acc 64.9, mean_acc 59.8
# 	retrain #16, sparsity 0.15, final_train_loss 3.744e-02, max_acc 68.6, last_acc 68.6, mean_acc 59.7
# 	retrain #17, sparsity 0.16, final_train_loss 1.675e-01, max_acc 65.3, last_acc 63.7, mean_acc 58.5
# 	retrain #18, sparsity 0.17, final_train_loss 4.598e-01, max_acc 65.7, last_acc 62.6, mean_acc 59.5
# 	retrain #19, sparsity 0.18, final_train_loss 3.643e-01, max_acc 65.8, last_acc 65.4, mean_acc 58.9
# 	retrain #20, sparsity 0.19, final_train_loss 1.187e-01, max_acc 67.5, last_acc 67.5, mean_acc 60.3
# 	retrain #21, sparsity 0.20, final_train_loss 1.973e-01, max_acc 67.3, last_acc 64.9, mean_acc 59.9
# 	retrain #22, sparsity 0.21, final_train_loss 2.311e-01, max_acc 66.9, last_acc 66.0, mean_acc 59.8
# 	retrain #23, sparsity 0.22, final_train_loss 3.657e-02, max_acc 66.1, last_acc 66.1, mean_acc 59.4
# 	retrain #24, sparsity 0.23, final_train_loss 2.503e-01, max_acc 66.8, last_acc 65.7, mean_acc 59.9
# 	retrain #25, sparsity 0.24, final_train_loss 1.790e-01, max_acc 66.8, last_acc 66.4, mean_acc 60.0
# 	retrain #26, sparsity 0.25, final_train_loss 2.557e-01, max_acc 66.9, last_acc 61.9, mean_acc 59.4
# 	retrain #27, sparsity 0.26, final_train_loss 1.267e-01, max_acc 67.6, last_acc 65.5, mean_acc 60.5
# 	retrain #28, sparsity 0.27, final_train_loss 4.024e-01, max_acc 68.2, last_acc 68.2, mean_acc 60.3
# 	retrain #29, sparsity 0.28, final_train_loss 1.768e-02, max_acc 66.7, last_acc 66.7, mean_acc 60.3
# 	retrain #30, sparsity 0.29, final_train_loss 1.560e-01, max_acc 68.2, last_acc 65.3, mean_acc 60.9
# 	retrain #31, sparsity 0.30, final_train_loss 2.836e-01, max_acc 66.3, last_acc 64.4, mean_acc 60.5
# 	retrain #32, sparsity 0.31, final_train_loss 1.323e-01, max_acc 67.6, last_acc 67.6, mean_acc 60.9
# 	retrain #33, sparsity 0.32, final_train_loss 3.033e-01, max_acc 66.9, last_acc 64.4, mean_acc 60.2
# 	retrain #34, sparsity 0.33, final_train_loss 2.400e-01, max_acc 65.9, last_acc 64.6, mean_acc 60.1
# 	retrain #35, sparsity 0.34, final_train_loss 2.409e-01, max_acc 67.0, last_acc 67.0, mean_acc 60.9
# 	retrain #36, sparsity 0.35, final_train_loss 1.050e-01, max_acc 67.8, last_acc 66.5, mean_acc 61.2
# 	retrain #37, sparsity 0.36, final_train_loss 1.882e-01, max_acc 67.2, last_acc 67.2, mean_acc 61.3
# 	retrain #38, sparsity 0.37, final_train_loss 3.241e-01, max_acc 67.2, last_acc 64.5, mean_acc 60.7
# 	retrain #39, sparsity 0.38, final_train_loss 5.366e-02, max_acc 66.9, last_acc 66.9, mean_acc 60.3
# 	retrain #40, sparsity 0.39, final_train_loss 1.087e-01, max_acc 66.7, last_acc 65.8, mean_acc 60.7
# 	retrain #41, sparsity 0.40, final_train_loss 2.184e-01, max_acc 67.9, last_acc 67.9, mean_acc 61.6
# 	retrain #42, sparsity 0.41, final_train_loss 1.307e-01, max_acc 67.3, last_acc 65.4, mean_acc 60.8
# 	retrain #43, sparsity 0.42, final_train_loss 6.812e-02, max_acc 66.4, last_acc 66.4, mean_acc 60.0
# 	retrain #44, sparsity 0.43, final_train_loss 4.781e-02, max_acc 67.7, last_acc 64.5, mean_acc 60.8
# 	retrain #45, sparsity 0.44, final_train_loss 2.923e-01, max_acc 67.3, last_acc 64.4, mean_acc 60.8
# 	retrain #46, sparsity 0.45, final_train_loss 1.452e-02, max_acc 68.9, last_acc 68.9, mean_acc 61.4
# 	retrain #47, sparsity 0.46, final_train_loss 1.633e-02, max_acc 67.8, last_acc 67.5, mean_acc 61.5
# 	retrain #48, sparsity 0.47, final_train_loss 4.231e-02, max_acc 68.2, last_acc 66.1, mean_acc 62.3
# 	retrain #49, sparsity 0.48, final_train_loss 1.320e-01, max_acc 68.5, last_acc 67.5, mean_acc 61.9
# 	retrain #50, sparsity 0.49, final_train_loss 4.968e-02, max_acc 68.3, last_acc 65.8, mean_acc 61.8
# 	retrain #51, sparsity 0.51, final_train_loss 2.014e-01, max_acc 68.7, last_acc 68.6, mean_acc 62.2
# 	retrain #52, sparsity 0.52, final_train_loss 9.828e-02, max_acc 69.5, last_acc 64.3, mean_acc 62.7
# 	retrain #53, sparsity 0.53, final_train_loss 1.408e-01, max_acc 68.6, last_acc 68.6, mean_acc 62.1
# 	retrain #54, sparsity 0.54, final_train_loss 9.937e-02, max_acc 68.7, last_acc 67.3, mean_acc 62.6
# 	retrain #55, sparsity 0.55, final_train_loss 1.750e-01, max_acc 68.5, last_acc 68.0, mean_acc 62.3
# 	retrain #56, sparsity 0.56, final_train_loss 3.143e-01, max_acc 68.5, last_acc 65.9, mean_acc 62.5
# 	retrain #57, sparsity 0.57, final_train_loss 1.748e-01, max_acc 69.7, last_acc 67.8, mean_acc 63.1
# 	retrain #58, sparsity 0.58, final_train_loss 1.918e-02, max_acc 69.3, last_acc 68.9, mean_acc 63.0
# 	retrain #59, sparsity 0.59, final_train_loss 2.022e-01, max_acc 69.8, last_acc 66.2, mean_acc 63.0
# 	retrain #60, sparsity 0.60, final_train_loss 1.990e-01, max_acc 67.8, last_acc 66.9, mean_acc 62.6
# 	retrain #61, sparsity 0.61, final_train_loss 1.406e-01, max_acc 69.5, last_acc 69.5, mean_acc 62.9
# 	retrain #62, sparsity 0.62, final_train_loss 5.522e-02, max_acc 68.8, last_acc 67.7, mean_acc 62.7
# 	retrain #63, sparsity 0.63, final_train_loss 1.352e-01, max_acc 69.1, last_acc 67.9, mean_acc 63.1
# 	retrain #64, sparsity 0.64, final_train_loss 1.410e-01, max_acc 67.2, last_acc 65.4, mean_acc 62.5
# 	retrain #65, sparsity 0.65, final_train_loss 4.990e-01, max_acc 68.9, last_acc 66.0, mean_acc 62.9
# 	retrain #66, sparsity 0.66, final_train_loss 1.044e-01, max_acc 70.1, last_acc 68.9, mean_acc 63.5
# 	retrain #67, sparsity 0.67, final_train_loss 3.134e-02, max_acc 68.2, last_acc 68.1, mean_acc 62.5
# 	retrain #68, sparsity 0.68, final_train_loss 1.707e-01, max_acc 68.3, last_acc 66.4, mean_acc 61.9
# 	retrain #69, sparsity 0.69, final_train_loss 3.129e-02, max_acc 69.2, last_acc 68.0, mean_acc 63.6
# 	retrain #70, sparsity 0.70, final_train_loss 4.547e-02, max_acc 72.1, last_acc 72.0, mean_acc 64.3
# 	retrain #71, sparsity 0.71, final_train_loss 2.504e-01, max_acc 69.3, last_acc 69.1, mean_acc 63.8
# 	retrain #72, sparsity 0.72, final_train_loss 1.403e-02, max_acc 72.4, last_acc 72.4, mean_acc 63.7
# 	retrain #73, sparsity 0.73, final_train_loss 1.487e-03, max_acc 73.3, last_acc 72.7, mean_acc 65.0
# 	retrain #74, sparsity 0.74, final_train_loss 8.453e-02, max_acc 69.7, last_acc 68.8, mean_acc 63.5
# 	retrain #75, sparsity 0.75, final_train_loss 1.485e-01, max_acc 69.7, last_acc 67.7, mean_acc 63.8
# 	retrain #76, sparsity 0.76, final_train_loss 1.658e-01, max_acc 69.5, last_acc 69.4, mean_acc 64.1
# 	retrain #77, sparsity 0.77, final_train_loss 5.112e-02, max_acc 70.9, last_acc 69.4, mean_acc 64.2
# 	retrain #78, sparsity 0.78, final_train_loss 1.308e-01, max_acc 70.1, last_acc 68.2, mean_acc 64.0
# 	retrain #79, sparsity 0.79, final_train_loss 7.499e-02, max_acc 69.9, last_acc 68.9, mean_acc 63.7
# 	retrain #80, sparsity 0.80, final_train_loss 6.515e-02, max_acc 70.8, last_acc 66.9, mean_acc 64.1
# 	retrain #81, sparsity 0.81, final_train_loss 2.464e-02, max_acc 70.1, last_acc 68.2, mean_acc 63.8
# 	retrain #82, sparsity 0.82, final_train_loss 1.554e-02, max_acc 71.1, last_acc 71.1, mean_acc 64.2
# 	retrain #83, sparsity 0.83, final_train_loss 1.530e-01, max_acc 71.4, last_acc 68.5, mean_acc 65.1
# 	retrain #84, sparsity 0.84, final_train_loss 1.617e-03, max_acc 71.6, last_acc 71.6, mean_acc 65.0
# 	retrain #85, sparsity 0.85, final_train_loss 3.723e-02, max_acc 70.1, last_acc 68.4, mean_acc 64.5
# 	retrain #86, sparsity 0.86, final_train_loss 1.650e-03, max_acc 72.3, last_acc 72.3, mean_acc 66.0
# 	retrain #87, sparsity 0.87, final_train_loss 8.421e-02, max_acc 72.3, last_acc 67.7, mean_acc 65.8
# 	retrain #88, sparsity 0.88, final_train_loss 8.273e-02, max_acc 70.1, last_acc 68.8, mean_acc 64.9
# 	retrain #89, sparsity 0.89, final_train_loss 1.597e-03, max_acc 71.9, last_acc 71.4, mean_acc 66.1
# 	retrain #90, sparsity 0.90, final_train_loss 2.051e-01, max_acc 69.3, last_acc 66.9, mean_acc 63.7
# 	retrain #91, sparsity 0.91, final_train_loss 1.214e-01, max_acc 70.0, last_acc 68.2, mean_acc 64.6
# 	retrain #92, sparsity 0.92, final_train_loss 1.274e-01, max_acc 70.0, last_acc 69.5, mean_acc 64.6
# 	retrain #93, sparsity 0.93, final_train_loss 1.654e-01, max_acc 69.3, last_acc 68.0, mean_acc 63.9
# 	retrain #94, sparsity 0.94, final_train_loss 1.305e-01, max_acc 68.4, last_acc 65.3, mean_acc 62.6
# 	retrain #95, sparsity 0.95, final_train_loss 2.731e-01, max_acc 67.0, last_acc 66.3, mean_acc 62.2
# 	retrain #96, sparsity 0.96, final_train_loss 2.808e-01, max_acc 66.1, last_acc 65.3, mean_acc 61.1
# 	retrain #97, sparsity 0.97, final_train_loss 4.160e-01, max_acc 65.6, last_acc 65.6, mean_acc 59.4
# 	retrain #98, sparsity 0.98, final_train_loss 8.312e-01, max_acc 56.7, last_acc 55.7, mean_acc 51.3
# 	retrain #99, sparsity 0.99, final_train_loss 1.283e+00, max_acc 39.3, last_acc 38.2, mean_acc 35.6
# 	retrain #100, sparsity 1.00, final_train_loss 2.303e+00, max_acc 10.2, last_acc 10.2, mean_acc 10.2
# ############  Trial 1  ############
#    Random pruning
# 	retrain #1, sparsity 0.00, final_train_loss 2.837e-01, max_acc 65.5, last_acc 64.4, mean_acc 58.3
# 	retrain #2, sparsity 0.01, final_train_loss 1.945e-01, max_acc 65.1, last_acc 65.1, mean_acc 57.5
# 	retrain #3, sparsity 0.02, final_train_loss 1.494e-01, max_acc 65.4, last_acc 64.9, mean_acc 58.0
# 	retrain #4, sparsity 0.03, final_train_loss 2.148e-01, max_acc 66.4, last_acc 64.3, mean_acc 57.2
# 	retrain #5, sparsity 0.04, final_train_loss 2.124e-01, max_acc 64.4, last_acc 63.3, mean_acc 57.1
# 	retrain #6, sparsity 0.05, final_train_loss 2.320e-01, max_acc 65.0, last_acc 65.0, mean_acc 57.2
# 	retrain #7, sparsity 0.06, final_train_loss 1.441e-01, max_acc 64.7, last_acc 63.0, mean_acc 57.5
# 	retrain #8, sparsity 0.07, final_train_loss 4.566e-02, max_acc 66.3, last_acc 64.1, mean_acc 57.4
# 	retrain #9, sparsity 0.08, final_train_loss 2.233e-01, max_acc 66.6, last_acc 65.8, mean_acc 58.1
# 	retrain #10, sparsity 0.09, final_train_loss 1.633e-01, max_acc 66.0, last_acc 64.2, mean_acc 57.9
# 	retrain #11, sparsity 0.10, final_train_loss 1.057e-01, max_acc 65.3, last_acc 65.3, mean_acc 57.2
# 	retrain #12, sparsity 0.11, final_train_loss 2.287e-01, max_acc 65.0, last_acc 65.0, mean_acc 57.5
# 	retrain #13, sparsity 0.12, final_train_loss 1.253e-01, max_acc 65.7, last_acc 65.7, mean_acc 57.4
# 	retrain #14, sparsity 0.13, final_train_loss 1.370e-01, max_acc 66.9, last_acc 66.9, mean_acc 58.4
# 	retrain #15, sparsity 0.14, final_train_loss 8.288e-02, max_acc 64.8, last_acc 63.8, mean_acc 57.9
# 	retrain #16, sparsity 0.15, final_train_loss 3.037e-01, max_acc 65.0, last_acc 63.9, mean_acc 57.1
# 	retrain #17, sparsity 0.16, final_train_loss 1.608e-01, max_acc 65.2, last_acc 65.2, mean_acc 57.8
# 	retrain #18, sparsity 0.17, final_train_loss 1.344e-01, max_acc 64.6, last_acc 64.6, mean_acc 57.3
# 	retrain #19, sparsity 0.18, final_train_loss 2.100e-01, max_acc 65.4, last_acc 64.2, mean_acc 57.9
# 	retrain #20, sparsity 0.19, final_train_loss 2.219e-01, max_acc 64.3, last_acc 64.3, mean_acc 56.7
# 	retrain #21, sparsity 0.20, final_train_loss 6.088e-02, max_acc 65.3, last_acc 64.6, mean_acc 57.2
# 	retrain #22, sparsity 0.21, final_train_loss 6.663e-02, max_acc 64.1, last_acc 63.8, mean_acc 57.9
# 	retrain #23, sparsity 0.22, final_train_loss 1.901e-01, max_acc 66.3, last_acc 64.6, mean_acc 57.7
# 	retrain #24, sparsity 0.23, final_train_loss 2.163e-01, max_acc 65.6, last_acc 64.2, mean_acc 58.1
# 	retrain #25, sparsity 0.24, final_train_loss 3.785e-02, max_acc 66.1, last_acc 65.3, mean_acc 58.2
# 	retrain #26, sparsity 0.25, final_train_loss 3.576e-01, max_acc 64.6, last_acc 63.8, mean_acc 57.7
# 	retrain #27, sparsity 0.26, final_train_loss 1.023e-01, max_acc 65.5, last_acc 65.5, mean_acc 57.6
# 	retrain #28, sparsity 0.27, final_train_loss 1.598e-01, max_acc 64.1, last_acc 63.4, mean_acc 57.1
# 	retrain #29, sparsity 0.28, final_train_loss 2.809e-01, max_acc 66.3, last_acc 63.7, mean_acc 58.2
# 	retrain #30, sparsity 0.29, final_train_loss 1.809e-01, max_acc 65.8, last_acc 65.8, mean_acc 57.3
# 	retrain #31, sparsity 0.30, final_train_loss 1.623e-01, max_acc 66.1, last_acc 65.4, mean_acc 58.1
# 	retrain #32, sparsity 0.31, final_train_loss 1.803e-01, max_acc 64.5, last_acc 64.2, mean_acc 57.3
# 	retrain #33, sparsity 0.32, final_train_loss 1.159e-01, max_acc 65.5, last_acc 64.0, mean_acc 58.1
# 	retrain #34, sparsity 0.33, final_train_loss 1.867e-01, max_acc 64.2, last_acc 62.4, mean_acc 57.2
# 	retrain #35, sparsity 0.34, final_train_loss 2.070e-01, max_acc 65.8, last_acc 62.1, mean_acc 58.2
# 	retrain #36, sparsity 0.35, final_train_loss 1.502e-01, max_acc 64.8, last_acc 64.8, mean_acc 57.1
# 	retrain #37, sparsity 0.36, final_train_loss 2.773e-01, max_acc 65.6, last_acc 65.0, mean_acc 58.5
# 	retrain #38, sparsity 0.37, final_train_loss 3.166e-01, max_acc 65.8, last_acc 62.5, mean_acc 57.9
# 	retrain #39, sparsity 0.38, final_train_loss 1.798e-01, max_acc 63.9, last_acc 62.2, mean_acc 57.4
# 	retrain #40, sparsity 0.39, final_train_loss 3.981e-01, max_acc 65.6, last_acc 64.8, mean_acc 57.8
# 	retrain #41, sparsity 0.40, final_train_loss 1.804e-01, max_acc 66.4, last_acc 64.0, mean_acc 57.5
# 	retrain #42, sparsity 0.41, final_train_loss 2.540e-01, max_acc 65.4, last_acc 65.4, mean_acc 58.6
# 	retrain #43, sparsity 0.42, final_train_loss 2.452e-01, max_acc 64.2, last_acc 61.6, mean_acc 57.1
# 	retrain #44, sparsity 0.43, final_train_loss 2.363e-01, max_acc 65.5, last_acc 65.5, mean_acc 58.8
# 	retrain #45, sparsity 0.44, final_train_loss 2.842e-01, max_acc 66.4, last_acc 64.5, mean_acc 57.9
# 	retrain #46, sparsity 0.45, final_train_loss 2.392e-01, max_acc 64.1, last_acc 64.1, mean_acc 57.2
# 	retrain #47, sparsity 0.46, final_train_loss 2.360e-01, max_acc 65.6, last_acc 64.3, mean_acc 57.6
# 	retrain #48, sparsity 0.47, final_train_loss 3.209e-01, max_acc 63.7, last_acc 63.1, mean_acc 56.7
# 	retrain #49, sparsity 0.48, final_train_loss 2.024e-01, max_acc 66.3, last_acc 62.2, mean_acc 58.5
# 	retrain #50, sparsity 0.49, final_train_loss 1.634e-01, max_acc 63.6, last_acc 63.6, mean_acc 57.8
# 	retrain #51, sparsity 0.51, final_train_loss 2.562e-01, max_acc 65.9, last_acc 65.4, mean_acc 58.5
# 	retrain #52, sparsity 0.52, final_train_loss 1.287e-01, max_acc 65.3, last_acc 64.3, mean_acc 58.0
# 	retrain #53, sparsity 0.53, final_train_loss 9.556e-02, max_acc 67.4, last_acc 65.6, mean_acc 58.8
# 	retrain #54, sparsity 0.54, final_train_loss 9.784e-02, max_acc 65.9, last_acc 65.7, mean_acc 58.8
# 	retrain #55, sparsity 0.55, final_train_loss 3.253e-01, max_acc 66.8, last_acc 66.2, mean_acc 59.1
# 	retrain #56, sparsity 0.56, final_train_loss 8.840e-02, max_acc 64.9, last_acc 64.9, mean_acc 58.3
# 	retrain #57, sparsity 0.57, final_train_loss 1.546e-01, max_acc 67.7, last_acc 67.7, mean_acc 58.3
# 	retrain #58, sparsity 0.58, final_train_loss 2.250e-01, max_acc 66.7, last_acc 66.2, mean_acc 59.5
# 	retrain #59, sparsity 0.59, final_train_loss 1.889e-01, max_acc 65.3, last_acc 65.3, mean_acc 57.9
# 	retrain #60, sparsity 0.60, final_train_loss 8.012e-02, max_acc 67.7, last_acc 67.7, mean_acc 58.8
# 	retrain #61, sparsity 0.61, final_train_loss 1.644e-01, max_acc 66.9, last_acc 66.9, mean_acc 59.3
# 	retrain #62, sparsity 0.62, final_train_loss 3.066e-01, max_acc 67.8, last_acc 65.6, mean_acc 58.8
# 	retrain #63, sparsity 0.63, final_train_loss 3.415e-01, max_acc 65.4, last_acc 63.2, mean_acc 58.6
# 	retrain #64, sparsity 0.64, final_train_loss 1.477e-01, max_acc 68.1, last_acc 66.5, mean_acc 60.3
# 	retrain #65, sparsity 0.65, final_train_loss 7.860e-02, max_acc 66.8, last_acc 64.8, mean_acc 59.2
# 	retrain #66, sparsity 0.66, final_train_loss 1.063e-01, max_acc 68.5, last_acc 68.5, mean_acc 60.2
# 	retrain #67, sparsity 0.67, final_train_loss 2.964e-01, max_acc 67.8, last_acc 65.2, mean_acc 60.0
# 	retrain #68, sparsity 0.68, final_train_loss 4.796e-02, max_acc 68.6, last_acc 68.6, mean_acc 59.0
# 	retrain #69, sparsity 0.69, final_train_loss 1.726e-01, max_acc 68.3, last_acc 66.1, mean_acc 60.1
# 	retrain #70, sparsity 0.70, final_train_loss 1.908e-01, max_acc 67.2, last_acc 66.3, mean_acc 60.3
# 	retrain #71, sparsity 0.71, final_train_loss 1.151e-01, max_acc 68.6, last_acc 68.6, mean_acc 60.4
# 	retrain #72, sparsity 0.72, final_train_loss 1.880e-01, max_acc 68.0, last_acc 65.9, mean_acc 60.0
# 	retrain #73, sparsity 0.73, final_train_loss 2.723e-01, max_acc 66.7, last_acc 65.4, mean_acc 60.2
# 	retrain #74, sparsity 0.74, final_train_loss 2.049e-01, max_acc 67.0, last_acc 66.1, mean_acc 60.4
# 	retrain #75, sparsity 0.75, final_train_loss 5.756e-02, max_acc 68.9, last_acc 68.2, mean_acc 61.1
# 	retrain #76, sparsity 0.76, final_train_loss 5.945e-02, max_acc 68.7, last_acc 66.0, mean_acc 60.1
# 	retrain #77, sparsity 0.77, final_train_loss 4.451e-01, max_acc 67.6, last_acc 65.8, mean_acc 60.8
# 	retrain #78, sparsity 0.78, final_train_loss 1.620e-01, max_acc 69.6, last_acc 69.6, mean_acc 60.4
# 	retrain #79, sparsity 0.79, final_train_loss 1.437e-01, max_acc 68.9, last_acc 67.8, mean_acc 60.4
# 	retrain #80, sparsity 0.80, final_train_loss 2.803e-02, max_acc 69.1, last_acc 69.1, mean_acc 60.5
# 	retrain #81, sparsity 0.81, final_train_loss 2.060e-02, max_acc 68.2, last_acc 66.8, mean_acc 60.8
# 	retrain #82, sparsity 0.82, final_train_loss 2.765e-02, max_acc 68.8, last_acc 68.1, mean_acc 60.9
# 	retrain #83, sparsity 0.83, final_train_loss 6.647e-02, max_acc 67.2, last_acc 64.4, mean_acc 58.2
# 	retrain #84, sparsity 0.84, final_train_loss 6.829e-02, max_acc 66.8, last_acc 65.3, mean_acc 58.4
# 	retrain #85, sparsity 0.85, final_train_loss 5.012e-03, max_acc 68.3, last_acc 68.3, mean_acc 60.6
# 	retrain #86, sparsity 0.86, final_train_loss 8.928e-03, max_acc 69.4, last_acc 69.4, mean_acc 59.7
# 	retrain #87, sparsity 0.87, final_train_loss 3.384e-02, max_acc 69.4, last_acc 69.4, mean_acc 59.2
# 	retrain #88, sparsity 0.88, final_train_loss 1.557e-01, max_acc 63.0, last_acc 60.9, mean_acc 56.3
# 	retrain #89, sparsity 0.89, final_train_loss 1.140e-01, max_acc 64.9, last_acc 63.5, mean_acc 57.8
# 	retrain #90, sparsity 0.90, final_train_loss 2.733e-02, max_acc 64.9, last_acc 61.5, mean_acc 57.6
# 	retrain #91, sparsity 0.91, final_train_loss 1.767e-01, max_acc 63.4, last_acc 62.0, mean_acc 55.7
# 	retrain #92, sparsity 0.92, final_train_loss 1.642e-01, max_acc 60.6, last_acc 59.3, mean_acc 54.4
# 	retrain #93, sparsity 0.93, final_train_loss 4.406e-01, max_acc 58.3, last_acc 55.3, mean_acc 52.5
# 	retrain #94, sparsity 0.94, final_train_loss 5.300e-01, max_acc 58.4, last_acc 56.4, mean_acc 51.8
# 	retrain #95, sparsity 0.95, final_train_loss 4.486e-01, max_acc 55.5, last_acc 55.5, mean_acc 48.4
# 	retrain #96, sparsity 0.96, final_train_loss 8.044e-01, max_acc 52.1, last_acc 51.0, mean_acc 46.0
# 	retrain #97, sparsity 0.97, final_train_loss 1.075e+00, max_acc 40.6, last_acc 40.5, mean_acc 36.4
# 	retrain #98, sparsity 0.98, final_train_loss 1.698e+00, max_acc 31.1, last_acc 29.3, mean_acc 28.3
# 	retrain #99, sparsity 0.99, final_train_loss 2.326e+00, max_acc 14.8, last_acc 14.8, mean_acc 14.3
# 	retrain #100, sparsity 1.00, final_train_loss 2.303e+00, max_acc 10.2, last_acc 10.2, mean_acc 10.2
#    Magnitude pruning
# 	retrain #1, sparsity 0.00, final_train_loss 3.662e-02, max_acc 64.3, last_acc 64.3, mean_acc 57.0
# 	retrain #2, sparsity 0.01, final_train_loss 2.673e-01, max_acc 65.8, last_acc 63.0, mean_acc 58.4
# 	retrain #3, sparsity 0.02, final_train_loss 3.085e-01, max_acc 66.0, last_acc 63.7, mean_acc 57.5
# 	retrain #4, sparsity 0.03, final_train_loss 3.066e-01, max_acc 64.4, last_acc 62.2, mean_acc 58.3
# 	retrain #5, sparsity 0.04, final_train_loss 1.688e-01, max_acc 67.2, last_acc 65.1, mean_acc 58.3
# 	retrain #6, sparsity 0.05, final_train_loss 1.705e-01, max_acc 66.1, last_acc 66.1, mean_acc 58.6
# 	retrain #7, sparsity 0.06, final_train_loss 8.805e-02, max_acc 66.0, last_acc 66.0, mean_acc 58.4
# 	retrain #8, sparsity 0.07, final_train_loss 3.868e-01, max_acc 65.3, last_acc 65.3, mean_acc 59.0
# 	retrain #9, sparsity 0.08, final_train_loss 2.677e-01, max_acc 66.5, last_acc 66.5, mean_acc 59.7
# 	retrain #10, sparsity 0.09, final_train_loss 8.774e-02, max_acc 66.2, last_acc 66.0, mean_acc 58.9
# 	retrain #11, sparsity 0.10, final_train_loss 3.164e-01, max_acc 67.5, last_acc 65.2, mean_acc 59.1
# 	retrain #12, sparsity 0.11, final_train_loss 2.564e-01, max_acc 65.4, last_acc 63.2, mean_acc 58.6
# 	retrain #13, sparsity 0.12, final_train_loss 3.707e-01, max_acc 66.1, last_acc 63.0, mean_acc 58.4
# 	retrain #14, sparsity 0.13, final_train_loss 1.120e-01, max_acc 66.5, last_acc 65.5, mean_acc 59.8
# 	retrain #15, sparsity 0.14, final_train_loss 1.174e-01, max_acc 66.7, last_acc 65.2, mean_acc 59.2
# 	retrain #16, sparsity 0.15, final_train_loss 2.412e-01, max_acc 66.7, last_acc 64.8, mean_acc 59.5
# 	retrain #17, sparsity 0.16, final_train_loss 9.153e-02, max_acc 67.1, last_acc 65.6, mean_acc 59.1
# 	retrain #18, sparsity 0.17, final_train_loss 1.148e-01, max_acc 66.6, last_acc 63.8, mean_acc 59.2
# 	retrain #19, sparsity 0.18, final_train_loss 2.228e-01, max_acc 67.0, last_acc 65.7, mean_acc 59.8
# 	retrain #20, sparsity 0.19, final_train_loss 1.578e-01, max_acc 66.8, last_acc 65.7, mean_acc 59.8
# 	retrain #21, sparsity 0.20, final_train_loss 8.736e-02, max_acc 66.9, last_acc 64.5, mean_acc 59.4
# 	retrain #22, sparsity 0.21, final_train_loss 2.708e-01, max_acc 65.7, last_acc 63.2, mean_acc 58.9
# 	retrain #23, sparsity 0.22, final_train_loss 5.796e-02, max_acc 66.7, last_acc 66.7, mean_acc 58.2
# 	retrain #24, sparsity 0.23, final_train_loss 1.542e-01, max_acc 67.8, last_acc 67.5, mean_acc 59.7
# 	retrain #25, sparsity 0.24, final_train_loss 1.958e-01, max_acc 68.3, last_acc 66.1, mean_acc 60.5
# 	retrain #26, sparsity 0.25, final_train_loss 1.032e-01, max_acc 68.7, last_acc 65.7, mean_acc 59.9
# 	retrain #27, sparsity 0.26, final_train_loss 2.708e-01, max_acc 66.8, last_acc 65.8, mean_acc 59.8
# 	retrain #28, sparsity 0.27, final_train_loss 1.262e-01, max_acc 65.9, last_acc 65.9, mean_acc 59.6
# 	retrain #29, sparsity 0.28, final_train_loss 3.626e-01, max_acc 67.0, last_acc 67.0, mean_acc 59.6
# 	retrain #30, sparsity 0.29, final_train_loss 1.952e-01, max_acc 66.5, last_acc 62.7, mean_acc 59.9
# 	retrain #31, sparsity 0.30, final_train_loss 1.676e-01, max_acc 68.4, last_acc 65.7, mean_acc 60.8
# 	retrain #32, sparsity 0.31, final_train_loss 9.519e-02, max_acc 65.7, last_acc 65.7, mean_acc 59.3
# 	retrain #33, sparsity 0.32, final_train_loss 2.856e-01, max_acc 67.2, last_acc 63.7, mean_acc 60.2
# 	retrain #34, sparsity 0.33, final_train_loss 1.438e-01, max_acc 67.2, last_acc 65.3, mean_acc 60.6
# 	retrain #35, sparsity 0.34, final_train_loss 1.373e-01, max_acc 66.1, last_acc 66.1, mean_acc 60.2
# 	retrain #36, sparsity 0.35, final_train_loss 1.124e-01, max_acc 67.2, last_acc 65.6, mean_acc 60.7
# 	retrain #37, sparsity 0.36, final_train_loss 1.994e-01, max_acc 66.1, last_acc 65.7, mean_acc 59.5
# 	retrain #38, sparsity 0.37, final_train_loss 1.928e-01, max_acc 68.2, last_acc 66.2, mean_acc 61.1
# 	retrain #39, sparsity 0.38, final_train_loss 8.333e-02, max_acc 68.4, last_acc 67.9, mean_acc 61.2
# 	retrain #40, sparsity 0.39, final_train_loss 6.072e-02, max_acc 67.3, last_acc 66.8, mean_acc 60.4
# 	retrain #41, sparsity 0.40, final_train_loss 1.560e-01, max_acc 68.0, last_acc 67.9, mean_acc 62.0
# 	retrain #42, sparsity 0.41, final_train_loss 1.982e-01, max_acc 66.7, last_acc 66.1, mean_acc 60.1
# 	retrain #43, sparsity 0.42, final_train_loss 1.530e-01, max_acc 68.0, last_acc 66.4, mean_acc 60.9
# 	retrain #44, sparsity 0.43, final_train_loss 1.585e-01, max_acc 66.8, last_acc 66.3, mean_acc 60.4
# 	retrain #45, sparsity 0.44, final_train_loss 1.409e-01, max_acc 67.0, last_acc 64.4, mean_acc 60.8
# 	retrain #46, sparsity 0.45, final_train_loss 2.913e-01, max_acc 67.8, last_acc 65.4, mean_acc 60.9
# 	retrain #47, sparsity 0.46, final_train_loss 2.309e-01, max_acc 67.2, last_acc 65.4, mean_acc 61.0
# 	retrain #48, sparsity 0.47, final_train_loss 3.004e-01, max_acc 68.2, last_acc 67.2, mean_acc 62.0
# 	retrain #49, sparsity 0.48, final_train_loss 4.804e-02, max_acc 67.5, last_acc 67.5, mean_acc 60.5
# 	retrain #50, sparsity 0.49, final_train_loss 1.803e-01, max_acc 67.8, last_acc 66.1, mean_acc 61.4
# 	retrain #51, sparsity 0.51, final_train_loss 1.458e-01, max_acc 68.2, last_acc 68.1, mean_acc 62.0
# 	retrain #52, sparsity 0.52, final_train_loss 2.636e-01, max_acc 68.3, last_acc 65.5, mean_acc 61.4
# 	retrain #53, sparsity 0.53, final_train_loss 9.930e-02, max_acc 67.6, last_acc 66.3, mean_acc 61.8
# 	retrain #54, sparsity 0.54, final_train_loss 2.188e-02, max_acc 67.0, last_acc 65.5, mean_acc 60.8
# 	retrain #55, sparsity 0.55, final_train_loss 3.578e-02, max_acc 68.3, last_acc 67.2, mean_acc 61.6
# 	retrain #56, sparsity 0.56, final_train_loss 3.488e-01, max_acc 66.9, last_acc 63.4, mean_acc 60.5
# 	retrain #57, sparsity 0.57, final_train_loss 1.314e-01, max_acc 68.8, last_acc 68.8, mean_acc 62.0
# 	retrain #58, sparsity 0.58, final_train_loss 7.032e-02, max_acc 68.5, last_acc 68.0, mean_acc 62.0
# 	retrain #59, sparsity 0.59, final_train_loss 2.210e-01, max_acc 69.9, last_acc 66.4, mean_acc 62.4
# 	retrain #60, sparsity 0.60, final_train_loss 1.540e-02, max_acc 70.2, last_acc 70.2, mean_acc 61.7
# 	retrain #61, sparsity 0.61, final_train_loss 5.133e-02, max_acc 69.6, last_acc 67.9, mean_acc 62.6
# 	retrain #62, sparsity 0.62, final_train_loss 2.075e-01, max_acc 71.9, last_acc 66.4, mean_acc 63.3
# 	retrain #63, sparsity 0.63, final_train_loss 1.161e-01, max_acc 69.4, last_acc 66.3, mean_acc 62.3
# 	retrain #64, sparsity 0.64, final_train_loss 1.032e-01, max_acc 69.0, last_acc 67.7, mean_acc 62.6
# 	retrain #65, sparsity 0.65, final_train_loss 8.450e-02, max_acc 69.6, last_acc 68.0, mean_acc 62.4
# 	retrain #66, sparsity 0.66, final_train_loss 1.128e-01, max_acc 70.7, last_acc 70.7, mean_acc 63.4
# 	retrain #67, sparsity 0.67, final_train_loss 2.789e-02, max_acc 70.0, last_acc 69.2, mean_acc 63.8
# 	retrain #68, sparsity 0.68, final_train_loss 1.550e-01, max_acc 69.6, last_acc 66.5, mean_acc 62.7
# 	retrain #69, sparsity 0.69, final_train_loss 6.817e-02, max_acc 67.7, last_acc 67.7, mean_acc 62.4
# 	retrain #70, sparsity 0.70, final_train_loss 6.781e-02, max_acc 70.2, last_acc 69.1, mean_acc 63.3
# 	retrain #71, sparsity 0.71, final_train_loss 1.000e-01, max_acc 71.0, last_acc 68.0, mean_acc 64.3
# 	retrain #72, sparsity 0.72, final_train_loss 4.578e-02, max_acc 70.8, last_acc 70.3, mean_acc 64.4
# 	retrain #73, sparsity 0.73, final_train_loss 1.350e-01, max_acc 71.9, last_acc 69.6, mean_acc 64.8
# 	retrain #74, sparsity 0.74, final_train_loss 1.787e-02, max_acc 71.8, last_acc 68.5, mean_acc 65.2
# 	retrain #75, sparsity 0.75, final_train_loss 1.351e-03, max_acc 72.8, last_acc 72.8, mean_acc 64.5
# 	retrain #76, sparsity 0.76, final_train_loss 2.333e-02, max_acc 71.0, last_acc 70.8, mean_acc 64.4
# 	retrain #77, sparsity 0.77, final_train_loss 1.024e-01, max_acc 71.5, last_acc 71.0, mean_acc 65.5
# 	retrain #78, sparsity 0.78, final_train_loss 8.241e-02, max_acc 71.1, last_acc 70.8, mean_acc 65.3
# 	retrain #79, sparsity 0.79, final_train_loss 7.610e-02, max_acc 70.8, last_acc 70.8, mean_acc 64.0
# 	retrain #80, sparsity 0.80, final_train_loss 9.390e-02, max_acc 71.4, last_acc 70.2, mean_acc 64.5
# 	retrain #81, sparsity 0.81, final_train_loss 5.915e-02, max_acc 72.6, last_acc 70.1, mean_acc 65.8
# 	retrain #82, sparsity 0.82, final_train_loss 3.182e-02, max_acc 71.2, last_acc 69.7, mean_acc 65.3
# 	retrain #83, sparsity 0.83, final_train_loss 1.668e-02, max_acc 73.6, last_acc 73.6, mean_acc 65.6
# 	retrain #84, sparsity 0.84, final_train_loss 9.366e-03, max_acc 73.1, last_acc 73.1, mean_acc 66.4
# 	retrain #85, sparsity 0.85, final_train_loss 7.400e-03, max_acc 73.6, last_acc 73.0, mean_acc 67.1
# 	retrain #86, sparsity 0.86, final_train_loss 1.302e-01, max_acc 71.8, last_acc 69.0, mean_acc 66.1
# 	retrain #87, sparsity 0.87, final_train_loss 1.155e-01, max_acc 74.4, last_acc 74.4, mean_acc 66.5
# 	retrain #88, sparsity 0.88, final_train_loss 9.505e-02, max_acc 72.5, last_acc 70.9, mean_acc 65.7
# 	retrain #89, sparsity 0.89, final_train_loss 3.822e-02, max_acc 71.9, last_acc 71.9, mean_acc 66.1
# 	retrain #90, sparsity 0.90, final_train_loss 1.677e-01, max_acc 72.5, last_acc 72.5, mean_acc 66.0
# 	retrain #91, sparsity 0.91, final_train_loss 1.309e-01, max_acc 71.9, last_acc 70.3, mean_acc 65.6
# 	retrain #92, sparsity 0.92, final_train_loss 1.027e-01, max_acc 71.0, last_acc 69.4, mean_acc 65.0
# 	retrain #93, sparsity 0.93, final_train_loss 1.043e-01, max_acc 71.0, last_acc 67.5, mean_acc 64.8
# 	retrain #94, sparsity 0.94, final_train_loss 8.552e-02, max_acc 70.9, last_acc 66.9, mean_acc 64.3
# 	retrain #95, sparsity 0.95, final_train_loss 1.051e-01, max_acc 68.5, last_acc 68.1, mean_acc 63.2
# 	retrain #96, sparsity 0.96, final_train_loss 2.411e-01, max_acc 68.7, last_acc 68.7, mean_acc 62.8
# 	retrain #97, sparsity 0.97, final_train_loss 3.973e-01, max_acc 67.2, last_acc 67.0, mean_acc 61.6
# 	retrain #98, sparsity 0.98, final_train_loss 7.190e-01, max_acc 60.1, last_acc 58.6, mean_acc 54.0
# 	retrain #99, sparsity 0.99, final_train_loss 1.418e+00, max_acc 38.2, last_acc 38.1, mean_acc 34.2
# 	retrain #100, sparsity 1.00, final_train_loss 2.303e+00, max_acc 10.2, last_acc 10.2, mean_acc 10.2

# %%
to_pickle(trials, path='/content/lottery_with_xavier.pkl')

# %%
trials = from_pickle('/content/lottery_with_xavier.pkl')

# %%
def average_over(trials, trial_name, key):
    ys = [trials[trial_name][i][key] for i in range(len(trials[trial_name]))]
    return np.stack(ys).mean(0), np.stack(ys).std(0) / np.sqrt(len(ys))
x = sparsity_schedule
# Define colors and figure
rand_color, lott_color = 'r', 'b'
fig = plt.figure(figsize=[8, 3], dpi=200)

# Plotting Final Test Loss
plt.subplot(1, 2, 1)
for trial_name, color, label in zip(['rand_stats', 'lott_stats'], [rand_color, lott_color], ['random', 'lottery']):
    y, y_err = average_over(trials, trial_name, 'test_losses')
    y, y_err = y[:, -1], y_err[:, -1]
    plt.plot(x, y, '-', color=color, label=label)
    plt.fill_between(x, y - y_err, y + y_err, color=color, alpha=0.25)

plt.plot(x, np.ones_like(x) * y[0], 'k--', label='dense')
plt.xlabel('Sparsity')
plt.title('Final test loss')
plt.yscale('log')
plt.ylim(None, 5e0)
plt.legend(fontsize=7, ncol=3, loc='upper left')

# Plotting Final Test Accuracy
plt.subplot(1, 2, 2)
for trial_name, color, label in zip(['rand_stats', 'lott_stats'], [rand_color, lott_color], ['random', 'lottery']):
    y, y_err = average_over(trials, trial_name, 'test_accs')
    y, y_err = y[:, -1], y_err[:, -1]
    plt.plot(x, y, '-', color=color, label=label)
    plt.fill_between(x, y - y_err, y + y_err, color=color, alpha=0.25)

plt.plot(x, np.ones_like(x) * y[0], 'k--', label='dense')
plt.xlabel('Sparsity')
plt.title('Final test accuracy')
plt.ylim(55, 80)
plt.legend(fontsize=7, ncol=3, loc='upper left')

plt.show()
