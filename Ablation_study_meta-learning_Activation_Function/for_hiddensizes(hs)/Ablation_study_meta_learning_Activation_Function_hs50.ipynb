# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 50,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.4,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
hs_results_50 = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 1.6s, meta_grad_norm: 1.5e-01, mean_inner_loss: 1.363e+00, final_inner_loss: 1.406e+00, test_acc: 48.2
# step: 1, dt: 1.9s, meta_grad_norm: 4.0e-02, mean_inner_loss: 1.330e+00, final_inner_loss: 1.312e+00, test_acc: 51.6
# step: 2, dt: 2.4s, meta_grad_norm: 3.6e-02, mean_inner_loss: 1.318e+00, final_inner_loss: 1.296e+00, test_acc: 50.8
# step: 3, dt: 1.7s, meta_grad_norm: 2.9e-02, mean_inner_loss: 1.306e+00, final_inner_loss: 1.267e+00, test_acc: 52.0
, meta_grad_norm: 1.3e-03, mean_inner_loss: 1.077e+00, final_inner_loss: 1.042e+00, test_acc: 60.8
# step: 27, dt: 1.7s, meta_grad_norm: 3.9e-03, mean_inner_loss: 1.076e+00, final_inner_loss: 1.042e+00, test_acc: 60.6
# step: 28, dt: 1.7s, meta_grad_norm: 1.1e-03, mean_inner_loss: 1.077e+00, final_inner_loss: 1.044e+00, test_acc: 60.8
# step: 29, dt: 2.0s, meta_grad_norm: 9.3e-04, mean_inner_loss: 1.076e+00, final_inner_loss: 1.045e+00, test_acc: 61.0
# step: 30, dt: 2.1s, meta_grad_norm: 8.7e-04, mean_inner_loss: 1.076e+00, final_inner_loss: 1.045e+00, test_acc: 61.0
# step: 31, dt: 1.7s, meta_grad_norm: 9.1e-04, mean_inner_loss: 1.076e+00, final_inner_loss: 1.045e+00, test_acc: 60.8
# step: 32, dt: 1.7s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.075e+00, final_inner_loss: 1.046e+00, test_acc: 60.8
# step: 33, dt: 1.7s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.075e+00, final_inner_loss: 1.040e+00, test_acc: 60.6
# step: 34, dt: 1.7s, meta_grad_norm: 4.4e-03, mean_inner_loss: 1.075e+00, final_inner_loss: 1.044e+00, test_acc: 60.8
# step: 35, dt: 1.7s, meta_grad_norm: 8.1e-03, mean_inner_loss: 1.074e+00, final_inner_loss: 1.041e+00, test_acc: 60.6
# step: 36, dt: 2.1s, meta_grad_norm: 1.0e-03, mean_inner_loss: 1.074e+00, final_inner_loss: 1.043e+00, test_acc: 61.0
# step: 37, dt: 2.0s, meta_grad_norm: 1.5e-03, mean_inner_loss: 1.074e+00, final_inner_loss: 1.044e+00, test_acc: 61.0
# step: 38, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 1.073e+00, final_inner_loss: 1.039e+00, test_acc: 60.4
# step: 39, dt: 1.7s, meta_grad_norm: 4.9e-02, mean_inner_loss: 1.078e+00, final_inner_loss: 1.042e+00, test_acc: 60.4
# step: 40, dt: 1.7s, meta_grad_norm: 1.4e-03, mean_inner_loss: 1.074e+00, final_inner_loss: 1.029e+00, test_acc: 60.8
# step: 41, dt: 1.7s, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.074e+00, final_inner_loss: 1.040e+00, test_acc: 61.2
# step: 42, dt: 1.7s, meta_grad_norm: 2.8e-02, mean_inner_loss: 1.074e+00, final_inner_loss: 1.043e+00, test_acc: 60.4
# step: 43, dt: 2.0s, meta_grad_norm: 3.2e-03, mean_inner_loss: 1.073e+00, final_inner_loss: 1.030e+00, test_acc: 61.6
# step: 44, dt: 2.0s, meta_grad_norm: 9.6e-04, mean_inner_loss: 1.072e+00, final_inner_loss: 1.043e+00, test_acc: 60.8
# step: 45, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.072e+00, final_inner_loss: 1.042e+00, test_acc: 61.2
# step: 46, dt: 1.7s, meta_grad_norm: 3.0e-02, mean_inner_loss: 1.072e+00, final_inner_loss: 1.042e+00, test_acc: 60.4
# step: 47, dt: 1.7s, meta_grad_norm: 4.8e-03, mean_inner_loss: 1.073e+00, final_inner_loss: 1.025e+00, test_acc: 60.4
# step: 48, dt: 1.7s, meta_grad_norm: 1.0e-03, mean_inner_loss: 1.071e+00, final_inner_loss: 1.041e+00, test_acc: 60.6
# step: 49, dt: 1.8s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1
, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 1.020e+00, test_acc: 60.8
# step: 101, dt: 1.6s, meta_grad_norm: 1.1e-01, mean_inner_loss: 1.065e+00, final_inner_loss: 1.028e+00, test_acc: 62.0
# step: 102, dt: 1.9s, meta_grad_norm: 5.0e-02, mean_inner_loss: 1.064e+00, final_inner_loss: 9.955e-01, test_acc: 60.0
# step: 103, dt: 2.3s, meta_grad_norm: 9.2e-04, mean_inner_loss: 1.060e+00, final_inner_loss: 1.024e+00, test_acc: 60.8
# step: 104, dt: 2.0s, meta_grad_norm: 1.5e-03, mean_inner_loss: 1.060e+00, final_inner_loss: 1.025e+00, test_acc: 60.8
# step: 105, dt: 1.6s, meta_grad_norm: 2.7e-03, mean_inner_loss: 1.060e+00, final_inner_loss: 1.022e+00, test_acc: 60.6
# step: 106, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.060e+00, final_inner_loss: 1.022e+00, test_acc: 60.8
# step: 107, dt: 1.6s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.063e+00, final_inner_loss: 1.024e+00, test_acc: 61.4
# step: 108, dt: 1.7s, meta_grad_norm: 1.0e-03, mean_inner_loss: 1.059e+00, final_inner_loss: 1.022e+00, test_acc: 61.0
# step: 109, dt: 1.7s, meta_grad_norm: 3.3e-03, mean_inner_loss: 1.059e+00, final_inner_loss: 1.020e+00, test_acc: 61.2
# step: 110, dt: 1.8s, meta_grad_norm: 2.9e-02, mean_inner_loss: 1.060e+00, final_inner_loss: 1.020e+00, test_acc: 61.0
# step: 111, dt: 2.1s, meta_grad_norm: 4.5e-03, mean_inner_loss: 1.063e+00, final_inner_loss: 1.018e+00, test_acc: 60.8
# step: 112, dt: 1.6s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 1.018e+00, test_acc: 61.6
# step: 113, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.019e+00, test_acc: 60.8
# step: 114, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 1.021e+00, test_acc: 61.0
# step: 115, dt: 1.6s, meta_grad_norm: 1.2e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.019e+00, test_acc: 61.0
# step: 116, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 1.018e+00, test_acc: 62.0
# step: 117, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.019e+00, test_acc: 60.6
# step: 118, dt: 2.2s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 1.019e+00, test_acc: 61.2
# step: 119, dt: 1.7s, meta_grad_norm: 2.4e-03, mean_inner_loss: 1.058e+00, final_inner_loss: 1.020e+00, test_acc: 61.0
# step: 120, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.018e+00, test_acc: 60.8
# step: 121, dt: 1.7s, meta_grad_norm: 8.3e-02, mean_inner_loss: 1.062e+00, final_inner_loss: 1.025e+00, test_acc: 62.0
# step: 122, dt: 1.6s, meta_grad_norm: 1.7e-03, mean_inner_loss: 1.061e+00, final_inner_loss: 9.899e-01, test_acc: 60.8
# step: 123, dt: 1.7s, meta_grad_norm: 2.4e-02, mean_inner_loss: 1.061e+00, final_inner_loss: 9.967e-01, test_acc: 60.6
# step: 124, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 1.076e+00, final_inner_loss: 1.003e+00, test_acc: 57.4
# step: 125, dt: 2.2s, meta_grad_norm: 1.1e-01, mean_inner_loss: 1.081e+00, final_inner_loss: 9.893e-01, test_acc: 58.2
# step: 126, dt: 1.8s, meta_grad_norm: 1.2e-02, mean_inner_loss: 1.060e+00, final_inner_loss: 1.017e+00, test_acc: 61.2
# step: 127, dt: 1.6s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.057e+00, final_inner_loss: 1.019e+00, test_acc: 61.0
# step: 128, dt: 1.7s, meta_grad_norm: 1.7e-03, mean_inner_loss: 1.057e+00, final_inner_loss: 1.019e+00, test_acc: 61.8
# step: 129, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.057e+00, final_inner_loss: 1.018e+00, test_acc: 60.8
# step: 130, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.012e+00, test_acc: 61.6
# step: 131, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 1.057e+00, final_inner_loss: 1.018e+00, test_acc: 60.8
# step: 132, dt: 2.3s, meta_grad_norm: 9.0e-03, mean_inner_loss: 1.059e+00, final_inner_loss: 1.011e+00, test_acc: 61.6
# step: 133, dt: 1.9s, meta_grad_norm: 4.5e-03, mean_inner_loss: 1.057e+00, final_inner_loss: 1.018e+00, test_acc: 60.8
# step: 134, dt: 1.8s, meta_grad_norm: 2.5e-02, mean_inner_loss: 1.058e+00, final_inner_loss: 1.016e+00, test_acc: 61.8
# step: 135, dt: 1.7s, meta_grad_norm: 9.7e-02, mean_inner_loss: 1.062e+00, final_inner_loss: 1.027e+00, test_acc: 62.0
# step: 136, dt: 1.7s, meta_grad_norm: 2.4e-03, mean_inner_loss: 1.059e+00, final_inner_loss: 9.869e-01, test_acc: 60.2
# step: 137, dt: 1.7s, meta_grad_norm: 2.8e-03, mean_inner_loss: 1.058e+00, final_inner_loss: 9.831e-01, test_acc: 60.6
# step: 138, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 9.865e-01, test_acc: 60.0
# step: 139, dt: 2.2s, meta_grad_norm: 5.7e-03, mean_inner_loss: 1.058e+00, final_inner_loss: 1.010e+00, test_acc: 61.6
# step: 140, dt: 1.8s, meta_grad_norm: 3.9e-03, mean_inner_loss: 1.056e+00, final_inner_loss: 1.015e+00, test_acc: 61.6
# step: 141, dt: 1.7s, meta_grad_norm: 8.7e-03, mean_inner_loss: 1.057e+00, final_inner_loss: 1.012e+00, test_acc: 61.0
# step: 142, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 1.057e+00, final_inner_loss: 1.018e+00, test_acc: 61.6
# step: 143, dt: 1.7s, meta_grad_norm: 5.6e-03, mean_inner_loss: 1.057e+00, final_inner_loss: 1.009e+00, test_acc: 61.6
# step: 144, dt: 2.1s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.055e+00, final_inner_loss: 1.015e+00, test_acc: 61.4
# step: 145, dt: 1.8s, meta_grad_norm: 1.6e-02, mean_inner_loss: 1.056e+00, final_inner_loss: 1.012e+00, test_acc: 61.8
# step: 146, dt: 2.2s, meta_grad_norm: 8.1e-02, mean_inner_loss: 1.058e+00, final_inner_loss: 1.013e+00, test_acc: 60.2
# step: 147, dt: 1.6s, meta_grad_norm: 2.8e-03, mean_inner_loss: 1.057e+00, final_inner_loss: 9.818e-01, test_acc: 60.6
# step: 148, dt: 1.7s, meta_grad_norm: 1.5e-03, mean_inner_loss: 1
, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.054e+00, final_inner_loss: 9.795e-01, test_acc: 61.4
# step: 173, dt: 1.6s, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.054e+00, final_inner_loss: 1.008e+00, test_acc: 61.4
# step: 174, dt: 2.0s, meta_grad_norm: 7.2e-02, mean_inner_loss: 1.055e+00, final_inner_loss: 1.014e+00, test_acc: 60.4
# step: 175, dt: 1.8s, meta_grad_norm: 3.5e-03, mean_inner_loss: 1.054e+00, final_inner_loss: 9.834e-01, test_acc: 60.4
# step: 176, dt: 1.6s, meta_grad_norm: 3.1e-02, mean_inner_loss: 1.054e+00, final_inner_loss: 9.862e-01, test_acc: 61.0
# step: 177, dt: 1.6s, meta_grad_norm: 1.3e-02, mean_inner_loss: 1.070e+00, final_inner_loss: 9.826e-01, test_acc: 58.0
# step: 178, dt: 1.6s, meta_grad_norm: 4.6e-01, mean_inner_loss: 1.076e+00, final_inner_loss: 9.719e-01, test_acc: 58.2
# step: 179, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.064e+00, final_inner_loss: 1.027e+00, test_acc: 62.0
# step: 180, dt: 1.6s, meta_grad_norm: 4.3e-02, mean_inner_loss: 1.057e+00, final_inner_loss: 1.022e+00, test_acc: 61.8
# step: 181, dt: 1.9s, meta_grad_norm: 5.0e-04, mean_inner_loss: 1.054e+00, final_inner_loss: 1.005e+00, test_acc: 61.2
# step: 182, dt: 1.9s, meta_grad_norm: 7.4e-04, mean_inner_loss: 1.054e+00, final_inner_loss: 1.006e+00, test_acc: 61.2
# step: 183, dt: 1.7s, meta_grad_norm: 4.4e-03, mean_inner_loss: 1.053e+00, final_inner_loss: 1.008e+00, test_acc: 61.0
# step: 184, dt: 1.6s, meta_grad_norm: 1.1e-03, mean_inner_loss: 1.051e+00, final_inner_loss: 1.012e+00, test_acc: 61.8
# step: 185, dt: 1.6s, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.052e+00, final_inner_loss: 1.012e+00, test_acc: 62.0
# step: 186, dt: 1.6s, meta_grad_norm: 9.8e-02, mean_inner_loss: 1.056e+00, final_inner_loss: 1.016e+00, test_acc: 60.6
# step: 187, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 1.053e+00, final_inner_loss: 9.809e-01, test_acc: 60.6
# step: 188, dt: 1.8s, meta_grad_norm: 1.1e+00, mean_inner_loss: 1.068e+00, final_inner_loss: 9.798e-01, test_acc: 58.4
# step: 189, dt: 2.0s, meta_grad_norm: 1.6e-01, mean_inner_loss: 1.091e+00, final_inner_loss: 1.061e+00, test_acc: 62.4
# step: 190, dt: 1.6s, meta_grad_norm: 8.9e-03, mean_inner_loss: 1.063e+00, final_inner_loss: 1.030e+00, test_acc: 61.8
# step: 191, dt: 1.6s, meta_grad_norm: 2.8e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.028e+00, test_acc: 62.2
# step: 192, dt: 1.6s, meta_grad_norm: 1.6e-03, mean_inner_loss: 1.051e+00, final_inner_loss: 1.019e+00, test_acc: 61.4
# step: 193, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 1.052e+00, final_inner_loss: 1.018e+00, test_acc: 61.6
# step: 194, dt: 1.6s, meta_grad_norm: 3.0e-02, mean_inner_loss: 1.056e+00, final_inner_loss: 1.024e+00, test_acc: 62.0
# step: 195, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 1.052e+00, final_inner_loss: 1.019e+00, test_acc: 62.2
# step: 196, dt: 2.1s, meta_grad_norm: 8.2e-03, mean_inner_loss: 1.051e+00, final_inner_loss: 1.016e+00, test_acc: 60.8
# step: 197, dt: 1.6s, meta_grad_norm: 2.2e-02, mean_inner_loss: 1.051e+00, final_inner_loss: 1.016e+00, test_acc: 62.0
# step: 198, dt: 1.6s, meta_grad_norm: 7.7e-02, mean_inner_loss: 1.055e+00, final_inner_loss: 1.023e+00, test_acc: 61.4
# step: 199, dt: 1.6s, meta_grad_norm: 7.7e-03, mean_inner_loss: 1.052e+00, final_inner_loss: 9.847e-01, test_acc: 61.4
# step: 200, dt: 1.6s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.052e+00, final_inner_loss: 9.792e-01, test_acc: 60.2
# step: 201, dt: 1.6s, meta_grad_norm: 7.2e-04, mean_inner_loss: 1.052e+00, final_inner_loss: 9.799e-01, test_acc: 60.4
# step: 202, dt: 1.6s, meta_grad_norm: 4.1e-03, mean_inner_loss: 1.052e+00, final_inner_loss: 9.757e-01, test_acc: 60.4
# step: 203, dt: 2.2s, meta_grad_norm: 2.9e-02, mean_inner_loss: 1.053e+00, final_inner_loss: 9.755e-01, test_acc: 60.0
# step: 204, dt: 1.7s, meta_grad_norm: 1.6e-03, mean_inner_loss: 1.051e+00, final_inner_loss: 1.012e+00, test_acc: 60.8
# step: 205, dt: 1.6s, meta_grad_norm: 8.6e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 9.964e-01, test_acc: 61.2
# step: 206, dt: 1.6s, meta_grad_norm: 7.0e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 1.004e+00, test_acc: 61.0
# step: 207, dt: 1.6s, meta_grad_norm: 7.9e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 9.958e-01, test_acc: 61.0
# step: 208, dt: 1.7s, meta_grad_norm: 7.1e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 9.966e-01, test_acc: 61.0
# step: 209, dt: 1.6s, meta_grad_norm: 7.9e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 9.899e-01, test_acc: 61.8
# step: 210, dt: 2.1s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.050e+00, final_inner_loss: 9.795e-01, test_acc: 60.8
# step: 211, dt: 1.8s, meta_grad_norm: 7.9e-02, mean_inner_loss: 1.052e+00, final_inner_loss: 9.763e-01, test_acc: 60.2
# step: 212, dt: 1.6s, meta_grad_norm: 6.3e-03, mean_inner_loss: 1.049e+00, final_inner_loss: 1.014e+00, test_acc: 62.2
# step: 213, dt: 1.6s, meta_grad_norm: 1.5e-02, mean_inner_loss: 1.050e+00, final_inner_loss: 1.010e+00, test_acc: 60.2
# step: 214, dt: 1.6s, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.050e+00, final_inner_loss: 1.020e+00, test_acc: 61.6
# step: 215, dt: 1.6s, meta_grad_norm: 4.6e-04, mean_inner_loss: 1.051e+00, final_inner_loss: 1.009e+00, test_acc: 60.8
# step: 216, dt: 1.6s, meta_grad_norm: 1.2e-03, mean_inner_loss: 1
# step: 240, dt: 1.6s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.063e+00, final_inner_loss: 9.767e-01, test_acc: 58.8
# step: 241, dt: 1.6s, meta_grad_norm: 6.5e-04, mean_inner_loss: 1.063e+00, final_inner_loss: 9.781e-01, test_acc: 58.0
# step: 242, dt: 1.6s, meta_grad_norm: 4.0e-03, mean_inner_loss: 1.063e+00, final_inner_loss: 9.825e-01, test_acc: 58.2
# step: 243, dt: 1.6s, meta_grad_norm: 3.4e-01, mean_inner_loss: 1.049e+00, final_inner_loss: 9.822e-01, test_acc: 60.8
# step: 244, dt: 1.6s, meta_grad_norm: 5.8e-03, mean_inner_loss: 1.059e+00, final_inner_loss: 1.020e+00, test_acc: 62.4
# step: 245, dt: 1.6s, meta_grad_norm: 5.9e-03, mean_inner_loss: 1.056e+00, final_inner_loss: 1.021e+00, test_acc: 62.0
# step: 246, dt: 2.1s, meta_grad_norm: 9.8e-03, mean_inner_loss: 1.054e+00, final_inner_loss: 1.018e+00, test_acc: 61.4
# step: 247, dt: 1.7s, meta_grad_norm: 4.3e-02, mean_inner_loss: 1.049e+00, final_inner_loss: 1.008e+00, test_acc: 60.4
# step: 248, dt: 1.6s, meta_grad_norm: 9.4e-04, mean_inner_loss: 1.049e+00, final_inner_loss: 1.000e+00, test_acc: 61.2
# step: 249, dt: 1.6s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.048e+00, final_inner_loss: 9.939e-01, test_acc: 60.6
# step: 250, dt: 1.7s, meta_grad_norm: 1.0e-03, mean_inner_loss: 1.048e+00, final_inner_loss: 9.858e-01, test_acc: 60.2
# step: 251, dt: 1.6s, meta_grad_norm: 1.9e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 9.927e-01, test_acc: 60.4
# step: 252, dt: 1.7s, meta_grad_norm: 3.9e-03, mean_inner_loss: 1.047e+00, final_inner_loss: 1.010e+00, test_acc: 60.4
# step: 253, dt: 2.1s, meta_grad_norm: 3.2e-04, mean_inner_loss: 1.046e+00, final_inner_loss: 1.008e+00, test_acc: 60.8
# step: 254, dt: 1.9s, meta_grad_norm: 3.9e-04, mean_inner_loss: 1.046e+00, final_inner_loss: 1.008e+00, test_acc: 60.8
# step: 255, dt: 1.7s, meta_grad_norm: 2.2e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.005e+00, test_acc: 60.8
# step: 256, dt: 1.7s, meta_grad_norm: 2.3e-04, mean_inner_loss: 1.046e+00, final_inner_loss: 1.007e+00, test_acc: 62.0
# step: 257, dt: 1.7s, meta_grad_norm: 2.7e-04, mean_inner_loss: 1.046e+00, final_inner_loss: 1.007e+00, test_acc: 62.0
# step: 258, dt: 1.7s, meta_grad_norm: 2.9e-04, mean_inner_loss: 1.046e+00, final_inner_loss: 1.007e+00, test_acc: 62.0
# step: 259, dt: 1.6s, meta_grad_norm: 1.3e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.008e+00, test_acc: 61.6
# step: 260, dt: 2.2s, meta_grad_norm: 7.8e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.008e+00, test_acc: 62.4
# step: 261, dt: 1.9s, meta_grad_norm: 4.4e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.003e+00, test_acc: 60.4
# step: 262, dt: 1.7s, meta_grad_norm: 1.2e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.006e+00, test_acc: 62.0
# step: 263, dt: 1.8s, meta_grad_norm: 8.7e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.008e+00, test_acc: 62.2
# step: 264, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.046e+00, final_inner_loss: 1.002e+00, test_acc: 60.6
# step: 265, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 1.007e+00, test_acc: 61.8
# step: 266, dt: 1.7s, meta_grad_norm: 2.8e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 1.003e+00, test_acc: 60.4
# step: 267, dt: 2.2s, meta_grad_norm: 3.0e-02, mean_inner_loss: 1.048e+00, final_inner_loss: 1.007e+00, test_acc: 60.4
# step: 268, dt: 1.9s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 1.003e+00, test_acc: 60.8
# step: 269, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.046e+00, final_inner_loss: 1.009e+00, test_acc: 62.0
# step: 270, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 1.001e+00, test_acc: 60.8
# step: 271, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 1.046e+00, final_inner_loss: 1.009e+00, test_acc: 61.6
# step: 272, dt: 1.7s, meta_grad_norm: 9.7e-03, mean_inner_loss: 1.046e+00, final_inner_loss: 1.003e+00, test_acc: 60.6
# step: 273, dt: 1.7s, meta_grad_norm: 1.1e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 1.008e+00, test_acc: 61.4
# step: 274, dt: 2.2s, meta_grad_norm: 1.4e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.003e+00, test_acc: 60.4
# step: 275, dt: 1.8s, meta_grad_norm: 2.6e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.002e+00, test_acc: 60.2
# step: 276, dt: 1.7s, meta_grad_norm: 1.8e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.003e+00, test_acc: 60.8
# step: 277, dt: 1.7s, meta_grad_norm: 1.0e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 1.005e+00, test_acc: 61.8
# step: 278, dt: 1.7s, meta_grad_norm: 6.7e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 1.009e+00, test_acc: 62.0
# step: 279, dt: 1.7s, meta_grad_norm: 2.2e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 9.976e-01, test_acc: 61.2
# step: 280, dt: 1.8s, meta_grad_norm: 3.8e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.005e+00, test_acc: 60.8
# step: 281, dt: 2.2s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.008e+00, test_acc: 61.4
# step: 282, dt: 1.7s, meta_grad_norm: 5.1e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.005e+00, test_acc: 60.6
# step: 283, dt: 1.7s, meta_grad_norm: 2.1e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.986e-01, test_acc: 60.2
# step: 284, dt: 1.7s, meta_grad_norm: 2.5e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.968e-01, test_acc: 60.8
# step: 285, dt: 1.7s, meta_grad_norm: 5.5e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.959e-01, test_acc: 60.8
# step: 286, dt: 1.7s, meta_grad_norm: 3.9e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.996e-01, test_acc: 60.2
# step: 287, dt: 1.8s, meta_grad_norm: 2.0e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.957e-01, test_acc: 60.8
# step: 288, dt: 2.2s, meta_grad_norm: 3.5e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 9.960e-01, test_acc: 60.4
# step: 289, dt: 1.7s, meta_grad_norm: 3.8e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 9.952e-01, test_acc: 61.2
# step: 290, dt: 1.7s, meta_grad_norm: 1.3e-04, mean_inner_loss: 1.045e+00, final_inner_loss: 1.008e+00, test_acc: 61.2
# step: 291, dt: 1.7s, meta_grad_norm: 2.3e-04, mean_inner_loss: 1.044e+00, final_inner_loss: 1.008e+00, test_acc: 61.4
# step: 292, dt: 1.7s, meta_grad_norm: 5.5e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 1.006e+00, test_acc: 60.8
# step: 293, dt: 1.6s, meta_grad_norm: 1.3e-02, mean_inner_loss: 1.046e+00, final_inner_loss: 1.007e+00, test_acc: 61.2
# step: 294, dt: 1.8s, meta_grad_norm: 8.3e-04, mean_inner_loss: 1.044e+00, final_inner_loss: 9.976e-01, test_acc: 60.6
# step: 295, dt: 2.2s, meta_grad_norm: 8.8e-03, mean_inner_loss: 1.045e+00, final_inner_loss: 9.941e-01, test_acc: 61.4
# step: 296, dt: 1.7s, meta_grad_norm: 3.4e-03, mean_inner_loss: 1.044e+00, final_inner_loss: 1.009e+00, test_acc: 61.8
# step: 297, dt: 1.7s, meta_grad_norm: 5.0e-04, mean_inner_loss: 1.044e+00, final_inner_loss: 9.992e-01, test_acc: 59.8
# step: 298, dt: 1.7s, meta_grad_norm: 2.7e-04, mean_inner_loss: 1.044e+00, final_inner_loss: 9.943e-01, test_acc: 60.6
# step: 299, dt: 1.7s, meta_grad_norm: 1.5e-03, mean_inner_loss: 1.044e+00, final_inner_loss: 9.955e-01, test_acc: 60.6
# step: 300, dt: 1.7s, meta_grad_norm: 3.0e-02, mean_inner_loss: 1.045e+00, final_inner_loss: 9.978e-01, test_acc: 61.0

# %%
import pickle

# Save results using pickle
with open('hs_results_50.pkl', 'wb') as f:
    pickle.dump(hs_results_50, f)

print("Results saved to 'hs_results_50.pkl'")
# Out:
# Results saved to 'hs_results_50.pkl'

# %%
# Load results from pickle file
with open('hs_results_50.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
hs_results_50['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    hs_results_50['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(hs_results_50['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 1.0702672709658296
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.4871613, 1.4558675, 1.5073454, 1.615674, 1.5847273, 1.7372775]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(hs_results_50, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 59.6
