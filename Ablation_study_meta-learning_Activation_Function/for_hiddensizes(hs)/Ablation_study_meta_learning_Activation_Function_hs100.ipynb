# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 100,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.4,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
hs_results_100 = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 2.8s, meta_grad_norm: 8.5e-02, mean_inner_loss: 1.350e+00, final_inner_loss: 1.358e+00, test_acc: 49.0
# step: 1, dt: 1.8s, meta_grad_norm: 1.6e-01, mean_inner_loss: 1.325e+00, final_inner_loss: 1.308e+00, test_acc: 49.6
# step: 2, dt: 2.2s, meta_grad_norm: 4.2e-02, mean_inner_loss: 1.299e+00, final_inner_loss: 1.268e+00, test_acc: 50.8
# step: 3, dt: 1.7s, meta_grad_norm: 5.8e-02, mean_inner_loss: 1.285e+00, final_inner_loss: 1.257e+00, test_acc: 51.4
# step: 90, dt: 1.9s, meta_grad_norm: 3.2e-02, mean_inner_loss: 9.938e-01, final_inner_loss: 8.834e-01, test_acc: 62.8
# step: 91, dt: 1.8s, meta_grad_norm: 1.3e-01, mean_inner_loss: 9.765e-01, final_inner_loss: 8.214e-01, test_acc: 64.2
# step: 92, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.997e-01, final_inner_loss: 8.703e-01, test_acc: 64.2
# step: 93, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.948e-01, final_inner_loss: 8.772e-01, test_acc: 62.2
# step: 94, dt: 1.7s, meta_grad_norm: 5.2e-02, mean_inner_loss: 9.881e-01, final_inner_loss: 8.781e-01, test_acc: 65.0
# step: 95, dt: 1.7s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.854e-01, final_inner_loss: 8.006e-01, test_acc: 62.2
# step: 96, dt: 2.2s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.950e-01, final_inner_loss: 8.902e-01, test_acc: 63.2
# step: 97, dt: 1.9s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.892e-01, final_inner_loss: 8.793e-01, test_acc: 64.4
# step: 98, dt: 1.8s, meta_grad_norm: 4.0e-03, mean_inner_loss: 9.817e-01, final_inner_loss: 8.014e-01, test_acc: 64.2
# step: 99, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 9.743e-01, final_inner_loss: 8.150e-01, test_acc: 65.8
# step: 100, dt: 1.7s, meta_grad_norm: 9.8e-03, mean_inner_loss: 9.999e-01, final_inner_loss: 8.622e-01, test_acc: 64.2
# step: 101, dt: 1.7s, meta_grad_norm: 2.9e-02, mean_inner_loss: 9.965e-01, final_inner_loss: 8.539e-01, test_acc: 64.0
# step: 102, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.904e-01, final_inner_loss: 8.671e-01, test_acc: 63.2
# step: 103, dt: 2.2s, meta_grad_norm: 8.2e-02, mean_inner_loss: 9.836e-01, final_inner_loss: 8.692e-01, test_acc: 64.4
# step: 104, dt: 1.8s, meta_grad_norm: 3.1e-01, mean_inner_loss: 9.882e-01, final_inner_loss: 8.172e-01, test_acc: 62.2
# step: 105, dt: 1.7s, meta_grad_norm: 2.7e-02, mean_inner_loss: 9.949e-01, final_inner_loss: 8.527e-01, test_acc: 63.6
# step: 106, dt: 1.7s, meta_grad_norm: 3.3e-02, mean_inner_loss: 9.893e-01, final_inner_loss: 8.726e-01, test_acc: 63.4
# step: 107, dt: 1.7s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.746e-01, final_inner_loss: 8.476e-01, test_acc: 63.2
# step: 108, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.977e-01, final_inner_loss: 9.126e-01, test_acc: 61.8
# step: 109, dt: 1.7s, meta_grad_norm: 4.8e-03, mean_inner_loss: 9.938e-01, final_inner_loss: 8.616e-01, test_acc: 63.0
# step: 110, dt: 2.2s, meta_grad_norm: 7.5e-02, mean_inner_loss: 9.925e-01, final_inner_loss: 8.639e-01, test_acc: 61.8
# step: 111, dt: 1.8s, meta_grad_norm: 2.1e-01, mean_inner_loss: 9.712e-01, final_inner_loss: 8.503e-01, test_acc: 64.0
# step: 112, dt: 1.7s, meta_grad_norm: 5.4e-02, mean_inner_loss: 1.000e+00, final_inner_loss: 9.335e-01, test_acc: 62.0
# step: 113, dt: 1.7s, meta_grad_norm: 1.9e-01, mean_inner_loss: 9.870e-01, final_inner_loss: 8.330e-01, test_acc: 61.8
# step: 114, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.871e-01, final_inner_loss: 8.783e-01, test_acc: 64.0
# step: 115, dt: 1.7s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.801e-01, final_inner_loss: 8.703e-01, test_acc: 65.0
# step: 116, dt: 1.7s, meta_grad_norm: 3.1e-02, mean_inner_loss: 9.915e-01, final_inner_loss: 8.532e-01, test_acc: 62.2
# step: 117, dt: 2.2s, meta_grad_norm: 3.0e-01, mean_inner_loss: 9.717e-01, final_inner_loss: 8.021e-01, test_acc: 64.2
# step: 118, dt: 1.8s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.945e-01, final_inner_loss: 8.504e-01, test_acc: 64.2
# step: 119, dt: 1.7s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.895e-01, final_inner_loss: 8.664e-01, test_acc: 63.8
# step: 120, dt: 1.7s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.839e-01, final_inner_loss: 8.656e-01, test_acc: 64.0
# step: 121, dt: 1.7s, meta_grad_norm: 7.8e-02, mean_inner_loss: 9.743e-01, final_inner_loss: 8.557e-01, test_acc: 63.8
# step: 122, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 9.837e-01, final_inner_loss: 8.122e-01, test_acc: 61.8
# step: 123, dt: 1.7s, meta_grad_norm: 3.2e-02, mean_inner_loss: 9.854e-01, final_inner_loss: 8.814e-01, test_acc: 63.8
# step: 124, dt: 2.2s, meta_grad_norm: 5.2e-02, mean_inner_loss: 9.762e-01, final_inner_loss: 8.656e-01, test_acc: 65.2
# step: 125, dt: 1.8s, meta_grad_norm: 9.2e-02, mean_inner_loss: 9.726e-01, final_inner_loss: 7.990e-01, test_acc: 63.4
# step: 126, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.801e-01, final_inner_loss: 8.617e-01, test_acc: 63.6
# step: 127, dt: 1.7s, meta_grad_norm: 4.1e-02, mean_inner_loss: 9.734e-01, final_inner_loss: 8.570e-01, test_acc: 64.8
# step: 128, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.708e-01, final_inner_loss: 7.986e-01, test_acc: 63.8
# step: 129, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.852e-01, final_inner_loss: 8.663e-01, test_acc: 63.6
# step: 130, dt: 1.8s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.788e-01, final_inner_loss: 8.649e-01, test_acc: 64.6
# step: 131, dt: 2.2s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.702e-01, final_inner_loss: 8.460e-01, test_acc: 65.0
# step: 132, dt: 1.7s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.885e-01, final_inner_loss: 8.441e-01, test_acc: 63.4
# step: 133, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 9.686e-01, final_inner_loss: 8.383e-01, test_acc: 65.0
# step: 134, dt: 1.7s, meta_grad_norm: 3.0e-01, mean_inner_loss: 9.915e-01, final_inner_loss: 8.961e-01, test_acc: 63.0
# step: 135, dt: 1.7s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.699e-01, final_inner_loss: 8.812e-01, test_acc: 66.0
# step: 136, dt: 1.7s, meta_grad_norm: 3.5e-01, mean_inner_loss: 9.592e-01, final_inner_loss: 7.958e-01, test_acc: 65.2
# step: 137, dt: 1.9s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.865e-01, final_inner_loss: 8.705e-01, test_acc: 62.8
# step: 138, dt: 2.2s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.810e-01, final_inner_loss: 8.928e-01, test_acc: 64.8
# step: 139, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.750e-01, final_inner_loss: 8.767e-01, test_acc: 65.4
# step: 140, dt: 1.7s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.702e-01, final_inner_loss: 8.692e-01, test_acc: 65.0
# step: 141, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.539e-01, final_inner_loss: 7.921e-01, test_acc: 64.8
# step: 142, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.575e-01, final_inner_loss: 7.951e-01, test_acc: 64.2
# step: 143, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.778e-01, final_inner_loss: 8.661e-01, test_acc: 64.6
# step: 144, dt: 1.9s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.718e-01, final_inner_loss: 8.657e-01, test_acc: 65.0
# step: 145, dt: 2.0s, meta_grad_norm: 9.2e-02, mean_inner_loss: 9.638e-01, final_inner_loss: 8.339e-01, test_acc: 65.8
# step: 146, dt: 1.7s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.689e-01, final_inner_loss: 7.733e-01, test_acc: 62.4
# step: 147, dt: 1.7s, meta_grad_norm: 7.2e-02, mean_inner_loss: 9.543e-01, final_inner_loss: 7.969e-01, test_acc: 64.8
# step: 148, dt: 1.7s, meta_grad_norm: 4.2e-01, mean_inner_loss: 9.771e-01, final_inner_loss: 8.037e-01, test_acc: 61.8
# step: 149, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.781e-01, final_inner_loss: 8.757e-01, test_acc: 63.4
# step: 150, dt: 1.7s, meta_grad_norm: 2.9e-02, mean_inner_loss: 9.721e-01, final_inner_loss: 8.798e-01, test_acc: 64.0
# step: 151, dt: 1.9s, meta_grad_norm: 7.9e-02, mean_inner_loss: 9.633e-01, final_inner_loss: 8.486e-01, test_acc: 66.0
# step: 152, dt: 2.0s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.644e-01, final_inner_loss: 7.832e-01, test_acc: 63.8
# step: 153, dt: 1.7s, meta_grad_norm: 8.7e-02, mean_inner_loss: 9.686e-01, final_inner_loss: 8.658e-01, test_acc: 66.0
# step: 154, dt: 1.7s, meta_grad_norm: 2.8e-01, mean_inner_loss: 9.547e-01, final_inner_loss: 7.929e-01, test_acc: 64.8
# step: 155, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.758e-01, final_inner_loss: 8.461e-01, test_acc: 62.4
# step: 156, dt: 1.7s, meta_grad_norm: 4.3e-02, mean_inner_loss: 9.723e-01, final_inner_loss: 8.616e-01, test_acc: 64.0
# step: 157, dt: 1.7s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.605e-01, final_inner_loss: 8.360e-01, test_acc: 65.2
# step: 158, dt: 2.0s, meta_grad_norm: 3.6e-01, mean_inner_loss: 9.568e-01, final_inner_loss: 7.939e-01, test_acc: 63.6
# step: 159, dt: 2.0s, meta_grad_norm: 4.0e-02, mean_inner_loss: 9.780e-01, final_inner_loss: 8.538e-01, test_acc: 61.8
# step: 160, dt: 1.8s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.690e-01, final_inner_loss: 8.701e-01, test_acc: 65.6
# step: 161, dt: 1.7s, meta_grad_norm: 5.2e-02, mean_inner_loss: 9.632e-01, final_inner_loss: 8.678e-01, test_acc: 66.2
# step: 162, dt: 1.7s, meta_grad_norm: 3.3e-02, mean_inner_loss: 9.492e-01, final_inner_loss: 8.006e-01, test_acc: 65.2
# step: 163, dt: 1.7s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.606e-01, final_inner_loss: 8.577e-01, test_acc: 65.6
# step: 164, dt: 1.7s, meta_grad_norm: 4.6e-03, mean_inner_loss: 9.465e-01, final_inner_loss: 7.943e-01, test_acc: 65.0
# step: 165, dt: 1.9s, meta_grad_norm: 9.3e-02, mean_inner_loss: 9.483e-01, final_inner_loss: 7.803e-01, test_acc: 66.0
# step: 166, dt: 2.0s, meta_grad_norm: 2.5e-01, mean_inner_loss: 9.794e-01, final_inner_loss: 8.074e-01, test_acc: 62.4
# step: 167, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.646e-01, final_inner_loss: 8.640e-01, test_acc: 66.2
# step: 168, dt: 1.7s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.539e-01, final_inner_loss: 8.159e-01, test_acc: 65.4
# step: 169, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.806e-01, final_inner_loss: 8.157e-01, test_acc: 61.2
# step: 170, dt: 1.7s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.519e-01, final_inner_loss: 8.095e-01, test_acc: 65.4
# step: 171, dt: 1.7s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.829e-01, final_inner_loss: 8.512e-01, test_acc: 61.8
# step: 172, dt: 2.1s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.764e-01, final_inner_loss: 7.982e-01, test_acc: 62.4
# step: 173, dt: 2.0s, meta_grad_norm: 7.4e-02, mean_inner_loss: 9.600e-01, final_inner_loss: 8.447e-01, test_acc: 66.0
# step: 174, dt: 1.7s, meta_grad_norm: 5.6e-01, mean_inner_loss: 9.504e-01, final_inner_loss: 7.956e-01, test_acc: 63.8
# step: 175, dt: 1.8s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.813e-01, final_inner_loss: 8.487e-01, test_acc: 63.6
# step: 176, dt: 1.7s, meta_grad_norm: 4.1e-02, mean_inner_loss: 9.743e-01, final_inner_loss: 8.441e-01, test_acc: 61.0
# step: 177, dt: 1.8s, meta_grad_norm: 2.7e-02, mean_inner_loss: 9.652e-01, final_inner_loss: 8.563e-01, test_acc: 63.8
# step: 178, dt: 1.7s, meta_grad_norm: 5.0e-02, mean_inner_loss: 9.560e-01, final_inner_loss: 8.456e-01, test_acc: 66.4
# step: 179, dt: 2.2s, meta_grad_norm: 3.3e-02, mean_inner_loss: 9.449e-01, final_inner_loss: 7.789e-01, test_acc: 65.0
# step: 180, dt: 1.9s, meta_grad_norm: 7.9e-02, mean_inner_loss: 9.533e-01, final_inner_loss: 8.263e-01, test_acc: 65.8
# step: 181, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 9.568e-01, final_inner_loss: 7.705e-01, test_acc: 64.0
# step: 182, dt: 1.8s, meta_grad_norm: 5.9e-03, mean_inner_loss: 9.473e-01, final_inner_loss: 7.965e-01, test_acc: 65.8
# step: 183, dt: 1.8s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.447e-01, final_inner_loss: 7.820e-01, test_acc: 65.6
# step: 184, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 9.598e-01, final_inner_loss: 7.552e-01, test_acc: 63.0
# step: 185, dt: 1.7s, meta_grad_norm: 9.9e-02, mean_inner_loss: 9.551e-01, final_inner_loss: 8.357e-01, test_acc: 66.8
# step: 186, dt: 2.2s, meta_grad_norm: 5.2e-01, mean_inner_loss: 9.584e-01, final_inner_loss: 7.812e-01, test_acc: 63.4
# step: 187, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.748e-01, final_inner_loss: 8.510e-01, test_acc: 61.8
# step: 188, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.669e-01, final_inner_loss: 8.571e-01, test_acc: 62.0
# step: 189, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.611e-01, final_inner_loss: 8.558e-01, test_acc: 64.8
# step: 190, dt: 1.7s, meta_grad_norm: 8.1e-02, mean_inner_loss: 9.511e-01, final_inner_loss: 8.268e-01, test_acc: 65.8
# step: 191, dt: 1.7s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.555e-01, final_inner_loss: 7.694e-01, test_acc: 64.6
# step: 192, dt: 1.9s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.549e-01, final_inner_loss: 7.637e-01, test_acc: 63.6
# step: 193, dt: 2.2s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.614e-01, final_inner_loss: 8.432e-01, test_acc: 66.8
# step: 194, dt: 1.7s, meta_grad_norm: 1.0e-01, mean_inner_loss: 9.528e-01, final_inner_loss: 8.215e-01, test_acc: 66.4
# step: 195, dt: 1.7s, meta_grad_norm: 6.8e-02, mean_inner_loss: 9.549e-01, final_inner_loss: 7.671e-01, test_acc: 64.2
# step: 196, dt: 1.7s, meta_grad_norm: 4.9e-02, mean_inner_loss: 9.442e-01, final_inner_loss: 8.047e-01, test_acc: 65.2
# step: 197, dt: 1.7s, meta_grad_norm: 4.9e-02, mean_inner_loss: 9.523e-01, final_inner_loss: 7.726e-01, test_acc: 63.4
# step: 198, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 9.440e-01, final_inner_loss: 8.100e-01, test_acc: 64.6
# step: 199, dt: 1.8s, meta_grad_norm: 3.0e-01, mean_inner_loss: 9.708e-01, final_inner_loss: 7.908e-01, test_acc: 61.8
# step: 200, dt: 2.2s, meta_grad_norm: 3.5e-02, mean_inner_loss: 9.585e-01, final_inner_loss: 8.540e-01, test_acc: 64.8
# step: 201, dt: 1.7s, meta_grad_norm: 8.2e-02, mean_inner_loss: 9.438e-01, final_inner_loss: 8.134e-01, test_acc: 65.0
# step: 202, dt: 1.7s, meta_grad_norm: 5.6e-02, mean_inner_loss: 9.563e-01, final_inner_loss: 7.539e-01, test_acc: 62.8
# step: 203, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.404e-01, final_inner_loss: 7.984e-01, test_acc: 65.2
# step: 204, dt: 1.7s, meta_grad_norm: 3.2e-02, mean_inner_loss: 9.408e-01, final_inner_loss: 7.725e-01, test_acc: 65.0
# step: 205, dt: 1.7s, meta_grad_norm: 2.7e-01, mean_inner_loss: 9.458e-01, final_inner_loss: 8.217e-01, test_acc: 66.0
# step: 206, dt: 2.0s, meta_grad_norm: 4.7e-02, mean_inner_loss: 9.783e-01, final_inner_loss: 8.527e-01, test_acc: 62.2
# step: 207, dt: 2.1s, meta_grad_norm: 4.7e-02, mean_inner_loss: 9.554e-01, final_inner_loss: 7.518e-01, test_acc: 62.8
# step: 208, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.388e-01, final_inner_loss: 7.926e-01, test_acc: 66.0
# step: 209, dt: 1.8s, meta_grad_norm: 6.9e-01, mean_inner_loss: 9.482e-01, final_inner_loss: 7.956e-01, test_acc: 65.4
# step: 210, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.781e-01, final_inner_loss: 8.585e-01, test_acc: 61.6
# step: 211, dt: 1.8s, meta_grad_norm: 4.1e-02, mean_inner_loss: 9.712e-01, final_inner_loss: 8.429e-01, test_acc: 62.6
# step: 212, dt: 1.8s, meta_grad_norm: 4.4e-03, mean_inner_loss: 9.618e-01, final_inner_loss: 8.537e-01, test_acc: 64.6
# step: 213, dt: 2.1s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.596e-01, final_inner_loss: 8.454e-01, test_acc: 65.0
# step: 214, dt: 2.0s, meta_grad_norm: 3.9e-02, mean_inner_loss: 9.482e-01, final_inner_loss: 8.274e-01, test_acc: 66.8
# step: 215, dt: 1.8s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.380e-01, final_inner_loss: 7.900e-01, test_acc: 65.0
# step: 216, dt: 1.8s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.455e-01, final_inner_loss: 8.201e-01, test_acc: 67.8
# step: 217, dt: 1.8s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.389e-01, final_inner_loss: 7.748e-01, test_acc: 64.6
# step: 218, dt: 1.8s, meta_grad_norm: 6.5e-02, mean_inner_loss: 9.395e-01, final_inner_loss: 8.132e-01, test_acc: 65.6
# step: 219, dt: 1.7s, meta_grad_norm: 4.3e-02, mean_inner_loss: 9.528e-01, final_inner_loss: 7.633e-01, test_acc: 62.2
# step: 220, dt: 2.2s, meta_grad_norm: 3.4e-02, mean_inner_loss: 9.376e-01, final_inner_loss: 7.896e-01, test_acc: 66.2
# step: 221, dt: 1.9s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.529e-01, final_inner_loss: 7.747e-01, test_acc: 63.8
# step: 222, dt: 1.8s, meta_grad_norm: 3.5e-01, mean_inner_loss: 9.635e-01, final_inner_loss: 7.741e-01, test_acc: 63.6
# step: 223, dt: 1.8s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.575e-01, final_inner_loss: 8.425e-01, test_acc: 64.0
# step: 224, dt: 1.7s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.494e-01, final_inner_loss: 8.192e-01, test_acc: 66.6
# step: 225, dt: 1.8s, meta_grad_norm: 4.7e-02, mean_inner_loss: 9.405e-01, final_inner_loss: 7.916e-01, test_acc: 65.2
# step: 226, dt: 1.9s, meta_grad_norm: 6.7e-01, mean_inner_loss: 9.470e-01, final_inner_loss: 7.959e-01, test_acc: 64.0
# step: 227, dt: 2.2s, meta_grad_norm: 2.8e-02, mean_inner_loss: 9.747e-01, final_inner_loss: 8.476e-01, test_acc: 62.8
# step: 228, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.655e-01, final_inner_loss: 8.546e-01, test_acc: 63.8
# step: 229, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.601e-01, final_inner_loss: 8.577e-01, test_acc: 63.8
# step: 230, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.557e-01, final_inner_loss: 8.402e-01, test_acc: 64.8
# step: 231, dt: 1.7s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.454e-01, final_inner_loss: 8.075e-01, test_acc: 68.2
# step: 232, dt: 1.7s, meta_grad_norm: 5.3e-03, mean_inner_loss: 9.365e-01, final_inner_loss: 7.876e-01, test_acc: 65.4
# step: 233, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.357e-01, final_inner_loss: 7.840e-01, test_acc: 65.4
# step: 234, dt: 2.1s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.396e-01, final_inner_loss: 8.031e-01, test_acc: 66.4
# step: 235, dt: 1.7s, meta_grad_norm: 4.4e-01, mean_inner_loss: 9.599e-01, final_inner_loss: 7.780e-01, test_acc: 63.2
# step: 236, dt: 1.8s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.583e-01, final_inner_loss: 8.426e-01, test_acc: 64.6
# step: 237, dt: 1.7s, meta_grad_norm: 9.1e-02, mean_inner_loss: 9.538e-01, final_inner_loss: 8.389e-01, test_acc: 65.2
# step: 238, dt: 1.7s, meta_grad_norm: 7.8e-03, mean_inner_loss: 9.357e-01, final_inner_loss: 7.849e-01, test_acc: 65.4
# step: 239, dt: 1.8s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.360e-01, final_inner_loss: 7.778e-01, test_acc: 65.2
# step: 240, dt: 2.1s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.360e-01, final_inner_loss: 7.998e-01, test_acc: 66.4
# step: 241, dt: 2.0s, meta_grad_norm: 7.8e-03, mean_inner_loss: 9.364e-01, final_inner_loss: 7.701e-01, test_acc: 66.2
# step: 242, dt: 1.7s, meta_grad_norm: 4.6e-03, mean_inner_loss: 9.351e-01, final_inner_loss: 7.871e-01, test_acc: 65.6
# step: 243, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.361e-01, final_inner_loss: 7.988e-01, test_acc: 66.8
# step: 244, dt: 1.7s, meta_grad_norm: 1.8e-03, mean_inner_loss: 9.365e-01, final_inner_loss: 7.689e-01, test_acc: 66.6
# step: 245, dt: 1.7s, meta_grad_norm: 9.5e-03, mean_inner_loss: 9.361e-01, final_inner_loss: 7.622e-01, test_acc: 65.6
# step: 246, dt: 1.7s, meta_grad_norm: 8.5e-02, mean_inner_loss: 9.346e-01, final_inner_loss: 7.872e-01, test_acc: 65.6
# step: 247, dt: 2.1s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.624e-01, final_inner_loss: 7.784e-01, test_acc: 63.4
# step: 248, dt: 1.9s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.407e-01, final_inner_loss: 7.898e-01, test_acc: 66.8
# step: 249, dt: 1.7s, meta_grad_norm: 7.8e-02, mean_inner_loss: 9.629e-01, final_inner_loss: 7.861e-01, test_acc: 61.4
# step: 250, dt: 1.7s, meta_grad_norm: 4.3e-03, mean_inner_loss: 9.344e-01, final_inner_loss: 7.704e-01, test_acc: 64.6
# step: 251, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 9.337e-01, final_inner_loss: 7.817e-01, test_acc: 65.0
# step: 252, dt: 1.7s, meta_grad_norm: 4.4e-01, mean_inner_loss: 9.528e-01, final_inner_loss: 7.728e-01, test_acc: 63.4
# step: 253, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.574e-01, final_inner_loss: 8.379e-01, test_acc: 64.8
# step: 254, dt: 2.1s, meta_grad_norm: 4.6e-02, mean_inner_loss: 9.516e-01, final_inner_loss: 8.397e-01, test_acc: 63.2
# step: 255, dt: 2.0s, meta_grad_norm: 4.1e-02, mean_inner_loss: 9.349e-01, final_inner_loss: 7.965e-01, test_acc: 66.2
# step: 256, dt: 1.8s, meta_grad_norm: 6.4e-01, mean_inner_loss: 9.414e-01, final_inner_loss: 7.809e-01, test_acc: 65.0
# step: 257, dt: 1.7s, meta_grad_norm: 3.6e-02, mean_inner_loss: 9.691e-01, final_inner_loss: 8.347e-01, test_acc: 63.4
# step: 258, dt: 1.8s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.586e-01, final_inner_loss: 8.376e-01, test_acc: 63.8
# step: 259, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.548e-01, final_inner_loss: 8.312e-01, test_acc: 66.0
# step: 260, dt: 1.7s, meta_grad_norm: 4.8e-02, mean_inner_loss: 9.477e-01, final_inner_loss: 8.513e-01, test_acc: 65.0
# step: 261, dt: 2.2s, meta_grad_norm: 3.1e-02, mean_inner_loss: 9.327e-01, final_inner_loss: 7.775e-01, test_acc: 67.6
# step: 262, dt: 1.8s, meta_grad_norm: 7.5e-01, mean_inner_loss: 9.415e-01, final_inner_loss: 7.799e-01, test_acc: 65.6
# step: 263, dt: 1.7s, meta_grad_norm: 3.1e-03, mean_inner_loss: 9.703e-01, final_inner_loss: 8.441e-01, test_acc: 61.8
# step: 264, dt: 1.7s, meta_grad_norm: 3.2e-03, mean_inner_loss: 9.693e-01, final_inner_loss: 8.406e-01, test_acc: 62.0
# step: 265, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.682e-01, final_inner_loss: 8.342e-01, test_acc: 62.4
# step: 266, dt: 1.7s, meta_grad_norm: 4.0e-02, mean_inner_loss: 9.622e-01, final_inner_loss: 8.368e-01, test_acc: 63.0
# step: 267, dt: 1.8s, meta_grad_norm: 9.1e-03, mean_inner_loss: 9.540e-01, final_inner_loss: 8.292e-01, test_acc: 65.2
# step: 268, dt: 2.2s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.503e-01, final_inner_loss: 8.408e-01, test_acc: 64.6
# step: 269, dt: 1.8s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.329e-01, final_inner_loss: 7.828e-01, test_acc: 66.4
# step: 270, dt: 1.7s, meta_grad_norm: 4.8e-03, mean_inner_loss: 9.328e-01, final_inner_loss: 7.751e-01, test_acc: 65.4
# step: 271, dt: 1.7s, meta_grad_norm: 7.3e-01, mean_inner_loss: 9.430e-01, final_inner_loss: 7.906e-01, test_acc: 65.8
# step: 272, dt: 1.7s, meta_grad_norm: 6.3e-03, mean_inner_loss: 9.669e-01, final_inner_loss: 8.397e-01, test_acc: 62.4
# step: 273, dt: 1.7s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.642e-01, final_inner_loss: 8.202e-01, test_acc: 63.8
# step: 274, dt: 1.8s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.561e-01, final_inner_loss: 8.479e-01, test_acc: 65.0
# step: 275, dt: 2.1s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.529e-01, final_inner_loss: 8.238e-01, test_acc: 64.2
# step: 276, dt: 1.7s, meta_grad_norm: 3.9e-02, mean_inner_loss: 9.489e-01, final_inner_loss: 8.359e-01, test_acc: 65.4
# step: 277, dt: 1.7s, meta_grad_norm: 2.1e-01, mean_inner_loss: 9.349e-01, final_inner_loss: 7.813e-01, test_acc: 66.4
# step: 278, dt: 1.7s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.608e-01, final_inner_loss: 7.966e-01, test_acc: 62.6
# step: 279, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.325e-01, final_inner_loss: 7.722e-01, test_acc: 65.2
# step: 280, dt: 1.8s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.326e-01, final_inner_loss: 7.689e-01, test_acc: 65.6
# step: 281, dt: 1.9s, meta_grad_norm: 1.1e-03, mean_inner_loss: 9.325e-01, final_inner_loss: 7.724e-01, test_acc: 64.0
# step: 282, dt: 2.1s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.318e-01, final_inner_loss: 7.775e-01, test_acc: 65.0
# step: 283, dt: 1.7s, meta_grad_norm: 6.4e-02, mean_inner_loss: 9.390e-01, final_inner_loss: 8.115e-01, test_acc: 67.4
# step: 284, dt: 1.7s, meta_grad_norm: 8.6e-03, mean_inner_loss: 9.325e-01, final_inner_loss: 7.744e-01, test_acc: 63.6
# step: 285, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.307e-01, final_inner_loss: 7.809e-01, test_acc: 66.2
# step: 286, dt: 1.7s, meta_grad_norm: 7.7e-02, mean_inner_loss: 9.382e-01, final_inner_loss: 8.121e-01, test_acc: 66.8
# step: 287, dt: 1.7s, meta_grad_norm: 6.7e-01, mean_inner_loss: 9.361e-01, final_inner_loss: 7.718e-01, test_acc: 65.2
# step: 288, dt: 1.9s, meta_grad_norm: 7.9e-03, mean_inner_loss: 9.625e-01, final_inner_loss: 8.458e-01, test_acc: 63.6
# step: 289, dt: 2.1s, meta_grad_norm: 3.9e-02, mean_inner_loss: 9.586e-01, final_inner_loss: 8.354e-01, test_acc: 63.6
# step: 290, dt: 1.7s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.514e-01, final_inner_loss: 8.452e-01, test_acc: 65.2
# step: 291, dt: 1.7s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.455e-01, final_inner_loss: 8.444e-01, test_acc: 65.6
# step: 292, dt: 1.7s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.363e-01, final_inner_loss: 8.093e-01, test_acc: 66.4
# step: 293, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.478e-01, final_inner_loss: 7.574e-01, test_acc: 64.6
# step: 294, dt: 1.7s, meta_grad_norm: 3.5e-01, mean_inner_loss: 9.556e-01, final_inner_loss: 7.702e-01, test_acc: 63.6
# step: 295, dt: 1.9s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.444e-01, final_inner_loss: 8.384e-01, test_acc: 65.0
# step: 296, dt: 2.1s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.336e-01, final_inner_loss: 8.073e-01, test_acc: 65.4
# step: 297, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.531e-01, final_inner_loss: 7.797e-01, test_acc: 61.0
# step: 298, dt: 1.7s, meta_grad_norm: 2.8e-01, mean_inner_loss: 9.359e-01, final_inner_loss: 8.150e-01, test_acc: 65.8
# step: 299, dt: 1.7s, meta_grad_norm: 6.6e-02, mean_inner_loss: 9.624e-01, final_inner_loss: 7.976e-01, test_acc: 63.2
# step: 300, dt: 1.7s, meta_grad_norm: 5.7e-01, mean_inner_loss: 9.392e-01, final_inner_loss: 7.768e-01, test_acc: 64.6

# %%
import pickle

# Save results using pickle
with open('hs_results_100.pkl', 'wb') as f:
    pickle.dump(hs_results_100, f)

print("Results saved to 'hs_results_100.pkl'")
# Out:
# Results saved to 'hs_results_100.pkl'

# %%
# Load results from pickle file
with open('hs_results_100.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
hs_results_100['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    hs_results_100['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(hs_results_100['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 0.9861675784041319
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.3642001, 1.3803443, 1.4692458, 1.6158363, 1.5453933, 1.7433902]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(hs_results_100, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 63.4
