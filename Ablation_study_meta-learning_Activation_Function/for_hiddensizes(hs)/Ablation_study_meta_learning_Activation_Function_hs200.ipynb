# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 200,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.4,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
hs_results_200 = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 2.9s, meta_grad_norm: 7.2e-01, mean_inner_loss: 1.368e+00, final_inner_loss: 1.381e+00, test_acc: 48.6
# step: 1, dt: 1.9s, meta_grad_norm: 4.2e-01, mean_inner_loss: 1.522e+00, final_inner_loss: 1.426e+00, test_acc: 45.2
# step: 2, dt: 1.9s, meta_grad_norm: 5.2e-01, mean_inner_loss: 1.423e+00, final_inner_loss: 1.389e+00, test_acc: 48.4
# step: 3, dt: 1.9s, meta_grad_norm: 6.1e-01, mean_inner_loss: 1.558e+00, final_inner_loss: 1.431e+00, test_acc: 44.2
# step: 4, dt: 2.0s, meta_grad_norm: 8.6e-01, mean_inner_loss: 1.606e+00, final_inner_loss: 1.434e+00, test_acc: 44.4
# step: 5, dt: 2.3s, meta_grad_norm: 7.5e-01, mean_inner_loss: 1.627e+00, final_inner_loss: 1.451e+00, test_acc: 43.2
# step: 6, dt: 1.9s, meta_grad_norm: 1.9e-01, mean_inner_loss: 1.578e+00, final_inner_loss: 1.409e+00, test_acc: 44.2
# step: 7, dt: 1.9s, meta_grad_norm: 3.0e-01, mean_inner_loss: 1.522e+00, final_inner_loss: 1.402e+00, test_acc: 45.6
# step: 8, dt: 1.9s, meta_grad_norm: 2.6e-01, mean_inner_loss: 1.435e+00, final_inner_loss: 1.342e+00, test_acc: 48.6
# step: 9, dt: 1.9s, meta_grad_norm: 3.4e-01, mean_inner_loss: 1.353e+00, final_inner_loss: 1.272e+00, test_acc: 52.2
# step: 10, dt: 1.9s, meta_grad_norm: 5.3e-01, mean_inner_loss: 1.229e+00, final_inner_loss: 1.183e+00, test_acc: 56.6
# step: 11, dt: 2.5s, meta_grad_norm: 2.0e-01, mean_inner_loss: 1.090e+00, final_inner_loss: 1.014e+00, test_acc: 59.2
# step: 12, dt: 1.9s, meta_grad_norm: 6.8e-02, mean_inner_loss: 1.047e+00, final_inner_loss: 9.845e-01, test_acc: 62.6
# step: 13, dt: 1.9s, meta_grad_norm: 2.1e-02, mean_inner_loss: 1.029e+00, final_inner_loss: 9.837e-01, test_acc: 61.8
# step: 14, dt: 1.9s, meta_grad_norm: 2.0e-01, mean_inner_loss: 1.025e+00, final_inner_loss: 9.603e-01, test_acc: 62.4
# step: 15, dt: 1.9s, meta_grad_norm: 1.1e+00, mean_inner_loss: 1.036e+00, final_inner_loss: 1.017e+00, test_acc: 59.2
# step: 16, dt: 1.9s, meta_grad_norm: 2.5e-02, mean_inner_loss: 1.001e+00, final_inner_loss: 9.799e-01, test_acc: 63.4
# step: 17, dt: 2.4s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.870e-01, final_inner_loss: 9.308e-01, test_acc: 64.2
# step: 18, dt: 2.0s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.984e-01, final_inner_loss: 9.823e-01, test_acc: 63.4
# step: 19, dt: 1.9s, meta_grad_norm: 7.0e-02, mean_inner_loss: 9.658e-01, final_inner_loss: 9.053e-01, test_acc: 64.4
# step: 20, dt: 1.9s, meta_grad_norm: 6.0e-03, mean_inner_loss: 9.576e-01, final_inner_loss: 8.814e-01, test_acc: 65.2
# step: 21, dt: 1.9s, meta_grad_norm: 6.0e-03, mean_inner_loss: 9.561e-01, final_inner_loss: 8.825e-01, test_acc: 66.4
# step: 22, dt: 1.9s, meta_grad_norm: 6.2e-03, mean_inner_loss: 9.546e-01, final_inner_loss: 8.749e-01, test_acc: 65.6
# step: 23, dt: 2.2s, meta_grad_norm: 4.9e-03, mean_inner_loss: 9.532e-01, final_inner_loss: 8.746e-01, test_acc: 66.6
# step: 24, dt: 2.1s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.520e-01, final_inner_loss: 8.694e-01, test_acc: 65.8
# step: 25, dt: 1.9s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.513e-01, final_inner_loss: 8.678e-01, test_acc: 66.4
# step: 26, dt: 1.9s, meta_grad_norm: 7.0e-03, mean_inner_loss: 9.497e-01, final_inner_loss: 8.588e-01, test_acc: 66.8
# step: 27, dt: 1.9s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.479e-01, final_inner_loss: 8.529e-01, test_acc: 65.6
# step: 28, dt: 1.9s, meta_grad_norm: 5.6e-03, mean_inner_loss: 9.472e-01, final_inner_loss: 8.710e-01, test_acc: 68.4
# step: 29, dt: 2.2s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.461e-01, final_inner_loss: 8.658e-01, test_acc: 68.0
# step: 30, dt: 2.2s, meta_grad_norm: 5.9e-03, mean_inner_loss: 9.442e-01, final_inner_loss: 8.513e-01, test_acc: 67.8
# step: 31, dt: 1.9s, meta_grad_norm: 4.6e-03, mean_inner_loss: 9.428e-01, final_inner_loss: 8.520e-01, test_acc: 67.6
# step: 32, dt: 1.9s, meta_grad_norm: 8.1e-03, mean_inner_loss: 9.415e-01, final_inner_loss: 8.534e-01, test_acc: 67.6
# step: 33, dt: 1.9s, meta_grad_norm: 6.3e-03, mean_inner_loss: 9.404e-01, final_inner_loss: 8.500e-01, test_acc: 69.2
# step: 34, dt: 1.9s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.387e-01, final_inner_loss: 8.519e-01, test_acc: 69.2
# step: 35, dt: 2.1s, meta_grad_norm: 5.2e-03, mean_inner_loss: 9.372e-01, final_inner_loss: 8.511e-01, test_acc: 67.0
# step: 36, dt: 2.2s, meta_grad_norm: 9.7e-03, mean_inner_loss: 9.359e-01, final_inner_loss: 8.474e-01, test_acc: 67.8
# step: 37, dt: 1.9s, meta_grad_norm: 8.2e-03, mean_inner_loss: 9.358e-01, final_inner_loss: 8.463e-01, test_acc: 68.2
# step: 38, dt: 1.9s, meta_grad_norm: 5.1e-03, mean_inner_loss: 9.329e-01, final_inner_loss: 8.445e-01, test_acc: 67.8
# step: 39, dt: 1.9s, meta_grad_norm: 7.1e-03, mean_inner_loss: 9.316e-01, final_inner_loss: 8.400e-01, test_acc: 68.8
# step: 40, dt: 2.0s, meta_grad_norm: 5.5e-03, mean_inner_loss: 9.306e-01, final_inner_loss: 8.408e-01, test_acc: 68.0
# step: 41, dt: 1.9s, meta_grad_norm: 6.4e-03, mean_inner_loss: 9.289e-01, final_inner_loss: 8.353e-01, test_acc: 69.2
# step: 42, dt: 2.7s, meta_grad_norm: 7.1e-03, mean_inner_loss: 9.271e-01, final_inner_loss: 8.286e-01, test_acc: 68.8
# step: 43, dt: 2.2s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.258e-01, final_inner_loss: 8.232e-01, test_acc: 68.4
# step: 44, dt: 1.9s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.252e-01, final_inner_loss: 8.288e-01, test_acc: 68.0
# step: 45, dt: 1.9s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.261e-01, final_inner_loss: 7.851e-01, test_acc: 69.2
# step: 46, dt: 1.9s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.229e-01, final_inner_loss: 8.042e-01, test_acc: 68.8
# step: 47, dt: 2.0s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.215e-01, final_inner_loss: 7.954e-01, test_acc: 68.4
# step: 48, dt: 2.4s, meta_grad_norm: 6.4e-03, mean_inner_loss: 9.196e-01, final_inner_loss: 8.188e-01, test_acc: 68.6
# step: 49, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.174e-01, final_inner_loss: 8.091e-01, test_acc: 68.4
# step: 50, dt: 1.9s, meta_grad_norm: 5.6e-03, mean_inner_loss: 9.162e-01, final_inner_loss: 7.994e-01, test_acc: 68.6
# step: 51, dt: 1.9s, meta_grad_norm: 5.7e-03, mean_inner_loss: 9.151e-01, final_inner_loss: 8.028e-01, test_acc: 68.8
# step: 52, dt: 1.9s, meta_grad_norm: 9.0e-03, mean_inner_loss: 9.138e-01, final_inner_loss: 7.891e-01, test_acc: 69.2
# step: 53, dt: 1.9s, meta_grad_norm: 9.8e-03, mean_inner_loss: 9.121e-01, final_inner_loss: 7.915e-01, test_acc: 68.6
# step: 54, dt: 2.4s, meta_grad_norm: 4.8e-02, mean_inner_loss: 9.128e-01, final_inner_loss: 7.805e-01, test_acc: 68.4
# step: 55, dt: 1.9s, meta_grad_norm: 5.6e-03, mean_inner_loss: 9.136e-01, final_inner_loss: 7.893e-01, test_acc: 67.8
# step: 56, dt: 1.9s, meta_grad_norm: 4.1e-03, mean_inner_loss: 9.119e-01, final_inner_loss: 7.838e-01, test_acc: 68.8
# step: 57, dt: 1.9s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.115e-01, final_inner_loss: 7.929e-01, test_acc: 67.4
# step: 58, dt: 1.9s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.070e-01, final_inner_loss: 7.845e-01, test_acc: 69.4
# step: 59, dt: 1.9s, meta_grad_norm: 3.8e-02, mean_inner_loss: 9.108e-01, final_inner_loss: 7.698e-01, test_acc: 67.0
# step: 60, dt: 2.3s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.062e-01, final_inner_loss: 7.783e-01, test_acc: 68.0
# step: 61, dt: 2.0s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.043e-01, final_inner_loss: 7.677e-01, test_acc: 67.8
# step: 62, dt: 1.9s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.061e-01, final_inner_loss: 7.762e-01, test_acc: 67.4
# step: 63, dt: 1.9s, meta_grad_norm: 9.2e-03, mean_inner_loss: 9.038e-01, final_inner_loss: 7.846e-01, test_acc: 67.6
# step: 64, dt: 1.9s, meta_grad_norm: 5.0e-03, mean_inner_loss: 9.025e-01, final_inner_loss: 7.721e-01, test_acc: 67.6
# step: 65, dt: 1.9s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.003e-01, final_inner_loss: 7.751e-01, test_acc: 69.4
# step: 66, dt: 2.2s, meta_grad_norm: 2.9e-02, mean_inner_loss: 9.022e-01, final_inner_loss: 7.748e-01, test_acc: 67.4
# step: 67, dt: 2.1s, meta_grad_norm: 2.1e-02, mean_inner_loss: 8.996e-01, final_inner_loss: 7.724e-01, test_acc: 69.4
# step: 68, dt: 1.9s, meta_grad_norm: 5.0e-02, mean_inner_loss: 8.974e-01, final_inner_loss: 7.680e-01, test_acc: 68.8
# step: 69, dt: 1.9s, meta_grad_norm: 6.5e-02, mean_inner_loss: 9.009e-01, final_inner_loss: 7.879e-01, test_acc: 66.8
# step: 70, dt: 1.9s, meta_grad_norm: 2.8e-02, mean_inner_loss: 8.994e-01, final_inner_loss: 7.824e-01, test_acc: 68.2
# step: 71, dt: 1.9s, meta_grad_norm: 4.6e-03, mean_inner_loss: 8.941e-01, final_inner_loss: 7.655e-01, test_acc: 69.6
# step: 72, dt: 2.2s, meta_grad_norm: 8.3e-03, mean_inner_loss: 8.936e-01, final_inner_loss: 7.735e-01, test_acc: 69.6
# step: 73, dt: 2.2s, meta_grad_norm: 3.0e-02, mean_inner_loss: 8.933e-01, final_inner_loss: 7.661e-01, test_acc: 69.0
# step: 74, dt: 1.9s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.938e-01, final_inner_loss: 7.579e-01, test_acc: 68.2
# step: 75, dt: 1.9s, meta_grad_norm: 3.8e-03, mean_inner_loss: 8.952e-01, final_inner_loss: 7.517e-01, test_acc: 68.2
# step: 76, dt: 1.9s, meta_grad_norm: 2.7e-02, mean_inner_loss: 8.938e-01, final_inner_loss: 7.492e-01, test_acc: 68.4
# step: 77, dt: 1.9s, meta_grad_norm: 5.0e-03, mean_inner_loss: 8.902e-01, final_inner_loss: 7.590e-01, test_acc: 68.8
# step: 78, dt: 2.0s, meta_grad_norm: 5.3e-03, mean_inner_loss: 8.888e-01, final_inner_loss: 7.628e-01, test_acc: 70.0
# step: 79, dt: 2.3s, meta_grad_norm: 2.2e-03, mean_inner_loss: 8.874e-01, final_inner_loss: 7.618e-01, test_acc: 70.0
# step: 80, dt: 2.0s, meta_grad_norm: 3.9e-03, mean_inner_loss: 8.868e-01, final_inner_loss: 7.601e-01, test_acc: 70.4
# step: 81, dt: 1.9s, meta_grad_norm: 2.5e-02, mean_inner_loss: 8.855e-01, final_inner_loss: 7.621e-01, test_acc: 68.4
# step: 82, dt: 1.9s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.886e-01, final_inner_loss: 7.383e-01, test_acc: 68.0
# step: 83, dt: 1.9s, meta_grad_norm: 3.1e-03, mean_inner_loss: 8.834e-01, final_inner_loss: 7.557e-01, test_acc: 68.0
# step: 84, dt: 1.9s, meta_grad_norm: 9.0e-03, mean_inner_loss: 8.826e-01, final_inner_loss: 7.533e-01, test_acc: 70.0
# step: 85, dt: 2.5s, meta_grad_norm: 6.9e-03, mean_inner_loss: 8.831e-01, final_inner_loss: 7.429e-01, test_acc: 70.4
# step: 86, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.825e-01, final_inner_loss: 7.561e-01, test_acc: 69.8
# step: 87, dt: 1.9s, meta_grad_norm: 3.4e-03, mean_inner_loss: 8.806e-01, final_inner_loss: 7.465e-01, test_acc: 70.6
# step: 88, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.796e-01, final_inner_loss: 7.438e-01, test_acc: 69.8
# step: 89, dt: 1.9s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.803e-01, final_inner_loss: 7.328e-01, test_acc: 67.0
# step: 90, dt: 1.9s, meta_grad_norm: 1.2e-01, mean_inner_loss: 8.853e-01, final_inner_loss: 7.596e-01, test_acc: 65.4
# step: 91, dt: 2.4s, meta_grad_norm: 5.0e-03, mean_inner_loss: 8.780e-01, final_inner_loss: 7.491e-01, test_acc: 69.6
# step: 92, dt: 2.0s, meta_grad_norm: 9.5e-03, mean_inner_loss: 8.758e-01, final_inner_loss: 7.456e-01, test_acc: 69.6
# step: 93, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.755e-01, final_inner_loss: 7.440e-01, test_acc: 69.8
# step: 94, dt: 1.9s, meta_grad_norm: 9.4e-03, mean_inner_loss: 8.742e-01, final_inner_loss: 7.374e-01, test_acc: 68.8
# step: 95, dt: 1.9s, meta_grad_norm: 3.1e-02, mean_inner_loss: 8.725e-01, final_inner_loss: 7.400e-01, test_acc: 69.4
# step: 96, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.741e-01, final_inner_loss: 7.135e-01, test_acc: 66.2
# step: 97, dt: 2.3s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.721e-01, final_inner_loss: 7.221e-01, test_acc: 67.4
# step: 98, dt: 2.0s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.822e-01, final_inner_loss: 7.786e-01, test_acc: 68.4
# step: 99, dt: 1.9s, meta_grad_norm: 1.7e-01, mean_inner_loss: 8.744e-01, final_inner_loss: 7.414e-01, test_acc: 68.6
# step: 100, dt: 1.9s, meta_grad_norm: 4.0e-02, mean_inner_loss: 8.753e-01, final_inner_loss: 7.272e-01, test_acc: 70.0
# step: 101, dt: 1.9s, meta_grad_norm: 7.0e-03, mean_inner_loss: 8.726e-01, final_inner_loss: 7.153e-01, test_acc: 68.2
# step: 102, dt: 1.9s, meta_grad_norm: 5.8e-03, mean_inner_loss: 8.710e-01, final_inner_loss: 7.051e-01, test_acc: 67.8
# step: 103, dt: 2.2s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.700e-01, final_inner_loss: 7.220e-01, test_acc: 69.4
# step: 104, dt: 2.2s, meta_grad_norm: 2.5e-02, mean_inner_loss: 8.693e-01, final_inner_loss: 7.232e-01, test_acc: 69.6
# step: 105, dt: 1.9s, meta_grad_norm: 5.9e-03, mean_inner_loss: 8.650e-01, final_inner_loss: 7.228e-01, test_acc: 67.0
# step: 106, dt: 1.9s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.637e-01, final_inner_loss: 7.218e-01, test_acc: 67.2
# step: 107, dt: 1.9s, meta_grad_norm: 5.6e-02, mean_inner_loss: 8.606e-01, final_inner_loss: 6.983e-01, test_acc: 68.8
# step: 108, dt: 1.9s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.669e-01, final_inner_loss: 7.019e-01, test_acc: 67.6
# step: 109, dt: 2.2s, meta_grad_norm: 5.7e-02, mean_inner_loss: 8.646e-01, final_inner_loss: 6.936e-01, test_acc: 68.8
# step: 110, dt: 2.2s, meta_grad_norm: 2.9e-03, mean_inner_loss: 8.650e-01, final_inner_loss: 6.932e-01, test_acc: 69.6
# step: 111, dt: 1.9s, meta_grad_norm: 1.0e-02, mean_inner_loss: 8.642e-01, final_inner_loss: 6.996e-01, test_acc: 69.0
# step: 112, dt: 1.9s, meta_grad_norm: 8.0e-03, mean_inner_loss: 8.642e-01, final_inner_loss: 6.877e-01, test_acc: 69.2
# step: 113, dt: 1.9s, meta_grad_norm: 3.4e-03, mean_inner_loss: 8.627e-01, final_inner_loss: 6.887e-01, test_acc: 71.2
# step: 114, dt: 2.0s, meta_grad_norm: 6.2e-03, mean_inner_loss: 8.616e-01, final_inner_loss: 6.814e-01, test_acc: 71.2
# step: 115, dt: 2.1s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.613e-01, final_inner_loss: 6.874e-01, test_acc: 68.8
# step: 116, dt: 2.3s, meta_grad_norm: 1.2e-02, mean_inner_loss: 8.613e-01, final_inner_loss: 6.899e-01, test_acc: 69.0
# step: 117, dt: 1.9s, meta_grad_norm: 5.6e-03, mean_inner_loss: 8.638e-01, final_inner_loss: 7.101e-01, test_acc: 69.4
# step: 118, dt: 1.9s, meta_grad_norm: 9.6e-03, mean_inner_loss: 8.622e-01, final_inner_loss: 7.029e-01, test_acc: 68.8
# step: 119, dt: 2.0s, meta_grad_norm: 5.6e-03, mean_inner_loss: 8.608e-01, final_inner_loss: 6.898e-01, test_acc: 71.2
# step: 120, dt: 2.0s, meta_grad_norm: 4.1e-03, mean_inner_loss: 8.594e-01, final_inner_loss: 6.983e-01, test_acc: 71.0
# step: 121, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.581e-01, final_inner_loss: 7.013e-01, test_acc: 71.0
# step: 122, dt: 2.3s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.573e-01, final_inner_loss: 6.920e-01, test_acc: 70.2
# step: 123, dt: 2.0s, meta_grad_norm: 1.2e-02, mean_inner_loss: 8.551e-01, final_inner_loss: 6.831e-01, test_acc: 70.2
# step: 124, dt: 1.9s, meta_grad_norm: 1.2e-02, mean_inner_loss: 8.549e-01, final_inner_loss: 6.840e-01, test_acc: 71.0
# step: 125, dt: 1.9s, meta_grad_norm: 9.1e-03, mean_inner_loss: 8.534e-01, final_inner_loss: 6.973e-01, test_acc: 69.4
# step: 126, dt: 1.9s, meta_grad_norm: 5.0e-02, mean_inner_loss: 8.532e-01, final_inner_loss: 6.902e-01, test_acc: 70.0
# step: 127, dt: 1.9s, meta_grad_norm: 5.1e-02, mean_inner_loss: 8.534e-01, final_inner_loss: 6.962e-01, test_acc: 67.4
# step: 128, dt: 2.4s, meta_grad_norm: 5.5e-03, mean_inner_loss: 8.551e-01, final_inner_loss: 7.232e-01, test_acc: 70.4
# step: 129, dt: 1.9s, meta_grad_norm: 1.5e-01, mean_inner_loss: 8.545e-01, final_inner_loss: 7.248e-01, test_acc: 71.6
# step: 130, dt: 1.9s, meta_grad_norm: 4.1e-02, mean_inner_loss: 8.566e-01, final_inner_loss: 7.621e-01, test_acc: 67.4
# step: 131, dt: 1.9s, meta_grad_norm: 1.1e+00, mean_inner_loss: 8.567e-01, final_inner_loss: 7.017e-01, test_acc: 68.2
# step: 132, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.882e-01, final_inner_loss: 8.214e-01, test_acc: 68.2
# step: 133, dt: 1.9s, meta_grad_norm: 2.0e-01, mean_inner_loss: 8.869e-01, final_inner_loss: 8.081e-01, test_acc: 67.8
# step: 134, dt: 2.4s, meta_grad_norm: 4.9e-02, mean_inner_loss: 8.569e-01, final_inner_loss: 7.351e-01, test_acc: 69.4
# step: 135, dt: 2.0s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.501e-01, final_inner_loss: 7.348e-01, test_acc: 70.4
# step: 136, dt: 1.9s, meta_grad_norm: 5.5e-02, mean_inner_loss: 8.468e-01, final_inner_loss: 7.461e-01, test_acc: 68.6
# step: 137, dt: 1.9s, meta_grad_norm: 2.2e-01, mean_inner_loss: 8.520e-01, final_inner_loss: 7.791e-01, test_acc: 70.6
# step: 138, dt: 1.9s, meta_grad_norm: 3.1e-02, mean_inner_loss: 8.360e-01, final_inner_loss: 7.179e-01, test_acc: 67.6
# step: 139, dt: 2.0s, meta_grad_norm: 1.0e-01, mean_inner_loss: 8.339e-01, final_inner_loss: 6.903e-01, test_acc: 69.8
# step: 140, dt: 2.2s, meta_grad_norm: 3.2e-02, mean_inner_loss: 8.508e-01, final_inner_loss: 7.181e-01, test_acc: 67.6
# step: 141, dt: 2.1s, meta_grad_norm: 9.7e-02, mean_inner_loss: 8.526e-01, final_inner_loss: 7.477e-01, test_acc: 69.0
# step: 142, dt: 1.9s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.410e-01, final_inner_loss: 6.776e-01, test_acc: 68.0
# step: 143, dt: 1.9s, meta_grad_norm: 8.2e-01, mean_inner_loss: 8.368e-01, final_inner_loss: 6.768e-01, test_acc: 66.4
# step: 144, dt: 1.9s, meta_grad_norm: 1.2e-02, mean_inner_loss: 8.532e-01, final_inner_loss: 6.487e-01, test_acc: 71.0
# step: 145, dt: 1.9s, meta_grad_norm: 3.6e-02, mean_inner_loss: 8.521e-01, final_inner_loss: 6.907e-01, test_acc: 69.0
# step: 146, dt: 2.1s, meta_grad_norm: 3.0e-02, mean_inner_loss: 8.514e-01, final_inner_loss: 6.714e-01, test_acc: 68.4
# step: 147, dt: 2.2s, meta_grad_norm: 5.5e-03, mean_inner_loss: 8.497e-01, final_inner_loss: 7.178e-01, test_acc: 69.0
# step: 148, dt: 1.9s, meta_grad_norm: 9.9e-03, mean_inner_loss: 8.486e-01, final_inner_loss: 7.144e-01, test_acc: 67.2
# step: 149, dt: 1.9s, meta_grad_norm: 9.0e-02, mean_inner_loss: 8.439e-01, final_inner_loss: 7.330e-01, test_acc: 69.2
# step: 150, dt: 1.9s, meta_grad_norm: 4.0e-02, mean_inner_loss: 8.396e-01, final_inner_loss: 6.741e-01, test_acc: 70.4
# step: 151, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.316e-01, final_inner_loss: 6.549e-01, test_acc: 68.4
# step: 152, dt: 2.0s, meta_grad_norm: 1.5e-01, mean_inner_loss: 8.307e-01, final_inner_loss: 6.380e-01, test_acc: 69.4
# step: 153, dt: 2.3s, meta_grad_norm: 2.4e-02, mean_inner_loss: 8.384e-01, final_inner_loss: 6.797e-01, test_acc: 70.0
# step: 154, dt: 1.9s, meta_grad_norm: 3.3e-02, mean_inner_loss: 8.369e-01, final_inner_loss: 7.075e-01, test_acc: 69.2
# step: 155, dt: 1.9s, meta_grad_norm: 6.3e-02, mean_inner_loss: 8.379e-01, final_inner_loss: 6.747e-01, test_acc: 70.6
# step: 156, dt: 1.9s, meta_grad_norm: 9.3e-02, mean_inner_loss: 8.263e-01, final_inner_loss: 6.607e-01, test_acc: 70.4
# step: 157, dt: 1.9s, meta_grad_norm: 4.7e-02, mean_inner_loss: 8.346e-01, final_inner_loss: 7.298e-01, test_acc: 70.0
# step: 158, dt: 1.9s, meta_grad_norm: 5.9e-02, mean_inner_loss: 8.394e-01, final_inner_loss: 7.162e-01, test_acc: 68.8
# step: 159, dt: 2.4s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.339e-01, final_inner_loss: 7.400e-01, test_acc: 70.4
# step: 160, dt: 2.0s, meta_grad_norm: 2.2e-01, mean_inner_loss: 8.334e-01, final_inner_loss: 6.983e-01, test_acc: 71.0
# step: 161, dt: 1.9s, meta_grad_norm: 5.5e-01, mean_inner_loss: 8.280e-01, final_inner_loss: 6.674e-01, test_acc: 70.0
# step: 162, dt: 1.9s, meta_grad_norm: 2.6e-02, mean_inner_loss: 8.460e-01, final_inner_loss: 6.439e-01, test_acc: 71.4
# step: 163, dt: 1.9s, meta_grad_norm: 8.8e-02, mean_inner_loss: 8.435e-01, final_inner_loss: 6.501e-01, test_acc: 70.8
# step: 164, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.346e-01, final_inner_loss: 6.849e-01, test_acc: 69.4
# step: 165, dt: 2.4s, meta_grad_norm: 5.7e-02, mean_inner_loss: 8.320e-01, final_inner_loss: 6.852e-01, test_acc: 70.4
# step: 166, dt: 2.0s, meta_grad_norm: 7.3e-02, mean_inner_loss: 8.279e-01, final_inner_loss: 6.158e-01, test_acc: 69.0
# step: 167, dt: 1.9s, meta_grad_norm: 9.8e-01, mean_inner_loss: 8.281e-01, final_inner_loss: 6.758e-01, test_acc: 69.4
# step: 168, dt: 1.9s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.441e-01, final_inner_loss: 7.349e-01, test_acc: 69.8
# step: 169, dt: 1.9s, meta_grad_norm: 2.2e-02, mean_inner_loss: 8.405e-01, final_inner_loss: 6.814e-01, test_acc: 69.8
# step: 170, dt: 1.9s, meta_grad_norm: 4.0e-01, mean_inner_loss: 8.362e-01, final_inner_loss: 6.977e-01, test_acc: 68.6
# step: 171, dt: 2.2s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.453e-01, final_inner_loss: 7.056e-01, test_acc: 71.6
# step: 172, dt: 2.1s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.418e-01, final_inner_loss: 6.889e-01, test_acc: 71.6
# step: 173, dt: 1.9s, meta_grad_norm: 3.8e-02, mean_inner_loss: 8.280e-01, final_inner_loss: 6.998e-01, test_acc: 69.6
# step: 174, dt: 1.9s, meta_grad_norm: 8.6e-02, mean_inner_loss: 8.214e-01, final_inner_loss: 6.114e-01, test_acc: 70.8
# step: 175, dt: 1.9s, meta_grad_norm: 7.5e-01, mean_inner_loss: 8.232e-01, final_inner_loss: 6.788e-01, test_acc: 70.6
# step: 176, dt: 1.9s, meta_grad_norm: 2.4e-01, mean_inner_loss: 8.745e-01, final_inner_loss: 7.128e-01, test_acc: 66.6
# step: 177, dt: 2.1s, meta_grad_norm: 9.0e-02, mean_inner_loss: 8.389e-01, final_inner_loss: 6.944e-01, test_acc: 68.0
# step: 178, dt: 2.1s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.315e-01, final_inner_loss: 6.189e-01, test_acc: 68.6
# step: 179, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.261e-01, final_inner_loss: 6.711e-01, test_acc: 68.4
# step: 180, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.239e-01, final_inner_loss: 6.824e-01, test_acc: 66.6
# step: 181, dt: 1.9s, meta_grad_norm: 2.3e-01, mean_inner_loss: 8.256e-01, final_inner_loss: 6.524e-01, test_acc: 68.6
# step: 182, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.226e-01, final_inner_loss: 6.859e-01, test_acc: 69.6
# step: 183, dt: 1.9s, meta_grad_norm: 1.5e-01, mean_inner_loss: 8.188e-01, final_inner_loss: 6.354e-01, test_acc: 71.4
# step: 184, dt: 2.4s, meta_grad_norm: 1.4e-01, mean_inner_loss: 8.172e-01, final_inner_loss: 6.774e-01, test_acc: 68.2
# step: 185, dt: 1.9s, meta_grad_norm: 9.2e-02, mean_inner_loss: 8.175e-01, final_inner_loss: 6.880e-01, test_acc: 69.8
# step: 186, dt: 1.9s, meta_grad_norm: 1.5e+00, mean_inner_loss: 8.155e-01, final_inner_loss: 6.772e-01, test_acc: 69.0
# step: 187, dt: 1.9s, meta_grad_norm: 7.3e-02, mean_inner_loss: 8.364e-01, final_inner_loss: 7.280e-01, test_acc: 69.4
# step: 188, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.342e-01, final_inner_loss: 7.478e-01, test_acc: 70.8
# step: 189, dt: 1.9s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.331e-01, final_inner_loss: 7.581e-01, test_acc: 69.4
# step: 190, dt: 2.4s, meta_grad_norm: 4.8e-02, mean_inner_loss: 8.309e-01, final_inner_loss: 7.133e-01, test_acc: 72.0
# step: 191, dt: 2.0s, meta_grad_norm: 5.3e-02, mean_inner_loss: 8.319e-01, final_inner_loss: 7.216e-01, test_acc: 70.0
# step: 192, dt: 1.9s, meta_grad_norm: 2.7e-02, mean_inner_loss: 8.344e-01, final_inner_loss: 6.947e-01, test_acc: 69.8
# step: 193, dt: 1.9s, meta_grad_norm: 8.6e-03, mean_inner_loss: 8.292e-01, final_inner_loss: 6.967e-01, test_acc: 69.4
# step: 194, dt: 1.9s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.271e-01, final_inner_loss: 7.062e-01, test_acc: 71.6
# step: 195, dt: 1.9s, meta_grad_norm: 2.1e-02, mean_inner_loss: 8.261e-01, final_inner_loss: 6.866e-01, test_acc: 71.4
# step: 196, dt: 2.2s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.260e-01, final_inner_loss: 6.902e-01, test_acc: 71.8
# step: 197, dt: 2.1s, meta_grad_norm: 2.8e-01, mean_inner_loss: 8.231e-01, final_inner_loss: 6.361e-01, test_acc: 71.4
# step: 198, dt: 1.9s, meta_grad_norm: 4.3e-02, mean_inner_loss: 8.248e-01, final_inner_loss: 6.124e-01, test_acc: 71.0
# step: 199, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.214e-01, final_inner_loss: 6.094e-01, test_acc: 70.6
# step: 200, dt: 2.0s, meta_grad_norm: 2.7e-01, mean_inner_loss: 8.175e-01, final_inner_loss: 6.064e-01, test_acc: 69.4
# step: 201, dt: 1.9s, meta_grad_norm: 4.1e-02, mean_inner_loss: 8.167e-01, final_inner_loss: 6.662e-01, test_acc: 69.0
# step: 202, dt: 2.2s, meta_grad_norm: 4.9e-02, mean_inner_loss: 8.169e-01, final_inner_loss: 7.031e-01, test_acc: 69.6
# step: 203, dt: 2.1s, meta_grad_norm: 3.1e-02, mean_inner_loss: 8.163e-01, final_inner_loss: 6.746e-01, test_acc: 70.4
# step: 204, dt: 1.9s, meta_grad_norm: 9.2e-02, mean_inner_loss: 8.138e-01, final_inner_loss: 6.629e-01, test_acc: 70.0
# step: 205, dt: 1.9s, meta_grad_norm: 8.2e-02, mean_inner_loss: 8.162e-01, final_inner_loss: 6.789e-01, test_acc: 70.4
# step: 206, dt: 1.9s, meta_grad_norm: 1.7e-01, mean_inner_loss: 8.056e-01, final_inner_loss: 6.866e-01, test_acc: 68.0
# step: 207, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.155e-01, final_inner_loss: 6.428e-01, test_acc: 69.2
# step: 208, dt: 2.1s, meta_grad_norm: 1.4e-01, mean_inner_loss: 8.152e-01, final_inner_loss: 6.089e-01, test_acc: 70.4
# step: 209, dt: 2.2s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.206e-01, final_inner_loss: 6.672e-01, test_acc: 71.0
# step: 210, dt: 1.9s, meta_grad_norm: 3.1e-02, mean_inner_loss: 8.125e-01, final_inner_loss: 6.156e-01, test_acc: 69.4
# step: 211, dt: 1.9s, meta_grad_norm: 2.8e-02, mean_inner_loss: 8.158e-01, final_inner_loss: 6.125e-01, test_acc: 69.6
# step: 212, dt: 1.9s, meta_grad_norm: 3.6e-01, mean_inner_loss: 8.144e-01, final_inner_loss: 6.355e-01, test_acc: 69.4
# step: 213, dt: 1.9s, meta_grad_norm: 3.9e-01, mean_inner_loss: 8.512e-01, final_inner_loss: 6.617e-01, test_acc: 68.0
# step: 214, dt: 2.0s, meta_grad_norm: 1.4e-02, mean_inner_loss: 8.171e-01, final_inner_loss: 5.866e-01, test_acc: 70.0
# step: 215, dt: 2.3s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.197e-01, final_inner_loss: 6.084e-01, test_acc: 68.8
# step: 216, dt: 1.9s, meta_grad_norm: 7.4e-02, mean_inner_loss: 8.133e-01, final_inner_loss: 5.910e-01, test_acc: 68.2
# step: 217, dt: 1.9s, meta_grad_norm: 6.1e-03, mean_inner_loss: 8.152e-01, final_inner_loss: 6.248e-01, test_acc: 69.4
# step: 218, dt: 1.9s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.152e-01, final_inner_loss: 6.276e-01, test_acc: 69.6
# step: 219, dt: 1.9s, meta_grad_norm: 9.3e-02, mean_inner_loss: 8.124e-01, final_inner_loss: 6.620e-01, test_acc: 69.2
# step: 220, dt: 1.9s, meta_grad_norm: 2.2e+00, mean_inner_loss: 8.057e-01, final_inner_loss: 7.286e-01, test_acc: 66.6
# step: 221, dt: 2.4s, meta_grad_norm: 4.6e-02, mean_inner_loss: 8.237e-01, final_inner_loss: 7.087e-01, test_acc: 71.0
# step: 222, dt: 2.0s, meta_grad_norm: 5.3e-02, mean_inner_loss: 8.212e-01, final_inner_loss: 7.129e-01, test_acc: 72.0
# step: 223, dt: 1.9s, meta_grad_norm: 3.0e-02, mean_inner_loss: 8.221e-01, final_inner_loss: 6.897e-01, test_acc: 69.4
# step: 224, dt: 1.9s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.229e-01, final_inner_loss: 7.219e-01, test_acc: 73.0
# step: 225, dt: 1.9s, meta_grad_norm: 9.6e-03, mean_inner_loss: 8.201e-01, final_inner_loss: 7.038e-01, test_acc: 71.4
# step: 226, dt: 1.9s, meta_grad_norm: 5.0e-02, mean_inner_loss: 8.207e-01, final_inner_loss: 7.127e-01, test_acc: 70.8
# step: 227, dt: 2.3s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.238e-01, final_inner_loss: 6.885e-01, test_acc: 72.0
# step: 228, dt: 2.1s, meta_grad_norm: 1.4e+00, mean_inner_loss: 8.215e-01, final_inner_loss: 7.248e-01, test_acc: 70.8
# step: 229, dt: 1.9s, meta_grad_norm: 3.3e-02, mean_inner_loss: 8.513e-01, final_inner_loss: 8.019e-01, test_acc: 68.6
# step: 230, dt: 1.9s, meta_grad_norm: 1.4e-02, mean_inner_loss: 8.485e-01, final_inner_loss: 7.841e-01, test_acc: 69.0
# step: 231, dt: 1.9s, meta_grad_norm: 6.0e-02, mean_inner_loss: 8.452e-01, final_inner_loss: 8.230e-01, test_acc: 69.0
# step: 232, dt: 1.9s, meta_grad_norm: 6.3e-01, mean_inner_loss: 8.424e-01, final_inner_loss: 7.649e-01, test_acc: 68.2
# step: 233, dt: 2.2s, meta_grad_norm: 2.6e-02, mean_inner_loss: 8.430e-01, final_inner_loss: 7.527e-01, test_acc: 68.4
# step: 234, dt: 2.1s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.309e-01, final_inner_loss: 6.852e-01, test_acc: 70.0
# step: 235, dt: 1.9s, meta_grad_norm: 9.7e-01, mean_inner_loss: 8.150e-01, final_inner_loss: 7.266e-01, test_acc: 68.4
# step: 236, dt: 1.9s, meta_grad_norm: 6.3e-01, mean_inner_loss: 9.079e-01, final_inner_loss: 7.825e-01, test_acc: 64.8
# step: 237, dt: 1.9s, meta_grad_norm: 9.8e-02, mean_inner_loss: 8.119e-01, final_inner_loss: 7.426e-01, test_acc: 73.4
# step: 238, dt: 1.9s, meta_grad_norm: 3.5e-02, mean_inner_loss: 8.251e-01, final_inner_loss: 7.362e-01, test_acc: 69.0
# step: 239, dt: 2.1s, meta_grad_norm: 2.8e-01, mean_inner_loss: 8.208e-01, final_inner_loss: 7.743e-01, test_acc: 66.6
# step: 240, dt: 2.3s, meta_grad_norm: 2.4e-01, mean_inner_loss: 8.090e-01, final_inner_loss: 7.069e-01, test_acc: 68.6
# step: 241, dt: 1.9s, meta_grad_norm: 2.6e-01, mean_inner_loss: 7.924e-01, final_inner_loss: 6.175e-01, test_acc: 69.8
# step: 242, dt: 1.9s, meta_grad_norm: 6.4e-01, mean_inner_loss: 7.997e-01, final_inner_loss: 6.518e-01, test_acc: 68.4
# step: 243, dt: 1.9s, meta_grad_norm: 1.2e+00, mean_inner_loss: 9.629e-01, final_inner_loss: 7.297e-01, test_acc: 62.6
# step: 244, dt: 1.9s, meta_grad_norm: 8.2e-02, mean_inner_loss: 8.007e-01, final_inner_loss: 6.966e-01, test_acc: 70.4
# step: 245, dt: 2.0s, meta_grad_norm: 2.9e-01, mean_inner_loss: 8.352e-01, final_inner_loss: 6.837e-01, test_acc: 66.8
# step: 246, dt: 2.3s, meta_grad_norm: 9.8e-01, mean_inner_loss: 9.501e-01, final_inner_loss: 7.182e-01, test_acc: 63.8
# step: 247, dt: 1.9s, meta_grad_norm: 8.9e-01, mean_inner_loss: 7.922e-01, final_inner_loss: 6.639e-01, test_acc: 69.0
# step: 248, dt: 1.9s, meta_grad_norm: 9.3e-01, mean_inner_loss: 9.391e-01, final_inner_loss: 7.527e-01, test_acc: 64.4
# step: 249, dt: 1.9s, meta_grad_norm: 8.8e-01, mean_inner_loss: 7.919e-01, final_inner_loss: 6.400e-01, test_acc: 70.4
# step: 250, dt: 1.9s, meta_grad_norm: 1.5e-01, mean_inner_loss: 8.174e-01, final_inner_loss: 6.840e-01, test_acc: 68.0
# step: 251, dt: 1.9s, meta_grad_norm: 2.4e-02, mean_inner_loss: 8.138e-01, final_inner_loss: 7.292e-01, test_acc: 70.2
# step: 252, dt: 2.4s, meta_grad_norm: 6.5e-02, mean_inner_loss: 8.121e-01, final_inner_loss: 6.809e-01, test_acc: 70.6
# step: 253, dt: 1.9s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.104e-01, final_inner_loss: 7.119e-01, test_acc: 69.4
# step: 254, dt: 1.9s, meta_grad_norm: 4.6e-02, mean_inner_loss: 8.048e-01, final_inner_loss: 6.870e-01, test_acc: 69.2
# step: 255, dt: 1.9s, meta_grad_norm: 3.3e-02, mean_inner_loss: 8.018e-01, final_inner_loss: 6.791e-01, test_acc: 68.8
# step: 256, dt: 1.9s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.008e-01, final_inner_loss: 6.557e-01, test_acc: 70.2
# step: 257, dt: 1.9s, meta_grad_norm: 4.8e-01, mean_inner_loss: 7.994e-01, final_inner_loss: 6.281e-01, test_acc: 70.4
# step: 258, dt: 2.3s, meta_grad_norm: 6.2e-02, mean_inner_loss: 7.995e-01, final_inner_loss: 6.417e-01, test_acc: 70.6
# step: 259, dt: 2.0s, meta_grad_norm: 8.3e-02, mean_inner_loss: 7.992e-01, final_inner_loss: 6.172e-01, test_acc: 71.2
# step: 260, dt: 1.9s, meta_grad_norm: 7.7e-01, mean_inner_loss: 7.941e-01, final_inner_loss: 6.395e-01, test_acc: 70.2
# step: 261, dt: 1.9s, meta_grad_norm: 5.3e-01, mean_inner_loss: 8.093e-01, final_inner_loss: 6.596e-01, test_acc: 67.0
# step: 262, dt: 1.9s, meta_grad_norm: 1.5e-01, mean_inner_loss: 7.909e-01, final_inner_loss: 5.691e-01, test_acc: 71.2
# step: 263, dt: 1.9s, meta_grad_norm: 1.4e+00, mean_inner_loss: 7.803e-01, final_inner_loss: 6.675e-01, test_acc: 68.4
# step: 264, dt: 2.1s, meta_grad_norm: 6.0e-02, mean_inner_loss: 8.221e-01, final_inner_loss: 6.813e-01, test_acc: 69.2
# step: 265, dt: 2.2s, meta_grad_norm: 5.3e-01, mean_inner_loss: 7.978e-01, final_inner_loss: 6.480e-01, test_acc: 70.4
# step: 266, dt: 1.9s, meta_grad_norm: 6.9e-01, mean_inner_loss: 7.956e-01, final_inner_loss: 7.818e-01, test_acc: 67.2
# step: 267, dt: 1.9s, meta_grad_norm: 1.3e+00, mean_inner_loss: 7.944e-01, final_inner_loss: 6.273e-01, test_acc: 71.6
# step: 268, dt: 1.9s, meta_grad_norm: 9.0e-02, mean_inner_loss: 8.090e-01, final_inner_loss: 6.711e-01, test_acc: 68.4
# step: 269, dt: 1.9s, meta_grad_norm: 3.0e-02, mean_inner_loss: 8.074e-01, final_inner_loss: 6.431e-01, test_acc: 70.0
# step: 270, dt: 2.1s, meta_grad_norm: 2.5e-01, mean_inner_loss: 8.058e-01, final_inner_loss: 6.632e-01, test_acc: 70.4
# step: 271, dt: 2.2s, meta_grad_norm: 7.6e-01, mean_inner_loss: 8.058e-01, final_inner_loss: 5.896e-01, test_acc: 70.2
# step: 272, dt: 1.9s, meta_grad_norm: 4.9e-01, mean_inner_loss: 8.042e-01, final_inner_loss: 6.359e-01, test_acc: 70.0
# step: 273, dt: 1.9s, meta_grad_norm: 4.9e-02, mean_inner_loss: 7.992e-01, final_inner_loss: 6.232e-01, test_acc: 70.0
# step: 274, dt: 1.9s, meta_grad_norm: 7.1e-02, mean_inner_loss: 8.022e-01, final_inner_loss: 5.809e-01, test_acc: 70.8
# step: 275, dt: 1.9s, meta_grad_norm: 1.1e-01, mean_inner_loss: 7.975e-01, final_inner_loss: 6.155e-01, test_acc: 69.6
# step: 276, dt: 1.9s, meta_grad_norm: 1.4e-01, mean_inner_loss: 8.044e-01, final_inner_loss: 6.311e-01, test_acc: 70.2
# step: 277, dt: 2.4s, meta_grad_norm: 2.4e-01, mean_inner_loss: 8.044e-01, final_inner_loss: 6.124e-01, test_acc: 69.4
# step: 278, dt: 1.9s, meta_grad_norm: 6.3e-01, mean_inner_loss: 8.034e-01, final_inner_loss: 6.255e-01, test_acc: 69.2
# step: 279, dt: 1.9s, meta_grad_norm: 1.2e-01, mean_inner_loss: 7.963e-01, final_inner_loss: 6.261e-01, test_acc: 70.8
# step: 280, dt: 2.0s, meta_grad_norm: 1.0e+00, mean_inner_loss: 8.088e-01, final_inner_loss: 5.807e-01, test_acc: 71.2
# step: 281, dt: 1.9s, meta_grad_norm: 3.6e-02, mean_inner_loss: 7.961e-01, final_inner_loss: 6.862e-01, test_acc: 69.2
# step: 282, dt: 1.9s, meta_grad_norm: 3.7e-02, mean_inner_loss: 7.898e-01, final_inner_loss: 6.430e-01, test_acc: 68.6
# step: 283, dt: 2.4s, meta_grad_norm: 1.1e-02, mean_inner_loss: 7.948e-01, final_inner_loss: 6.394e-01, test_acc: 68.4
# step: 284, dt: 2.0s, meta_grad_norm: 1.8e-01, mean_inner_loss: 7.894e-01, final_inner_loss: 6.301e-01, test_acc: 71.4
# step: 285, dt: 1.9s, meta_grad_norm: 3.7e-01, mean_inner_loss: 7.763e-01, final_inner_loss: 6.446e-01, test_acc: 68.2
# step: 286, dt: 1.9s, meta_grad_norm: 5.9e-01, mean_inner_loss: 8.196e-01, final_inner_loss: 6.422e-01, test_acc: 66.2
# step: 287, dt: 1.9s, meta_grad_norm: 1.4e-01, mean_inner_loss: 7.780e-01, final_inner_loss: 6.297e-01, test_acc: 67.2
# step: 288, dt: 1.9s, meta_grad_norm: 1.2e-01, mean_inner_loss: 7.790e-01, final_inner_loss: 5.304e-01, test_acc: 72.0
# step: 289, dt: 2.3s, meta_grad_norm: 6.8e-01, mean_inner_loss: 8.022e-01, final_inner_loss: 6.263e-01, test_acc: 66.6
# step: 290, dt: 2.1s, meta_grad_norm: 1.3e+00, mean_inner_loss: 8.786e-01, final_inner_loss: 7.555e-01, test_acc: 67.0
# step: 291, dt: 1.9s, meta_grad_norm: 3.9e-01, mean_inner_loss: 7.707e-01, final_inner_loss: 6.414e-01, test_acc: 69.6
# step: 292, dt: 1.9s, meta_grad_norm: 8.8e-01, mean_inner_loss: 7.801e-01, final_inner_loss: 6.259e-01, test_acc: 66.6
# step: 293, dt: 1.9s, meta_grad_norm: 9.4e-01, mean_inner_loss: 7.991e-01, final_inner_loss: 6.532e-01, test_acc: 68.6
# step: 294, dt: 1.9s, meta_grad_norm: 7.8e-02, mean_inner_loss: 8.128e-01, final_inner_loss: 5.832e-01, test_acc: 67.6
# step: 295, dt: 2.1s, meta_grad_norm: 6.4e-01, mean_inner_loss: 8.392e-01, final_inner_loss: 6.930e-01, test_acc: 66.2
# step: 296, dt: 2.1s, meta_grad_norm: 1.4e-01, mean_inner_loss: 7.677e-01, final_inner_loss: 6.030e-01, test_acc: 69.8
# step: 297, dt: 1.9s, meta_grad_norm: 4.3e-01, mean_inner_loss: 7.752e-01, final_inner_loss: 6.352e-01, test_acc: 68.2
# step: 298, dt: 1.9s, meta_grad_norm: 1.6e-01, mean_inner_loss: 7.881e-01, final_inner_loss: 6.342e-01, test_acc: 69.0
# step: 299, dt: 1.9s, meta_grad_norm: 1.5e-01, mean_inner_loss: 7.855e-01, final_inner_loss: 6.233e-01, test_acc: 69.8
# step: 300, dt: 1.9s, meta_grad_norm: 2.2e-01, mean_inner_loss: 7.887e-01, final_inner_loss: 6.026e-01, test_acc: 71.4

# %%
import pickle

# Save results using pickle
with open('hs_results_200.pkl', 'wb') as f:
    pickle.dump(hs_results_200, f)

print("Results saved to 'hs_results_200.pkl'")
# Out:
# Results saved to 'hs_results_200.pkl'

# %%
# Load results from pickle file
with open('hs_results_200.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
hs_results_200['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    hs_results_200['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(hs_results_200['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 0.8802562155992881
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.3054345, 1.331469, 1.4820358, 1.7095675, 1.5276744, 1.7855346]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(hs_results_200, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 69.0
