# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
   # h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1) #noise removed
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 128,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.4,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
noise_removed_results = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 2.8s, meta_grad_norm: 1.4e-01, mean_inner_loss: 1.350e+00, final_inner_loss: 1.334e+00, test_acc: 50.0
# step: 1, dt: 1.6s, meta_grad_norm: 7.1e-02, mean_inner_loss: 1.307e+00, final_inner_loss: 1.286e+00, test_acc: 51.4
# step: 2, dt: 4.0s, meta_grad_norm: 2.0e-01, mean_inner_loss: 1.300e+00, final_inner_loss: 1.283e+00, test_acc: 52.2
# step: 3, dt: 3.2s, meta_grad_norm: 1.2e-01, mean_inner_loss: 1.260e+00, final_inner_loss: 1.198e+00, test_acc: 54.8
# step: 4, dt: 2.1s, meta_grad_norm: 9.6e-02, mean_inner_loss: 1.232e+00, final_inner_loss: 1.168e+00, test_acc: 55.8
# step: 5, dt: 1.6s, meta_grad_norm: 9.1e-02, mean_inner_loss: 1.204e+00, final_inner_loss: 1.143e+00, test_acc: 56.4
# step: 6, dt: 1.6s, meta_grad_norm: 7.9e-02, mean_inner_loss: 1.178e+00, final_inner_loss: 1.117e+00, test_acc: 58.6
# step: 7, dt: 1.9s, meta_grad_norm: 6.5e-02, mean_inner_loss: 1.155e+00, final_inner_loss: 1.101e+00, test_acc: 59.0
# step: 8, dt: 2.8s, meta_grad_norm: 1.1e-01, mean_inner_loss: 1.132e+00, final_inner_loss: 1.068e+00, test_acc: 60.0
# step: 9, dt: 1.8s, meta_grad_norm: 1.7e-01, mean_inner_loss: 1.093e+00, final_inner_loss: 1.023e+00, test_acc: 60.6
# step: 31, dt: 1.8s, meta_grad_norm: 4.5e-02, mean_inner_loss: 9.971e-01, final_inner_loss: 9.001e-01, test_acc: 64.2
# step: 32, dt: 2.3s, meta_grad_norm: 1.0e-01, mean_inner_loss: 9.810e-01, final_inner_loss: 8.847e-01, test_acc: 63.6
# step: 33, dt: 3.3s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.802e-01, final_inner_loss: 9.099e-01, test_acc: 65.4
# step: 34, dt: 1.7s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.889e-01, final_inner_loss: 9.022e-01, test_acc: 65.2
# step: 35, dt: 1.8s, meta_grad_norm: 3.3e-01, mean_inner_loss: 9.753e-01, final_inner_loss: 8.975e-01, test_acc: 64.4
# step: 36, dt: 1.6s, meta_grad_norm: 4.2e-02, mean_inner_loss: 9.987e-01, final_inner_loss: 9.183e-01, test_acc: 63.2
# step: 37, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.944e-01, final_inner_loss: 9.108e-01, test_acc: 63.2
# step: 38, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.898e-01, final_inner_loss: 9.038e-01, test_acc: 64.2
# step: 39, dt: 1.9s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.784e-01, final_inner_loss: 8.820e-01, test_acc: 64.4
# step: 40, dt: 2.1s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.790e-01, final_inner_loss: 9.232e-01, test_acc: 66.0
# step: 41, dt: 1.6s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.841e-01, final_inner_loss: 9.367e-01, test_acc: 65.2
# step: 42, dt: 1.6s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.672e-01, final_inner_loss: 8.700e-01, test_acc: 65.6
# step: 43, dt: 1.6s, meta_grad_norm: 9.2e-02, mean_inner_loss: 9.677e-01, final_inner_loss: 8.777e-01, test_acc: 65.6
# step: 44, dt: 1.6s, meta_grad_norm: 9.5e-02, mean_inner_loss: 9.741e-01, final_inner_loss: 8.809e-01, test_acc: 65.2
# step: 45, dt: 1.6s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.663e-01, final_inner_loss: 8.760e-01, test_acc: 65.8
# step: 46, dt: 2.1s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.815e-01, final_inner_loss: 8.865e-01, test_acc: 66.0
# step: 47, dt: 2.1s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.621e-01, final_inner_loss: 8.624e-01, test_acc: 64.8
# step: 48, dt: 1.7s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.792e-01, final_inner_loss: 8.873e-01, test_acc: 66.4
# step: 49, dt: 1.6s, meta_grad_norm: 4.2e-02, mean_inner_loss: 9.638e-01, final_inner_loss: 8.617e-01, test_acc: 67.0
# step: 50, dt: 1.6s, meta_grad_norm: 4.6e-02, mean_inner_loss: 9.590e-01, final_inner_loss: 8.597e-01, test_acc: 66.0
# step: 194, dt: 1.6s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.776e-01, final_inner_loss: 7.784e-01, test_acc: 66.8
# step: 195, dt: 1.6s, meta_grad_norm: 2.4e-01, mean_inner_loss: 8.820e-01, final_inner_loss: 7.681e-01, test_acc: 66.6
# step: 196, dt: 1.6s, meta_grad_norm: 4.8e-01, mean_inner_loss: 8.974e-01, final_inner_loss: 8.208e-01, test_acc: 68.2
# step: 197, dt: 1.6s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.800e-01, final_inner_loss: 7.317e-01, test_acc: 68.6
# step: 198, dt: 1.8s, meta_grad_norm: 3.5e-01, mean_inner_loss: 8.806e-01, final_inner_loss: 7.572e-01, test_acc: 67.6
# step: 199, dt: 2.1s, meta_grad_norm: 5.2e-02, mean_inner_loss: 8.885e-01, final_inner_loss: 7.667e-01, test_acc: 65.8
# step: 200, dt: 1.7s, meta_grad_norm: 5.0e-01, mean_inner_loss: 8.737e-01, final_inner_loss: 7.534e-01, test_acc: 66.4
# step: 201, dt: 1.6s, meta_grad_norm: 2.4e-01, mean_inner_loss: 8.943e-01, final_inner_loss: 7.905e-01, test_acc: 65.2
# step: 202, dt: 1.6s, meta_grad_norm: 6.5e-01, mean_inner_loss: 9.035e-01, final_inner_loss: 7.649e-01, test_acc: 69.0
# step: 203, dt: 1.6s, meta_grad_norm: 3.2e-02, mean_inner_loss: 8.925e-01, final_inner_loss: 7.834e-01, test_acc: 68.4
# step: 204, dt: 1.7s, meta_grad_norm: 6.0e-03, mean_inner_loss: 8.887e-01, final_inner_loss: 8.003e-01, test_acc: 69.0
# step: 205, dt: 1.6s, meta_grad_norm: 7.2e-02, mean_inner_loss: 8.846e-01, final_inner_loss: 7.589e-01, test_acc: 68.8
# step: 206, dt: 2.1s, meta_grad_norm: 2.4e-02, mean_inner_loss: 8.753e-01, final_inner_loss: 7.440e-01, test_acc: 65.0
# step: 207, dt: 1.8s, meta_grad_norm: 1.2e-01, mean_inner_loss: 8.729e-01, final_inner_loss: 7.613e-01, test_acc: 67.0
# step: 208, dt: 1.6s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.824e-01, final_inner_loss: 7.469e-01, test_acc: 67.0
# step: 209, dt: 1.6s, meta_grad_norm: 4.9e-02, mean_inner_loss: 8.802e-01, final_inner_loss: 7.685e-01, test_acc: 66.8
# step: 210, dt: 1.7s, meta_grad_norm: 4.1e-01, mean_inner_loss: 8.759e-01, final_inner_loss: 7.795e-01, test_acc: 67.8
# step: 211, dt: 1.6s, meta_grad_norm: 3.0e-01, mean_inner_loss: 8.905e-01, final_inner_loss: 8.440e-01, test_acc: 67.2
# step: 212, dt: 1.6s, meta_grad_norm: 5.6e-03, mean_inner_loss: 8.750e-01, final_inner_loss: 7.517e-01, test_acc: 66.2
# step: 213, dt: 1.9s, meta_grad_norm: 5.3e-02, mean_inner_loss: 8.726e-01, final_inner_loss: 7.284e-01, test_acc: 67.2
# step: 214, dt: 1.9s, meta_grad_norm: 3.4e-01, mean_inner_loss: 8.807e-01, final_inner_loss: 7.894e-01, test_acc: 65.2
# step: 215, dt: 1.6s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.926e-01, final_inner_loss: 7.516e-01, test_acc: 66.0
# step: 216, dt: 1.6s, meta_grad_norm: 1.5e+00, mean_inner_loss: 8.734e-01, final_inner_loss: 7.208e-01, test_acc: 67.2
# step: 217, dt: 1.6s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.610e-01, final_inner_loss: 9.182e-01, test_acc: 63.0
# step: 218, dt: 1.6s, meta_grad_norm: 4.9e-01, mean_inner_loss: 9.137e-01, final_inner_loss: 8.529e-01, test_acc: 66.4
# step: 219, dt: 1.6s, meta_grad_norm: 6.0e-02, mean_inner_loss: 8.752e-01, final_inner_loss: 7.853e-01, test_acc: 65.6
# step: 220, dt: 1.8s, meta_grad_norm: 9.6e-02, mean_inner_loss: 8.679e-01, final_inner_loss: 7.214e-01, test_acc: 68.6
# step: 221, dt: 2.1s, meta_grad_norm: 4.7e-02, mean_inner_loss: 8.908e-01, final_inner_loss: 7.504e-01, test_acc: 63.6
# step: 222, dt: 1.7s, meta_grad_norm: 4.0e-01, mean_inner_loss: 9.057e-01, final_inner_loss: 8.848e-01, test_acc: 67.2
# step: 223, dt: 1.6s, meta_grad_norm: 5.4e-01, mean_inner_loss: 8.718e-01, final_inner_loss: 7.902e-01, test_acc: 66.4
# step: 224, dt: 1.6s, meta_grad_norm: 5.1e-02, mean_inner_loss: 8.874e-01, final_inner_loss: 6.922e-01, test_acc: 68.8
# step: 225, dt: 1.6s, meta_grad_norm: 8.0e-01, mean_inner_loss: 8.816e-01, final_inner_loss: 7.204e-01, test_acc: 67.0
# step: 226, dt: 1.6s, meta_grad_norm: 1.8e-01, mean_inner_loss: 9.266e-01, final_inner_loss: 8.784e-01, test_acc: 65.0
# step: 227, dt: 1.6s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.047e-01, final_inner_loss: 7.727e-01, test_acc: 68.2
# step: 228, dt: 2.1s, meta_grad_norm: 8.4e-01, mean_inner_loss: 8.853e-01, final_inner_loss: 6.787e-01, test_acc: 68.0
# step: 229, dt: 1.7s, meta_grad_norm: 3.8e-02, mean_inner_loss: 8.845e-01, final_inner_loss: 7.698e-01, test_acc: 69.4
# step: 230, dt: 1.6s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.788e-01, final_inner_loss: 7.764e-01, test_acc: 68.6
# step: 231, dt: 1.6s, meta_grad_norm: 5.0e-03, mean_inner_loss: 8.780e-01, final_inner_loss: 7.799e-01, test_acc: 68.4
# step: 232, dt: 1.6s, meta_grad_norm: 7.4e-03, mean_inner_loss: 8.772e-01, final_inner_loss: 7.600e-01, test_acc: 68.6
# step: 233, dt: 1.6s, meta_grad_norm: 2.3e-02, mean_inner_loss: 8.766e-01, final_inner_loss: 7.829e-01, test_acc: 68.8
# step: 234, dt: 1.6s, meta_grad_norm: 1.1e-01, mean_inner_loss: 8.825e-01, final_inner_loss: 7.884e-01, test_acc: 66.0
# step: 235, dt: 1.9s, meta_grad_norm: 3.5e-02, mean_inner_loss: 8.813e-01, final_inner_loss: 7.812e-01, test_acc: 69.8
# step: 236, dt: 1.9s, meta_grad_norm: 9.6e-03, mean_inner_loss: 8.770e-01, final_inner_loss: 7.516e-01, test_acc: 68.2
# step: 237, dt: 1.6s, meta_grad_norm: 6.0e-03, mean_inner_loss: 8.762e-01, final_inner_loss: 7.723e-01, test_acc: 66.2
# step: 238, dt: 1.6s, meta_grad_norm: 7.8e-03, mean_inner_loss: 8.747e-01, final_inner_loss: 7.927e-01, test_acc: 67.6
# step: 239, dt: 1.6s, meta_grad_norm: 1.8e-01, mean_inner_loss: 8.748e-01, final_inner_loss: 8.148e-01, test_acc: 68.6
# step: 240, dt: 1.7s, meta_grad_norm: 7.3e-02, mean_inner_loss: 8.916e-01, final_inner_loss: 8.108e-01, test_acc: 67.6
# step: 241, dt: 1.6s, meta_grad_norm: 2.0e-02, mean_inner_loss: 8.879e-01, final_inner_loss: 7.826e-01, test_acc: 69.8
# step: 242, dt: 1.9s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.837e-01, final_inner_loss: 7.460e-01, test_acc: 68.4
# step: 243, dt: 2.0s, meta_grad_norm: 6.3e-02, mean_inner_loss: 8.823e-01, final_inner_loss: 7.839e-01, test_acc: 69.6
# step: 244, dt: 1.6s, meta_grad_norm: 5.5e-02, mean_inner_loss: 8.705e-01, final_inner_loss: 7.489e-01, test_acc: 67.0
# step: 245, dt: 1.6s, meta_grad_norm: 7.1e-02, mean_inner_loss: 8.678e-01, final_inner_loss: 7.199e-01, test_acc: 66.6
# step: 246, dt: 1.6s, meta_grad_norm: 4.3e-02, mean_inner_loss: 8.710e-01, final_inner_loss: 7.694e-01, test_acc: 68.2
# step: 247, dt: 1.6s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.644e-01, final_inner_loss: 7.459e-01, test_acc: 67.6
# step: 248, dt: 1.7s, meta_grad_norm: 2.6e-01, mean_inner_loss: 8.650e-01, final_inner_loss: 7.139e-01, test_acc: 67.0
# step: 249, dt: 1.8s, meta_grad_norm: 5.3e-02, mean_inner_loss: 8.661e-01, final_inner_loss: 7.604e-01, test_acc: 66.4
# step: 250, dt: 2.1s, meta_grad_norm: 2.1e-01, mean_inner_loss: 8.709e-01, final_inner_loss: 7.939e-01, test_acc: 68.2
# step: 251, dt: 1.7s, meta_grad_norm: 5.8e-02, mean_inner_loss: 8.642e-01, final_inner_loss: 7.486e-01, test_acc: 67.2
# step: 252, dt: 1.6s, meta_grad_norm: 5.8e-01, mean_inner_loss: 8.655e-01, final_inner_loss: 8.182e-01, test_acc: 67.6
# step: 253, dt: 1.7s, meta_grad_norm: 2.0e+00, mean_inner_loss: 9.074e-01, final_inner_loss: 8.871e-01, test_acc: 68.8
# step: 254, dt: 1.6s, meta_grad_norm: 2.0e-01, mean_inner_loss: 8.859e-01, final_inner_loss: 7.707e-01, test_acc: 67.0
# step: 255, dt: 1.6s, meta_grad_norm: 8.4e-01, mean_inner_loss: 8.604e-01, final_inner_loss: 7.033e-01, test_acc: 66.0
# step: 256, dt: 1.6s, meta_grad_norm: 2.0e-02, mean_inner_loss: 8.768e-01, final_inner_loss: 7.684e-01, test_acc: 68.6
# step: 257, dt: 2.1s, meta_grad_norm: 1.4e+00, mean_inner_loss: 8.764e-01, final_inner_loss: 8.118e-01, test_acc: 67.8
# step: 258, dt: 1.9s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.069e-01, final_inner_loss: 7.822e-01, test_acc: 66.8
# step: 259, dt: 1.6s, meta_grad_norm: 6.6e-02, mean_inner_loss: 9.066e-01, final_inner_loss: 8.117e-01, test_acc: 69.4
# step: 260, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.034e-01, final_inner_loss: 7.914e-01, test_acc: 66.4
# step: 261, dt: 1.6s, meta_grad_norm: 5.9e-02, mean_inner_loss: 8.993e-01, final_inner_loss: 7.664e-01, test_acc: 70.0
# step: 262, dt: 1.6s, meta_grad_norm: 7.1e-02, mean_inner_loss: 8.875e-01, final_inner_loss: 7.589e-01, test_acc: 67.4
# step: 263, dt: 1.7s, meta_grad_norm: 2.7e-02, mean_inner_loss: 8.885e-01, final_inner_loss: 7.444e-01, test_acc: 66.6
# step: 264, dt: 1.9s, meta_grad_norm: 2.8e-02, mean_inner_loss: 8.894e-01, final_inner_loss: 7.957e-01, test_acc: 69.0
# step: 265, dt: 1.9s, meta_grad_norm: 2.5e-02, mean_inner_loss: 8.891e-01, final_inner_loss: 7.471e-01, test_acc: 67.0
# step: 266, dt: 1.6s, meta_grad_norm: 8.7e-03, mean_inner_loss: 8.878e-01, final_inner_loss: 7.660e-01, test_acc: 67.6
# step: 267, dt: 1.6s, meta_grad_norm: 5.7e-02, mean_inner_loss: 8.879e-01, final_inner_loss: 7.284e-01, test_acc: 66.4
# step: 268, dt: 1.6s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.871e-01, final_inner_loss: 7.552e-01, test_acc: 67.6
# step: 269, dt: 1.6s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.859e-01, final_inner_loss: 7.611e-01, test_acc: 67.2
# step: 270, dt: 1.6s, meta_grad_norm: 8.3e-03, mean_inner_loss: 8.935e-01, final_inner_loss: 7.598e-01, test_acc: 67.6
# step: 271, dt: 1.9s, meta_grad_norm: 3.1e-02, mean_inner_loss: 8.947e-01, final_inner_loss: 7.758e-01, test_acc: 68.6
# step: 272, dt: 2.0s, meta_grad_norm: 9.5e-02, mean_inner_loss: 8.902e-01, final_inner_loss: 7.210e-01, test_acc: 68.8
# step: 273, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.845e-01, final_inner_loss: 7.496e-01, test_acc: 66.0
# step: 274, dt: 1.7s, meta_grad_norm: 9.7e-03, mean_inner_loss: 8.835e-01, final_inner_loss: 7.479e-01, test_acc: 67.6
# step: 275, dt: 1.7s, meta_grad_norm: 7.1e-03, mean_inner_loss: 8.841e-01, final_inner_loss: 7.497e-01, test_acc: 68.0
# step: 276, dt: 1.6s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.821e-01, final_inner_loss: 7.360e-01, test_acc: 67.0
# step: 277, dt: 1.6s, meta_grad_norm: 3.2e-02, mean_inner_loss: 8.819e-01, final_inner_loss: 7.400e-01, test_acc: 68.8
# step: 278, dt: 1.8s, meta_grad_norm: 4.3e-02, mean_inner_loss: 8.836e-01, final_inner_loss: 7.438e-01, test_acc: 68.4
# step: 279, dt: 2.1s, meta_grad_norm: 5.3e-03, mean_inner_loss: 8.831e-01, final_inner_loss: 7.452e-01, test_acc: 67.2
# step: 280, dt: 1.8s, meta_grad_norm: 3.0e-02, mean_inner_loss: 8.821e-01, final_inner_loss: 7.482e-01, test_acc: 68.6
# step: 281, dt: 1.6s, meta_grad_norm: 2.6e-02, mean_inner_loss: 8.829e-01, final_inner_loss: 7.623e-01, test_acc: 68.6
# step: 282, dt: 1.6s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.877e-01, final_inner_loss: 7.553e-01, test_acc: 68.6
# step: 283, dt: 1.6s, meta_grad_norm: 1.2e-02, mean_inner_loss: 8.880e-01, final_inner_loss: 7.530e-01, test_acc: 66.6
# step: 284, dt: 1.7s, meta_grad_norm: 7.3e-03, mean_inner_loss: 8.848e-01, final_inner_loss: 7.294e-01, test_acc: 67.6
# step: 285, dt: 1.6s, meta_grad_norm: 4.1e-03, mean_inner_loss: 8.830e-01, final_inner_loss: 7.558e-01, test_acc: 68.6
# step: 286, dt: 2.0s, meta_grad_norm: 1.0e-01, mean_inner_loss: 8.829e-01, final_inner_loss: 7.506e-01, test_acc: 67.4
# step: 287, dt: 1.8s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.823e-01, final_inner_loss: 7.611e-01, test_acc: 65.8
# step: 288, dt: 1.6s, meta_grad_norm: 8.9e-03, mean_inner_loss: 8.837e-01, final_inner_loss: 7.709e-01, test_acc: 66.8
# step: 289, dt: 1.6s, meta_grad_norm: 3.4e-02, mean_inner_loss: 8.825e-01, final_inner_loss: 8.044e-01, test_acc: 69.4
# step: 290, dt: 1.6s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.777e-01, final_inner_loss: 7.525e-01, test_acc: 67.4
# step: 291, dt: 1.7s, meta_grad_norm: 6.6e-03, mean_inner_loss: 8.798e-01, final_inner_loss: 7.263e-01, test_acc: 68.0
# step: 292, dt: 1.6s, meta_grad_norm: 8.8e-01, mean_inner_loss: 8.812e-01, final_inner_loss: 7.340e-01, test_acc: 69.6
# step: 293, dt: 1.9s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.675e-01, final_inner_loss: 7.383e-01, test_acc: 66.4
# step: 294, dt: 2.0s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.609e-01, final_inner_loss: 7.222e-01, test_acc: 67.2
# step: 295, dt: 1.6s, meta_grad_norm: 4.9e-02, mean_inner_loss: 8.608e-01, final_inner_loss: 6.915e-01, test_acc: 67.2
# step: 296, dt: 1.6s, meta_grad_norm: 6.1e-02, mean_inner_loss: 8.635e-01, final_inner_loss: 6.951e-01, test_acc: 68.4
# step: 297, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 8.613e-01, final_inner_loss: 7.088e-01, test_acc: 68.4
# step: 298, dt: 1.7s, meta_grad_norm: 4.5e-01, mean_inner_loss: 8.615e-01, final_inner_loss: 7.278e-01, test_acc: 67.2
# step: 299, dt: 1.6s, meta_grad_norm: 1.3e+00, mean_inner_loss: 8.607e-01, final_inner_loss: 7.910e-01, test_acc: 67.0
# step: 300, dt: 1.9s, meta_grad_norm: 1.4e-02, mean_inner_loss: 8.687e-01, final_inner_loss: 7.281e-01, test_acc: 66.6

# %%
import pickle
with open('noise_removed_results.pkl', 'wb') as f:
    pickle.dump(noise_removed_results, f)

print("Results saved to 'noise_removed_results.pkl'")
# Out:
# Results saved to 'noise_removed_results.pkl'

# %%
with open('noise_removed_results.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
noise_removed_results['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    noise_removed_results['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(noise_removed_results['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 0.9259590108529278
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.3267955, 1.3618844, 1.4695846, 1.6468078, 1.5183997, 1.7493463]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(noise_removed_results, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Compare the graphs, when noise was present and when noise is absent, for example in Test accuray graph, in case of noise present the accuracy level of tanh and elu overlapped but when noise is absent tanh is mere accurate than elu.
#
# And in learned activation graph the distance between different curves for differnt steps is more then what is observed when noise was present.

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 67.6

# %% [markdown]
# Removing of the statement(h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)) that introduces noise in the network doesn't seem to have much effect on the test accuracy as, with noise acurracy was 67.4 and without noise 67.6.
#
# **In the case of MNIST-1D, the data is relatively simple and low-dimensional, which might make the model more robust to noise**
