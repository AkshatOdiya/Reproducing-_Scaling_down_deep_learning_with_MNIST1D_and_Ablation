# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 128,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.6,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
results_mu_6 = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 3.2s, meta_grad_norm: 1.5e-01, mean_inner_loss: 1.354e+00, final_inner_loss: 1.336e+00, test_acc: 48.6
# step: 1, dt: 2.0s, meta_grad_norm: 1.2e-01, mean_inner_loss: 1.304e+00, final_inner_loss: 1.247e+00, test_acc: 51.0
# step: 2, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 1.269e+00, final_inner_loss: 1.199e+00, test_acc: 54.0
# step: 3, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 1.229e+00, final_inner_loss: 1.137e+00, test_acc: 55.8
# step: 4, dt: 1.8s, meta_grad_norm: 1.6e-01, mean_inner_loss: 1.183e+00, final_inner_loss: 1.076e+00, test_acc: 59.4
# step: 5, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 1.138e+00, final_inner_loss: 1.034e+00, test_acc: 59.8
# step: 6, dt: 1.8s, meta_grad_norm: 9.3e-02, mean_inner_loss: 1.102e+00, final_inner_loss: 1.015e+00, test_acc: 60.2
# step: 7, dt: 2.2s, meta_grad_norm: 6.5e-02, mean_inner_loss: 1.076e+00, final_inner_loss: 1.015e+00, test_acc: 60.0
# step: 8, dt: 1.8s, meta_grad_norm: 5.6e-02, mean_inner_loss: 1.057e+00, final_inner_loss: 1.023e+00, test_acc: 59.6
# step: 9, dt: 1.7s, meta_grad_norm: 6.9e-02, mean_inner_loss: 1.039e+00, final_inner_loss: 1.018e+00, test_acc: 59.6
# step: 10, dt: 1.9s, meta_grad_norm: 2.0e-02, mean_inner_loss: 1.023e+00, final_inner_loss: 1.015e+00, test_acc: 60.8
# step: 11, dt: 1.8s, meta_grad_norm: 6.8e-02, mean_inner_loss: 1.016e+00, final_inner_loss: 1.039e+00, test_acc: 64.6
# step: 12, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.974e-01, final_inner_loss: 1.009e+00, test_acc: 64.6
# step: 13, dt: 1.9s, meta_grad_norm: 9.1e-03, mean_inner_loss: 9.921e-01, final_inner_loss: 9.842e-01, test_acc: 64.0
# step: 14, dt: 2.1s, meta_grad_norm: 3.6e-02, mean_inner_loss: 9.878e-01, final_inner_loss: 9.384e-01, test_acc: 62.8
# step: 15, dt: 1.8s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.896e-01, final_inner_loss: 9.176e-01, test_acc: 64.0
# step: 16, dt: 1.8s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.967e-01, final_inner_loss: 9.892e-01, test_acc: 64.6
# step: 17, dt: 1.7s, meta_grad_norm: 3.7e-03, mean_inner_loss: 9.857e-01, final_inner_loss: 9.315e-01, test_acc: 63.6
# step: 18, dt: 1.7s, meta_grad_norm: 5.1e-03, mean_inner_loss: 9.838e-01, final_inner_loss: 9.258e-01, test_acc: 63.8
# step: 19, dt: 1.7s, meta_grad_norm: 4.0e-02, mean_inner_loss: 9.839e-01, final_inner_loss: 9.238e-01, test_acc: 64.4
# step: 20, dt: 2.0s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.865e-01, final_inner_loss: 9.724e-01, test_acc: 63.4
# step: 21, dt: 2.0s, meta_grad_norm: 3.4e-02, mean_inner_loss: 9.934e-01, final_inner_loss: 9.898e-01, test_acc: 64.6
# step: 22, dt: 1.8s, meta_grad_norm: 2.1e-01, mean_inner_loss: 9.848e-01, final_inner_loss: 9.452e-01, test_acc: 63.6
# step: 45, dt: 1.7s, meta_grad_norm: 3.2e-03, mean_inner_loss: 9.712e-01, final_inner_loss: 8.581e-01, test_acc: 65.4
# step: 46, dt: 1.8s, meta_grad_norm: 3.0e-03, mean_inner_loss: 9.702e-01, final_inner_loss: 8.571e-01, test_acc: 65.6
# step: 47, dt: 2.2s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.693e-01, final_inner_loss: 8.564e-01, test_acc: 65.8
# step: 48, dt: 1.8s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.685e-01, final_inner_loss: 8.554e-01, test_acc: 66.0
# step: 49, dt: 1.7s, meta_grad_norm: 3.0e-03, mean_inner_loss: 9.676e-01, final_inner_loss: 8.542e-01, test_acc: 66.0
# step: 50, dt: 1.7s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.667e-01, final_inner_loss: 8.532e-01, test_acc: 67.0
# step: 51, dt: 1.7s, meta_grad_norm: 2.7e-03, mean_inner_loss: 9.658e-01, final_inner_loss: 8.522e-01, test_acc: 66.4
# step: 52, dt: 1.7s, meta_grad_norm: 3.5e-03, mean_inner_loss: 9.650e-01, final_inner_loss: 8.511e-01, test_acc: 66.6
# step: 53, dt: 1.9s, meta_grad_norm: 7.4e-03, mean_inner_loss: 9.638e-01, final_inner_loss: 8.483e-01, test_acc: 68.2
# step: 54, dt: 2.0s, meta_grad_norm: 4.0e-02, mean_inner_loss: 9.616e-01, final_inner_loss: 8.663e-01, test_acc: 67.6
# step: 55, dt: 1.7s, meta_grad_norm: 3.9e-03, mean_inner_loss: 9.540e-01, final_inner_loss: 8.934e-01, test_acc: 65.4
# step: 56, dt: 1.8s, meta_grad_norm: 3.4e-03, mean_inner_loss: 9.528e-01, final_inner_loss: 8.926e-01, test_acc: 65.6
# step: 57, dt: 1.7s, meta_grad_norm: 5.4e-03, mean_inner_loss: 9.519e-01, final_inner_loss: 8.946e-01, test_acc: 65.6
# step: 58, dt: 1.7s, meta_grad_norm: 1.0e-01, mean_inner_loss: 9.530e-01, final_inner_loss: 9.081e-01, test_acc: 64.0
# step: 59, dt: 1.8s, meta_grad_norm: 6.5e-03, mean_inner_loss: 9.607e-01, final_inner_loss: 8.556e-01, test_acc: 68.0
# step: 60, dt: 2.1s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.585e-01, final_inner_loss: 8.473e-01, test_acc: 67.2
# step: 61, dt: 1.9s, meta_grad_norm: 9.9e-03, mean_inner_loss: 9.553e-01, final_inner_loss: 8.680e-01, test_acc: 65.4
# step: 62, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.529e-01, final_inner_loss: 8.852e-01, test_acc: 64.8
# step: 63, dt: 1.7s, meta_grad_norm: 3.0e-03, mean_inner_loss: 9.491e-01, final_inner_loss: 8.949e-01, test_acc: 65.2
# step: 64, dt: 1.8s, meta_grad_norm: 2.6e-03, mean_inner_loss: 9.486e-01, final_inner_loss: 8.973e-01, test_acc: 65.0
# step: 65, dt: 1.7s, meta_grad_norm: 5.2e-03, mean_inner_loss: 9.477e-01, final_inner_loss: 8.924e-01, test_acc: 66.0
# step: 66, dt: 1.7s, meta_grad_norm: 3.4e-02, mean_inner_loss: 9.478e-01, final_inner_loss: 8.908e-01, test_acc: 64.6
# step: 67, dt: 2.2s, meta_grad_norm: 9.0e-02, mean_inner_loss: 9.522e-01, final_inner_loss: 9.071e-01, test_acc: 65.2
# step: 68, dt: 1.9s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.514e-01, final_inner_loss: 8.610e-01, test_acc: 65.4
# step: 69, dt: 1.8s, meta_grad_norm: 3.4e-02, mean_inner_loss: 9.468e-01, final_inner_loss: 8.847e-01, test_acc: 65.0
# step: 70, dt: 1.7s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.498e-01, final_inner_loss: 9.120e-01, test_acc: 65.2
# step: 71, dt: 1.8s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.478e-01, final_inner_loss: 8.725e-01, test_acc: 65.2
# step: 72, dt: 1.8s, meta_grad_norm: 5.7e-03, mean_inner_loss: 9.441e-01, final_inner_loss: 8.911e-01, test_acc: 64.2
# step: 73, dt: 1.8s, meta_grad_norm: 6.6e-02, mean_inner_loss: 9.460e-01, final_inner_loss: 8.969e-01, test_acc: 64.0
# step: 74, dt: 2.2s, meta_grad_norm: 7.8e-02, mean_inner_loss: 9.612e-01, final_inner_loss: 8.739e-01, test_acc: 66.0
# step: 75, dt: 1.8s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.845e-01, final_inner_loss: 9.717e-01, test_acc: 64.4
# step: 76, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.613e-01, final_inner_loss: 8.941e-01, test_acc: 64.6
# step: 77, dt: 1.7s, meta_grad_norm: 3.2e-01, mean_inner_loss: 9.689e-01, final_inner_loss: 9.089e-01, test_acc: 66.0
# step: 78, dt: 1.7s, meta_grad_norm: 6.1e-03, mean_inner_loss: 9.462e-01, final_inner_loss: 8.592e-01, test_acc: 66.4
# step: 79, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.436e-01, final_inner_loss: 8.617e-01, test_acc: 65.2
# step: 80, dt: 2.0s, meta_grad_norm: 4.0e-03, mean_inner_loss: 9.405e-01, final_inner_loss: 8.927e-01, test_acc: 65.4
# step: 81, dt: 2.1s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.399e-01, final_inner_loss: 8.792e-01, test_acc: 63.2
# step: 82, dt: 1.7s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.407e-01, final_inner_loss: 8.685e-01, test_acc: 64.0
# step: 83, dt: 1.7s, meta_grad_norm: 7.3e-02, mean_inner_loss: 9.400e-01, final_inner_loss: 8.951e-01, test_acc: 64.2
# step: 84, dt: 1.8s, meta_grad_norm: 3.9e-01, mean_inner_loss: 9.578e-01, final_inner_loss: 8.682e-01, test_acc: 65.0
# step: 85, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9
# step: 191, dt: 1.8s, meta_grad_norm: 2.2e-03, mean_inner_loss: 9.135e-01, final_inner_loss: 7.736e-01, test_acc: 67.6
# step: 192, dt: 1.8s, meta_grad_norm: 5.7e-03, mean_inner_loss: 9.136e-01, final_inner_loss: 7.756e-01, test_acc: 67.8
# step: 193, dt: 1.8s, meta_grad_norm: 5.1e-03, mean_inner_loss: 9.136e-01, final_inner_loss: 7.719e-01, test_acc: 67.8
# step: 194, dt: 1.9s, meta_grad_norm: 4.2e-03, mean_inner_loss: 9.132e-01, final_inner_loss: 7.768e-01, test_acc: 67.8
# step: 195, dt: 2.5s, meta_grad_norm: 6.1e-03, mean_inner_loss: 9.131e-01, final_inner_loss: 7.713e-01, test_acc: 67.8
# step: 196, dt: 1.9s, meta_grad_norm: 9.9e-03, mean_inner_loss: 9.131e-01, final_inner_loss: 7.752e-01, test_acc: 67.6
# step: 197, dt: 1.9s, meta_grad_norm: 5.6e-03, mean_inner_loss: 9.132e-01, final_inner_loss: 7.705e-01, test_acc: 68.0
# step: 198, dt: 1.9s, meta_grad_norm: 2.1e-03, mean_inner_loss: 9.124e-01, final_inner_loss: 7.763e-01, test_acc: 67.6
# step: 199, dt: 1.9s, meta_grad_norm: 2.8e-03, mean_inner_loss: 9.123e-01, final_inner_loss: 7.699e-01, test_acc: 67.2
# step: 200, dt: 1.9s, meta_grad_norm: 3.7e-03, mean_inner_loss: 9.122e-01, final_inner_loss: 7.773e-01, test_acc: 67.6
# step: 201, dt: 2.4s, meta_grad_norm: 5.7e-03, mean_inner_loss: 9.121e-01, final_inner_loss: 7.675e-01, test_acc: 68.4
# step: 202, dt: 2.0s, meta_grad_norm: 7.6e-03, mean_inner_loss: 9.122e-01, final_inner_loss: 7.776e-01, test_acc: 67.4
# step: 203, dt: 1.8s, meta_grad_norm: 4.2e-03, mean_inner_loss: 9.121e-01, final_inner_loss: 7.665e-01, test_acc: 68.2
# step: 204, dt: 1.8s, meta_grad_norm: 2.0e-03, mean_inner_loss: 9.115e-01, final_inner_loss: 7.755e-01, test_acc: 67.4
# step: 205, dt: 1.8s, meta_grad_norm: 3.9e-03, mean_inner_loss: 9.113e-01, final_inner_loss: 7.679e-01, test_acc: 68.0
# step: 206, dt: 1.8s, meta_grad_norm: 6.3e-03, mean_inner_loss: 9.116e-01, final_inner_loss: 7.776e-01, test_acc: 67.4
# step: 207, dt: 2.1s, meta_grad_norm: 5.0e-03, mean_inner_loss: 9.114e-01, final_inner_loss: 7.672e-01, test_acc: 68.2
# step: 208, dt: 2.1s, meta_grad_norm: 4.3e-03, mean_inner_loss: 9.111e-01, final_inner_loss: 7.779e-01, test_acc: 67.4
# step: 209, dt: 1.8s, meta_grad_norm: 5.5e-03, mean_inner_loss: 9.110e-01, final_inner_loss: 7.674e-01, test_acc: 68.4
# step: 210, dt: 1.8s, meta_grad_norm: 6.0e-03, mean_inner_loss: 9.110e-01, final_inner_loss: 7.794e-01, test_acc: 67.8
# step: 211, dt: 1.8s, meta_grad_norm: 5.7e-03, mean_inner_loss: 9.108e-01, final_inner_loss: 7.677e-01, test_acc: 68.2
# step: 212, dt: 1.8s, meta_grad_norm: 5.6e-03, mean_inner_loss: 9.107e-01, final_inner_loss: 7.806e-01, test_acc: 68.0
# step: 213, dt: 1.8s, meta_grad_norm: 8.1e-03, mean_inner_loss: 9.106e-01, final_inner_loss: 7.675e-01, test_acc: 68.0
# step: 214, dt: 2.2s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.109e-01, final_inner_loss: 7.800e-01, test_acc: 67.6
# step: 215, dt: 1.8s, meta_grad_norm: 8.0e-03, mean_inner_loss: 9.109e-01, final_inner_loss: 7.675e-01, test_acc: 68.4
# step: 216, dt: 1.8s, meta_grad_norm: 3.8e-03, mean_inner_loss: 9.101e-01, final_inner_loss: 7.802e-01, test_acc: 68.2
# step: 217, dt: 1.7s, meta_grad_norm: 7.6e-03, mean_inner_loss: 9.100e-01, final_inner_loss: 7.674e-01, test_acc: 68.0
# step: 218, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.105e-01, final_inner_loss: 7.815e-01, test_acc: 67.8
# step: 219, dt: 1.7s, meta_grad_norm: 7.6e-03, mean_inner_loss: 9.105e-01, final_inner_loss: 7.688e-01, test_acc: 68.2
# step: 220, dt: 1.8s, meta_grad_norm: 2.8e-03, mean_inner_loss: 9.095e-01, final_inner_loss: 7.781e-01, test_acc: 68.0
# step: 221, dt: 2.2s, meta_grad_norm: 5.8e-03, mean_inner_loss: 9.093e-01, final_inner_loss: 7.700e-01, test_acc: 68.2
# step: 222, dt: 1.8s, meta_grad_norm: 8.2e-03, mean_inner_loss: 9.098e-01, final_inner_loss: 7.792e-01, test_acc: 67.8
# step: 223, dt: 1.7s, meta_grad_norm: 7.1e-03, mean_inner_loss: 9.095e-01, final_inner_loss: 7.688e-01, test_acc: 68.2
# step: 224, dt: 1.7s, meta_grad_norm: 8.4e-03, mean_inner_loss: 9.094e-01, final_inner_loss: 7.805e-01, test_acc: 68.0
# step: 225, dt: 1.8s, meta_grad_norm: 9.6e-03, mean_inner_loss: 9.094e-01, final_inner_loss: 7.679e-01, test_acc: 67.8
# step: 226, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.095e-01, final_inner_loss: 7.782e-01, test_acc: 67.8
# step: 227, dt: 2.0s, meta_grad_norm: 6.4e-03, mean_inner_loss: 9.092e-01, final_inner_loss: 7.701e-01, test_acc: 68.2
# step: 228, dt: 2.0s, meta_grad_norm: 5.5e-03, mean_inner_loss: 9.087e-01, final_inner_loss: 7.809e-01, test_acc: 68.4
# step: 229, dt: 1.7s, meta_grad_norm: 6.1e-03, mean_inner_loss: 9.086e-01, final_inner_loss: 7.689e-01, test_acc: 68.0
# step: 230, dt: 1.7s, meta_grad_norm: 6.0e-03, mean_inner_loss: 9.087e-01, final_inner_loss: 7.796e-01, test_acc: 68.2
# step: 231, dt: 1.7s, meta_grad_norm: 8.5e-03, mean_inner_loss: 9.084e-01, final_inner_loss: 7.714e-01, test_acc: 68.4
# step: 232, dt: 1.8s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.089e-01, final_inner_loss: 7.786e-01, test_acc: 67.8
# step: 233, dt: 1.7s, meta_grad_norm: 7.9e-03, mean_inner_loss: 9.089e-01, final_inner_loss: 7.692e-01, test_acc: 68.6
# step: 234, dt: 2.1s, meta_grad_norm: 3.1e-03, mean_inner_loss: 9.079e-01, final_inner_loss: 7.809e-01, test_acc: 68.4
# step: 235, dt: 2.0s, meta_grad_norm: 4.7e-03, mean_inner_loss: 9.077e-01, final_inner_loss: 7.739e-01, test_acc: 68.2
# step: 236, dt: 1.8s, meta_grad_norm: 6.6e-03, mean_inner_loss: 9.080e-01, final_inner_loss: 7.801e-01, test_acc: 68.4
# step: 237, dt: 1.7s, meta_grad_norm: 8.2e-03, mean_inner_loss: 9.078e-01, final_inner_loss: 7.723e-01, test_acc: 68.2
# step: 238, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.080e-01, final_inner_loss: 7.786e-01, test_acc: 68.4
# step: 239, dt: 1.8s, meta_grad_norm: 7.4e-03, mean_inner_loss: 9.080e-01, final_inner_loss: 7.718e-01, test_acc: 68.4
# step: 240, dt: 1.7s, meta_grad_norm: 3.8e-03, mean_inner_loss: 9.073e-01, final_inner_loss: 7.802e-01, test_acc: 68.8
# step: 241, dt: 2.3s, meta_grad_norm: 4.8e-03, mean_inner_loss: 9.071e-01, final_inner_loss: 7.761e-01, test_acc: 68.4
# step: 242, dt: 1.8s, meta_grad_norm: 6.3e-03, mean_inner_loss: 9.072e-01, final_inner_loss: 7.801e-01, test_acc: 68.2
# step: 243, dt: 1.7s, meta_grad_norm: 7.6e-03, mean_inner_loss: 9.071e-01, final_inner_loss: 7.748e-01, test_acc: 68.2
# step: 244, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.072e-01, final_inner_loss: 7.788e-01, test_acc: 68.6
# step: 245, dt: 1.7s, meta_grad_norm: 8.3e-03, mean_inner_loss: 9.073e-01, final_inner_loss: 7.730e-01, test_acc: 68.2
# step: 246, dt: 1.7s, meta_grad_norm: 6.0e-03, mean_inner_loss: 9.067e-01, final_inner_loss: 7.801e-01, test_acc: 68.4
# step: 247, dt: 1.9s, meta_grad_norm: 7.5e-03, mean_inner_loss: 9.067e-01, final_inner_loss: 7.751e-01, test_acc: 67.8
# step: 248, dt: 2.2s, meta_grad_norm: 9.6e-03, mean_inner_loss: 9.067e-01, final_inner_loss: 7.785e-01, test_acc: 68.6
# step: 249, dt: 1.7s, meta_grad_norm: 7.9e-03, mean_inner_loss: 9.067e-01, final_inner_loss: 7.760e-01, test_acc: 68.2
# step: 250, dt: 1.7s, meta_grad_norm: 6.7e-03, mean_inner_loss: 9.063e-01, final_inner_loss: 7.774e-01, test_acc: 68.8
# step: 251, dt: 1.8s, meta_grad_norm: 6.6e-03, mean_inner_loss: 9.063e-01, final_inner_loss: 7.794e-01, test_acc: 68.0
# step: 252, dt: 1.7s, meta_grad_norm: 5.1e-03, mean_inner_loss: 9.060e-01, final_inner_loss: 7.803e-01, test_acc: 68.4
# step: 253, dt: 1.7s, meta_grad_norm: 5.4e-03, mean_inner_loss: 9.058e-01, final_inner_loss: 7.803e-01, test_acc: 68.2
# step: 254, dt: 2.0s, meta_grad_norm: 6.5e-03, mean_inner_loss: 9.059e-01, final_inner_loss: 7.755e-01, test_acc: 68.8
# step: 255, dt: 2.1s, meta_grad_norm: 4.9e-03, mean_inner_loss: 9.056e-01, final_inner_loss: 7.819e-01, test_acc: 67.8
# step: 256, dt: 1.7s, meta_grad_norm: 4.5e-03, mean_inner_loss: 9.055e-01, final_inner_loss: 7.809e-01, test_acc: 68.4
# step: 257, dt: 1.8s, meta_grad_norm: 4.0e-03, mean_inner_loss: 9.053e-01, final_inner_loss: 7.822e-01, test_acc: 68.0
# step: 258, dt: 1.7s, meta_grad_norm: 5.0e-03, mean_inner_loss: 9.052e-01, final_inner_loss: 7.754e-01, test_acc: 69.2
# step: 259, dt: 1.7s, meta_grad_norm: 4.0e-03, mean_inner_loss: 9.051e-01, final_inner_loss: 7.835e-01, test_acc: 67.8
# step: 260, dt: 1.8s, meta_grad_norm: 2.5e-03, mean_inner_loss: 9.049e-01, final_inner_loss: 7.816e-01, test_acc: 68.4
# step: 261, dt: 2.1s, meta_grad_norm: 1.3e-03, mean_inner_loss: 9.046e-01, final_inner_loss: 7.798e-01, test_acc: 68.4
# step: 262, dt: 1.9s, meta_grad_norm: 3.2e-03, mean_inner_loss: 9.045e-01, final_inner_loss: 7.753e-01, test_acc: 69.6
# step: 263, dt: 1.7s, meta_grad_norm: 9.8e-04, mean_inner_loss: 9.045e-01, final_inner_loss: 7.850e-01, test_acc: 68.2
# step: 264, dt: 1.7s, meta_grad_norm: 2.1e-03, mean_inner_loss: 9.043e-01, final_inner_loss: 7.822e-01, test_acc: 68.4
# step: 265, dt: 1.7s, meta_grad_norm: 1.4e-03, mean_inner_loss: 9.043e-01, final_inner_loss: 7.743e-01, test_acc: 68.8
# step: 266, dt: 1.7s, meta_grad_norm: 6.0e-04, mean_inner_loss: 9.039e-01, final_inner_loss: 7.766e-01, test_acc: 69.0
# step: 267, dt: 1.7s, meta_grad_norm: 1.2e-03, mean_inner_loss: 9.038e-01, final_inner_loss: 7.758e-01, test_acc: 68.8
# step: 268, dt: 2.2s, meta_grad_norm: 2.4e-03, mean_inner_loss: 9.039e-01, final_inner_loss: 7.842e-01, test_acc: 67.8
# step: 269, dt: 1.8s, meta_grad_norm: 2.1e-03, mean_inner_loss: 9.037e-01, final_inner_loss: 7.737e-01, test_acc: 68.8
# step: 270, dt: 1.8s, meta_grad_norm: 3.1e-03, mean_inner_loss: 9.035e-01, final_inner_loss: 7.796e-01, test_acc: 67.8
# step: 271, dt: 1.7s, meta_grad_norm: 1.3e-03, mean_inner_loss: 9.035e-01, final_inner_loss: 7.733e-01, test_acc: 68.2
# step: 272, dt: 1.8s, meta_grad_norm: 1.1e-03, mean_inner_loss: 9.032e-01, final_inner_loss: 7.736e-01, test_acc: 68.6
# step: 273, dt: 1.7s, meta_grad_norm: 1.2e-03, mean_inner_loss: 9.029e-01, final_inner_loss: 7.726e-01, test_acc: 68.4
# step: 274, dt: 1.9s, meta_grad_norm: 2.2e-03, mean_inner_loss: 9.027e-01, final_inner_loss: 7.742e-01, test_acc: 68.6
# step: 275, dt: 2.1s, meta_grad_norm: 1.1e-03, mean_inner_loss: 9.026e-01, final_inner_loss: 7.718e-01, test_acc: 68.0
# step: 276, dt: 1.7s, meta_grad_norm: 7.7e-04, mean_inner_loss: 9.023e-01, final_inner_loss: 7.714e-01, test_acc: 68.2
# step: 277, dt: 1.7s, meta_grad_norm: 6.8e-04, mean_inner_loss: 9.021e-01, final_inner_loss: 7.708e-01, test_acc: 68.2
# step: 278, dt: 1.7s, meta_grad_norm: 6.9e-04, mean_inner_loss: 9.019e-01, final_inner_loss: 7.706e-01, test_acc: 67.8
# step: 279, dt: 1.7s, meta_grad_norm: 7.2e-04, mean_inner_loss: 9.017e-01, final_inner_loss: 7.702e-01, test_acc: 68.4
# step: 280, dt: 1.7s, meta_grad_norm: 7.5e-04, mean_inner_loss: 9.015e-01, final_inner_loss: 7.711e-01, test_acc: 68.6
# step: 281, dt: 2.1s, meta_grad_norm: 1.0e-03, mean_inner_loss: 9.013e-01, final_inner_loss: 7.683e-01, test_acc: 68.6
# step: 282, dt: 2.0s, meta_grad_norm: 1.5e-03, mean_inner_loss: 9.012e-01, final_inner_loss: 7.722e-01, test_acc: 68.6
# step: 283, dt: 1.7s, meta_grad_norm: 3.0e-03, mean_inner_loss: 9.011e-01, final_inner_loss: 7.644e-01, test_acc: 68.8
# step: 284, dt: 1.7s, meta_grad_norm: 1.0e-03, mean_inner_loss: 9.011e-01, final_inner_loss: 7.734e-01, test_acc: 68.6
# step: 285, dt: 1.7s, meta_grad_norm: 1.2e-03, mean_inner_loss: 9.008e-01, final_inner_loss: 7.697e-01, test_acc: 69.2
# step: 286, dt: 1.7s, meta_grad_norm: 2.3e-03, mean_inner_loss: 9.006e-01, final_inner_loss: 7.639e-01, test_acc: 69.4
# step: 287, dt: 1.7s, meta_grad_norm: 1.1e-03, mean_inner_loss: 9.005e-01, final_inner_loss: 7.702e-01, test_acc: 68.6
# step: 288, dt: 2.1s, meta_grad_norm: 1.1e-03, mean_inner_loss: 9.002e-01, final_inner_loss: 7.675e-01, test_acc: 68.8
# step: 289, dt: 1.9s, meta_grad_norm: 1.5e-03, mean_inner_loss: 9.000e-01, final_inner_loss: 7.626e-01, test_acc: 68.4
# step: 290, dt: 1.7s, meta_grad_norm: 1.4e-03, mean_inner_loss: 8.998e-01, final_inner_loss: 7.657e-01, test_acc: 68.6
# step: 291, dt: 1.7s, meta_grad_norm: 9.2e-04, mean_inner_loss: 8.994e-01, final_inner_loss: 7.634e-01, test_acc: 68.8
# step: 292, dt: 1.7s, meta_grad_norm: 9.3e-04, mean_inner_loss: 8.992e-01, final_inner_loss: 7.641e-01, test_acc: 68.8
# step: 293, dt: 1.7s, meta_grad_norm: 9.8e-04, mean_inner_loss: 8.989e-01, final_inner_loss: 7.650e-01, test_acc: 69.0
# step: 294, dt: 1.7s, meta_grad_norm: 7.9e-04, mean_inner_loss: 8.986e-01, final_inner_loss: 7.653e-01, test_acc: 68.6
# step: 295, dt: 2.2s, meta_grad_norm: 6.9e-04, mean_inner_loss: 8.984e-01, final_inner_loss: 7.636e-01, test_acc: 68.8
# step: 296, dt: 1.8s, meta_grad_norm: 6.3e-04, mean_inner_loss: 8.982e-01, final_inner_loss: 7.633e-01, test_acc: 68.8
# step: 297, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 8.980e-01, final_inner_loss: 7.629e-01, test_acc: 68.6
# step: 298, dt: 1.7s, meta_grad_norm: 5.4e-04, mean_inner_loss: 8.979e-01, final_inner_loss: 7.630e-01, test_acc: 68.8
# step: 299, dt: 1.7s, meta_grad_norm: 5.5e-04, mean_inner_loss: 8.977e-01, final_inner_loss: 7.632e-01, test_acc: 69.2
# step: 300, dt: 1.7s, meta_grad_norm: 5.5e-04, mean_inner_loss: 8.975e-01, final_inner_loss: 7.628e-01, test_acc: 69.0

# %%
import pickle

# Save results using pickle
with open('results_mu_6.pkl', 'wb') as f:
    pickle.dump(results_mu_6, f)

print("Results saved to 'results_mu_6.pkl'")
# Out:
# Results saved to 'results_mu_6.pkl'

# %%
# Load results from pickle file
with open('results_mu_6.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
results_mu_6['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    results_mu_6['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(results_mu_6['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 0.9379676778451153
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.350861, 1.3822151, 1.4888653, 1.6618439, 1.5402863, 1.7651119]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(results_mu_6, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 67.8
