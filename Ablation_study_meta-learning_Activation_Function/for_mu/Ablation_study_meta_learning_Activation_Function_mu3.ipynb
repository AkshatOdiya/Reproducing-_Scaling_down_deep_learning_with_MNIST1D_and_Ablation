# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 128,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 0.3,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
results_mu_3 = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 4.6s, meta_grad_norm: 2.1e+00, mean_inner_loss: 1.354e+00, final_inner_loss: 1.362e+00, test_acc: 48.8
# step: 1, dt: 2.5s, meta_grad_norm: 7.3e-02, mean_inner_loss: 1.293e+00, final_inner_loss: 1.268e+00, test_acc: 51.8
# step: 2, dt: 1.8s, meta_grad_norm: 7.3e-02, mean_inner_loss: 1.273e+00, final_inner_loss: 1.250e+00, test_acc: 52.4
# step: 3, dt: 2.1s, meta_grad_norm: 9.4e-02, mean_inner_loss: 1.249e+00, final_inner_loss: 1.224e+00, test_acc: 54.0
# step: 4, dt: 2.9s, meta_grad_norm: 9.5e-02, mean_inner_loss: 1.221e+00, final_inner_loss: 1.172e+00, test_acc: 55.2
# step: 5, dt: 2.1s, meta_grad_norm: 1.3e-01, mean_inner_loss: 1.188e+00, final_inner_loss: 1.105e+00, test_acc: 57.8
# step: 6, dt: 2.3s, meta_grad_norm: 1.4e-01, mean_inner_loss: 1.146e+00, final_inner_loss: 1.064e+00, test_acc: 60.0
# step: 7, dt: 1.7s, meta_grad_norm: 1.2e-01, mean_inner_loss: 1.106e+00, final_inner_loss: 1.044e+00, test_acc: 60.0
# step: 8, dt: 1.7s, meta_grad_norm: 6.9e-02, mean_inner_loss: 1.076e+00, final_inner_loss: 1.007e+00, test_acc: 60.4
# step: 9, dt: 1.7s, meta_grad_norm: 5.6e-02, mean_inner_loss: 1.059e+00, final_inner_loss: 1.006e+00, test_acc: 60.8
# step: 10, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 1.042e+00, final_inner_loss: 9.983e-01, test_acc: 61.2
# step: 11, dt: 2.3s, meta_grad_norm: 4.3e-02, mean_inner_loss: 1.028e+00, final_inner_loss: 1.033e+00, test_acc: 60.8
# step: 12, dt: 1.7s, meta_grad_norm: 7.4e-02, mean_inner_loss: 1.010e+00, final_inner_loss: 1.036e+00, test_acc: 61.8
# step: 13, dt: 1.7s, meta_grad_norm: 9.5e-02, mean_inner_loss: 9.928e-01, final_inner_loss: 1.026e+00, test_acc: 62.0
# step: 14, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.832e-01, final_inner_loss: 9.536e-01, test_acc: 63.2
# step: 15, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.973e-01, final_inner_loss: 1.016e+00, test_acc: 62.6
# step: 16, dt: 1.9s, meta_grad_norm: 5.2e-02, mean_inner_loss: 9.895e-01, final_inner_loss: 1.023e+00, test_acc: 61.6
# step: 17, dt: 1.9s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.753e-01, final_inner_loss: 9.209e-01, test_acc: 63.4
# step: 18, dt: 2.1s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.738e-01, final_inner_loss: 9.288e-01, test_acc: 63.2
# step: 19, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.832e-01, final_inner_loss: 8.928e-01, test_acc: 62.6
# step: 20, dt: 1.7s, meta_grad_norm: 8.2e-02, mean_inner_loss: 9.747e-01, final_inner_loss: 9.003e-01, test_acc: 63.0
# step: 21, dt: 1.7s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.828e-01, final_inner_loss: 9.866e-01, test_acc: 62.6
# step: 22, dt: 1.7s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.903e-01, final_inner_loss: 9.593e-01, test_acc: 63.0
# step: 23, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.698e-01, final_inner_loss: 9.009e-01, test_acc: 63.8
# step: 24, dt: 2.0s, meta_grad_norm: 1.9e-01, mean_inner_loss: 9.852e-01, final_inner_loss: 9.500e-01, test_acc: 62.2
# step: 25, dt: 2.0s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.721e-01, final_inner_loss: 8.920e-01, test_acc: 63.8
# step: 26, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 9.827e-01, final_inner_loss: 9.821e-01, test_acc: 63.2
# step: 27, dt: 2.1s, meta_grad_norm: 3.9e-01, mean_inner_loss: 9.756e-01, final_inner_loss: 9.642e-01, test_acc: 63.4
# step: 28, dt: 2.0s, meta_grad_norm: 5.5e-03, mean_inner_loss: 9.832e-01, final_inner_loss: 8.909e-01, test_acc: 64.2
# step: 29, dt: 1.7s, meta_grad_norm: 4.6e-02, mean_inner_loss: 9.812e-01, final_inner_loss: 8.876e-01, test_acc: 64.0
# step: 30, dt: 1.7s, meta_grad_norm: 9.5e-03, mean_inner_loss: 9.688e-01, final_inner_loss: 8.903e-01, test_acc: 65.6
# step: 31, dt: 2.3s, meta_grad_norm: 3.6e-02, mean_inner_loss: 9.675e-01, final_inner_loss: 8.983e-01, test_acc: 64.8
# step: 32, dt: 1.8s, meta_grad_norm: 3.3e-01, mean_inner_loss: 9.667e-01, final_inner_loss: 8.815e-01, test_acc: 65.6
# step: 33, dt: 1.7s, meta_grad_norm: 3.1e-03, mean_inner_loss: 1.003e+00, final_inner_loss: 9.832e-01, test_acc: 62.6
# step: 34, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 1.001e+00, final_inner_loss: 9.927e-01, test_acc: 62.4
# step: 35, dt: 1.7s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.983e-01, final_inner_loss: 9.735e-01, test_acc: 63.6
# step: 36, dt: 1.7s, meta_grad_norm: 2.4e-01, mean_inner_loss: 9.913e-01, final_inner_loss: 9.492e-01, test_acc: 61.8
# step: 37, dt: 1.9s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.631e-01, final_inner_loss: 8.722e-01, test_acc: 65.8
# step: 38, dt: 2.1s, meta_grad_norm: 3.2e-02, mean_inner_loss: 9.811e-01, final_inner_loss: 9.790e-01, test_acc: 61.2
# step: 39, dt: 1.8s, meta_grad_norm: 1.1e-01, mean_inner_loss: 9.663e-01, final_inner_loss: 9.538e-01, test_acc: 63.8
# step: 40, dt: 1.7s, meta_grad_norm: 8.0e-03, mean_inner_loss: 9.640e-01, final_inner_loss: 8.758e-01, test_acc: 64.4
# step: 41, dt: 1.7s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.617e-01, final_inner_loss: 8.817e-01, test_acc: 65.8
# step: 42, dt: 1.7s, meta_grad_norm: 2.1e-03, mean_inner_loss: 9.518e-01, final_inner_loss: 8.684e-01, test_acc: 65.0
# step: 43, dt: 1.7s, meta_grad_norm: 8.1e-02, mean_inner_loss: 9.527e-01, final_inner_loss: 8.599e-01, test_acc: 64.6
# step: 44, dt: 2.0s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.742e-01, final_inner_loss: 9.798e-01, test_acc: 62.4
# step: 45, dt: 2.0s, meta_grad_norm: 8.1e-02, mean_inner_loss: 9.728e-01, final_inner_loss: 9.889e-01, test_acc: 63.0
# step: 46, dt: 1.7s, meta_grad_norm: 6.8e-02, mean_inner_loss: 9.528e-01, final_inner_loss: 8.730e-01, test_acc: 64.4
# step: 47, dt: 1.7s, meta_grad_norm: 1.1e-01, mean_inner_loss: 9.686e-01, final_inner_loss: 9.621e-01, test_acc: 62.2
# step: 48, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.550e-01, final_inner_loss: 8.819e-01, test_acc: 66.4
# step: 49, dt: 1.7s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.570e-01, final_inner_loss: 8.722e-01, test_acc: 65.6
# step: 50, dt: 1.7s, meta_grad_norm: 3.9e-02, mean_inner_loss: 9.561e-01, final_inner_loss: 8.980e-01, test_acc: 65.6
# step: 51, dt: 2.0s, meta_grad_norm: 5.4e-03, mean_inner_loss: 9.526e-01, final_inner_loss: 8.644e-01, test_acc: 67.0
# step: 52, dt: 2.0s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.508e-01, final_inner_loss: 8.581e-01, test_acc: 66.8
# step: 53, dt: 1.9s, meta_grad_norm: 5.9e-03, mean_inner_loss: 9.459e-01, final_inner_loss: 8.631e-01, test_acc: 67.0
# step: 54, dt: 1.7s, meta_grad_norm: 9.9e-03, mean_inner_loss: 9.460e-01, final_inner_loss: 8.655e-01, test_acc: 65.4
# step: 55, dt: 1.7s, meta_grad_norm: 9.8e-03, mean_inner_loss: 9.474e-01, final_inner_loss: 8.709e-01, test_acc: 65.0
# step: 56, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.440e-01, final_inner_loss: 8.695e-01, test_acc: 65.4
# step: 57, dt: 1.7s, meta_grad_norm: 8.6e-02, mean_inner_loss: 9.482e-01, final_inner_loss: 8.894e-01, test_acc: 66.0
# step: 58, dt: 2.2s, meta_grad_norm: 2.2e-02, mean_inner_loss: 9.476e-01, final_inner_loss: 8.572e-01, test_acc: 65.6
# step: 59, dt: 1.8s, meta_grad_norm: 5.6e-02, mean_inner_loss: 9.439e-01, final_inner_loss: 8.543e-01, test_acc: 66.0
# step: 60, dt: 1.7s, meta_grad_norm: 5.1e-01, mean_inner_loss: 9.569e-01, final_inner_loss: 9.568e-01, test_acc: 63.0
# step: 61, dt: 1.7s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.628e-01, final_inner_loss: 8.961e-01, test_acc: 66.2
# step: 62, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 9.556e-01, final_inner_loss: 8.963e-01, test_acc: 65.8
# step: 63, dt: 1.7s, meta_grad_norm: 2.3e-02, mean_inner_loss: 9.433e-01, final_inner_loss: 8.602e-01, test_acc: 66.8
# step: 64, dt: 1.8s, meta_grad_norm: 4.6e-03, mean_inner_loss: 9.401e-01, final_inner_loss: 8.477e-01, test_acc: 64.8
# step: 65, dt: 2.2s, meta_grad_norm: 3.0e-03, mean_inner_loss: 9.392e-01, final_inner_loss: 8.542e-01, test_acc: 67.6
# step: 66, dt: 1.7s, meta_grad_norm: 3.4e-03, mean_inner_loss: 9.383e-01, final_inner_loss: 8.587e-01, test_acc: 67.0
# step: 67, dt: 1.7s, meta_grad_norm: 9.3e-03, mean_inner_loss: 9.374e-01, final_inner_loss: 8.508e-01, test_acc: 66.2
# step: 68, dt: 1.7s, meta_grad_norm: 4.6e-03, mean_inner_loss: 9.374e-01, final_inner_loss: 8.559e-01, test_acc: 67.6
# step: 69, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.358e-01, final_inner_loss: 8.638e-01, test_acc: 66.6
# step: 70, dt: 1.7s, meta_grad_norm: 8.5e-02, mean_inner_loss: 9.394e-01, final_inner_loss: 8.983e-01, test_acc: 66.6
# step: 71, dt: 2.3s, meta_grad_norm: 1.0e-01, mean_inner_loss: 9.414e-01, final_inner_loss: 8.522e-01, test_acc: 66.0
# step: 72, dt: 2.3s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.406e-01, final_inner_loss: 8.667e-01, test_acc: 64.2
# step: 73, dt: 1.7s, meta_grad_norm: 4.3e-02, mean_inner_loss: 9.417e-01, final_inner_loss: 8.719e-01, test_acc: 66.6
# step: 74, dt: 1.7s, meta_grad_norm: 9.5e-03, mean_inner_loss: 9.341e-01, final_inner_loss: 8.419e-01, test_acc: 67.2
# step: 75, dt: 1.7s, meta_grad_norm: 6.5e-03, mean_inner_loss: 9.323e-01, final_inner_loss: 8.480e-01, test_acc: 66.4
# step: 76, dt: 1.7s, meta_grad_norm: 9.9e-01, mean_inner_loss: 9.334e-01, final_inner_loss: 8.641e-01, test_acc: 67.0
# step: 77, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.668e-01, final_inner_loss: 8.313e-01, test_acc: 64.6
# step: 78, dt: 2.1s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.637e-01, final_inner_loss: 8.256e-01, test_acc: 65.4
# step: 79, dt: 2.0s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.605e-01, final_inner_loss: 8.667e-01, test_acc: 66.6
# step: 80, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.524e-01, final_inner_loss: 8.589e-01, test_acc: 64.8
# step: 81, dt: 1.7s, meta_grad_norm: 5.9e-02, mean_inner_loss: 9.341e-01, final_inner_loss: 8.581e-01, test_acc: 65.4
# step: 82, dt: 1.7s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.329e-01, final_inner_loss: 8.900e-01, test_acc: 66.6
# step: 83, dt: 1.7s, meta_grad_norm: 3.3e-02, mean_inner_loss: 9.381e-01, final_inner_loss: 8.653e-01, test_acc: 66.0
# step: 84, dt: 1.7s, meta_grad_norm: 7.7e-02, mean_inner_loss: 9.321e-01, final_inner_loss: 8.530e-01, test_acc: 67.4
# step: 85, dt: 2.2s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.387e-01, final_inner_loss: 8.666e-01, test_acc: 65.4
# step: 86, dt: 1.8s, meta_grad_norm: 8.1e-02, mean_inner_loss: 9.347e-01, final_inner_loss: 8.462e-01, test_acc: 65.4
# step: 87, dt: 1.7s, meta_grad_norm: 6.4e-01, mean_inner_loss: 9.294e-01, final_inner_loss: 8.552e-01, test_acc: 66.6
# step: 88, dt: 1.7s, meta_grad_norm: 3.0e-02, mean_inner_loss: 9.587e-01, final_inner_loss: 8.557e-01, test_acc: 65.8
# step: 89, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.473e-01, final_inner_loss: 8.717e-01, test_acc: 67.0
# step: 90, dt: 1.7s, meta_grad_norm: 6.7e-02, mean_inner_loss: 9.403e-01, final_inner_loss: 8.576e-01, test_acc: 64.6
# step: 91, dt: 1.8s, meta_grad_norm: 6.2e-02, mean_inner_loss: 9.329e-01, final_inner_loss: 8.500e-01, test_acc: 65.4
# step: 92, dt: 2.2s, meta_grad_norm: 3.8e-01, mean_inner_loss: 9.256e-01, final_inner_loss: 8.638e-01, test_acc: 64.6
# step: 93, dt: 1.7s, meta_grad_norm: 4.6e-02, mean_inner_loss: 9.431e-01, final_inner_loss: 8.411e-01, test_acc: 65.6
# step: 94, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.351e-01, final_inner_loss: 8.592e-01, test_acc: 66.2
# step: 95, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.331e-01, final_inner_loss: 8.512e-01, test_acc: 66.2
# step: 96, dt: 1.7s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.284e-01, final_inner_loss: 8.560e-01, test_acc: 65.6
# step: 97, dt: 1.7s, meta_grad_norm: 3.7e-02, mean_inner_loss: 9.386e-01, final_inner_loss: 8.834e-01, test_acc: 65.6
# step: 98, dt: 1.9s, meta_grad_norm: 1.1e-01, mean_inner_loss: 9.212e-01, final_inner_loss: 8.522e-01, test_acc: 67.6
# step: 99, dt: 2.1s, meta_grad_norm: 7.3e-01, mean_inner_loss: 9.507e-01, final_inner_loss: 9.674e-01, test_acc: 65.0
# step: 100, dt: 1.7s, meta_grad_norm: 2.7e-03, mean_inner_loss: 9.410e-01, final_inner_loss: 8.299e-01, test_acc: 64.0
# step: 101, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.396e-01, final_inner_loss: 8.396e-01, test_acc: 63.8
# step: 102, dt: 1.7s, meta_grad_norm: 4.7e-02, mean_inner_loss: 9.355e-01, final_inner_loss: 8.700e-01, test_acc: 65.4
# step: 103, dt: 1.7s, meta_grad_norm: 2.7e-02, mean_inner_loss: 9.309e-01, final_inner_loss: 8.437e-01, test_acc: 65.8
# step: 104, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 9.222e-01, final_inner_loss: 8.709e-01, test_acc: 67.4
# step: 105, dt: 2.0s, meta_grad_norm: 3.8e-01, mean_inner_loss: 9.354e-01, final_inner_loss: 8.735e-01, test_acc: 65.2
# step: 106, dt: 2.0s, meta_grad_norm: 2.8e-02, mean_inner_loss: 9.343e-01, final_inner_loss: 8.671e-01, test_acc: 66.2
# step: 107, dt: 1.7s, meta_grad_norm: 3.9e-03, mean_inner_loss: 9.318e-01, final_inner_loss: 8.582e-01, test_acc: 67.8
# step: 108, dt: 1.7s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.300e-01, final_inner_loss: 8.579e-01, test_acc: 67.0
# step: 109, dt: 1.7s, meta_grad_norm: 7.7e-02, mean_inner_loss: 9.253e-01, final_inner_loss: 8.555e-01, test_acc: 65.0
# step: 110, dt: 1.7s, meta_grad_norm: 4.2e-01, mean_inner_loss: 9.248e-01, final_inner_loss: 8.616e-01, test_acc: 66.0
# step: 111, dt: 1.7s, meta_grad_norm: 2.1e-02, mean_inner_loss: 9.387e-01, final_inner_loss: 8.476e-01, test_acc: 66.2
# step: 112, dt: 2.1s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.315e-01, final_inner_loss: 8.649e-01, test_acc: 64.8
# step: 113, dt: 1.9s, meta_grad_norm: 6.2e-03, mean_inner_loss: 9.304e-01, final_inner_loss: 8.525e-01, test_acc: 67.0
# step: 114, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.333e-01, final_inner_loss: 8.519e-01, test_acc: 65.4
# step: 115, dt: 1.7s, meta_grad_norm: 5.8e-03, mean_inner_loss: 9.190e-01, final_inner_loss: 8.344e-01, test_acc: 67.0
# step: 116, dt: 1.7s, meta_grad_norm: 9.1e-02, mean_inner_loss: 9.164e-01, final_inner_loss: 8.424e-01, test_acc: 68.6
# step: 117, dt: 1.7s, meta_grad_norm: 4.2e-03, mean_inner_loss: 9.429e-01, final_inner_loss: 9.337e-01, test_acc: 65.2
# step: 118, dt: 1.7s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.435e-01, final_inner_loss: 9.407e-01, test_acc: 65.6
# step: 119, dt: 2.3s, meta_grad_norm: 5.4e-02, mean_inner_loss: 9.171e-01, final_inner_loss: 8.577e-01, test_acc: 67.2
# step: 120, dt: 1.8s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.252e-01, final_inner_loss: 8.533e-01, test_acc: 66.2
# step: 121, dt: 1.7s, meta_grad_norm: 1.9e-01, mean_inner_loss: 9.130e-01, final_inner_loss: 8.251e-01, test_acc: 67.6
# step: 122, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.298e-01, final_inner_loss: 8.516e-01, test_acc: 66.0
# step: 123, dt: 1.7s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.261e-01, final_inner_loss: 8.478e-01, test_acc: 65.0
# step: 124, dt: 1.7s, meta_grad_norm: 3.7e-03, mean_inner_loss: 9.264e-01, final_inner_loss: 8.457e-01, test_acc: 67.8
# step: 125, dt: 1.8s, meta_grad_norm: 5.5e-04, mean_inner_loss: 9.257e-01, final_inner_loss: 8.633e-01, test_acc: 66.6
# step: 126, dt: 2.2s, meta_grad_norm: 8.5e-04, mean_inner_loss: 9.256e-01, final_inner_loss: 8.635e-01, test_acc: 66.6
# step: 127, dt: 1.7s, meta_grad_norm: 1.6e-03, mean_inner_loss: 9.256e-01, final_inner_loss: 8.618e-01, test_acc: 68.0
# step: 128, dt: 1.7s, meta_grad_norm: 2.9e-03, mean_inner_loss: 9.253e-01, final_inner_loss: 8.596e-01, test_acc: 66.4
# step: 129, dt: 1.7s, meta_grad_norm: 4.2e-02, mean_inner_loss: 9.259e-01, final_inner_loss: 8.575e-01, test_acc: 67.0
# step: 130, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 9.180e-01, final_inner_loss: 8.470e-01, test_acc: 67.2
# step: 131, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 9.122e-01, final_inner_loss: 8.408e-01, test_acc: 68.6
# step: 132, dt: 1.9s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.175e-01, final_inner_loss: 8.385e-01, test_acc: 67.2
# step: 133, dt: 2.1s, meta_grad_norm: 8.9e-02, mean_inner_loss: 9.300e-01, final_inner_loss: 8.914e-01, test_acc: 66.6
# step: 134, dt: 1.7s, meta_grad_norm: 2.6e-02, mean_inner_loss: 9.111e-01, final_inner_loss: 8.475e-01, test_acc: 69.0
# step: 135, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 9.170e-01, final_inner_loss: 8.221e-01, test_acc: 66.6
# step: 136, dt: 1.8s, meta_grad_norm: 4.9e-02, mean_inner_loss: 9.232e-01, final_inner_loss: 8.682e-01, test_acc: 64.8
# step: 137, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 9.094e-01, final_inner_loss: 8.420e-01, test_acc: 67.8
# step: 138, dt: 1.7s, meta_grad_norm: 6.5e-02, mean_inner_loss: 9.061e-01, final_inner_loss: 8.308e-01, test_acc: 67.0
# step: 139, dt: 2.0s, meta_grad_norm: 1.4e-01, mean_inner_loss: 9.289e-01, final_inner_loss: 8.933e-01, test_acc: 66.4
# step: 140, dt: 2.0s, meta_grad_norm: 1.9e-01, mean_inner_loss: 9.152e-01, final_inner_loss: 8.481e-01, test_acc: 67.2
# step: 141, dt: 1.7s, meta_grad_norm: 2.7e-02, mean_inner_loss: 9.303e-01, final_inner_loss: 9.005e-01, test_acc: 66.0
# step: 142, dt: 1.7s, meta_grad_norm: 6.4e-02, mean_inner_loss: 9.291e-01, final_inner_loss: 9.161e-01, test_acc: 67.0
# step: 143, dt: 1.7s, meta_grad_norm: 7.4e-02, mean_inner_loss: 9.169e-01, final_inner_loss: 8.576e-01, test_acc: 65.8
# step: 144, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.074e-01, final_inner_loss: 8.377e-01, test_acc: 67.6
# step: 145, dt: 1.7s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.015e-01, final_inner_loss: 8.359e-01, test_acc: 66.8
# step: 146, dt: 2.0s, meta_grad_norm: 6.4e-02, mean_inner_loss: 9.143e-01, final_inner_loss: 8.251e-01, test_acc: 66.4
# step: 147, dt: 2.0s, meta_grad_norm: 1.6e-02, mean_inner_loss: 9.034e-01, final_inner_loss: 8.362e-01, test_acc: 66.8
# step: 148, dt: 1.7s, meta_grad_norm: 8.3e-01, mean_inner_loss: 9.134e-01, final_inner_loss: 8.418e-01, test_acc: 66.0
# step: 149, dt: 1.7s, meta_grad_norm: 5.3e-02, mean_inner_loss: 9.995e-01, final_inner_loss: 1.005e+00, test_acc: 60.2
# step: 150, dt: 1.8s, meta_grad_norm: 2.8e-01, mean_inner_loss: 9.840e-01, final_inner_loss: 1.012e+00, test_acc: 61.8
# step: 151, dt: 1.7s, meta_grad_norm: 7.2e-01, mean_inner_loss: 9.307e-01, final_inner_loss: 9.175e-01, test_acc: 66.0
# step: 152, dt: 1.8s, meta_grad_norm: 3.1e-02, mean_inner_loss: 1.006e+00, final_inner_loss: 1.004e+00, test_acc: 59.8
# step: 153, dt: 2.2s, meta_grad_norm: 1.2e-01, mean_inner_loss: 9.946e-01, final_inner_loss: 9.997e-01, test_acc: 59.4
# step: 154, dt: 1.8s, meta_grad_norm: 5.1e-01, mean_inner_loss: 9.645e-01, final_inner_loss: 9.571e-01, test_acc: 64.0
# step: 155, dt: 1.7s, meta_grad_norm: 3.5e-02, mean_inner_loss: 8.981e-01, final_inner_loss: 8.210e-01, test_acc: 66.8
# step: 156, dt: 1.7s, meta_grad_norm: 1.1e-01, mean_inner_loss: 9.087e-01, final_inner_loss: 8.494e-01, test_acc: 66.4
# step: 157, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.095e-01, final_inner_loss: 8.301e-01, test_acc: 68.0
# step: 158, dt: 1.7s, meta_grad_norm: 4.9e-01, mean_inner_loss: 9.123e-01, final_inner_loss: 8.495e-01, test_acc: 67.2
# step: 159, dt: 1.9s, meta_grad_norm: 8.5e-02, mean_inner_loss: 9.342e-01, final_inner_loss: 7.929e-01, test_acc: 65.0
# step: 160, dt: 2.1s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.286e-01, final_inner_loss: 7.657e-01, test_acc: 67.2
# step: 161, dt: 1.7s, meta_grad_norm: 4.1e-02, mean_inner_loss: 9.239e-01, final_inner_loss: 7.710e-01, test_acc: 66.0
# step: 162, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 9.189e-01, final_inner_loss: 7.868e-01, test_acc: 67.6
# step: 163, dt: 1.7s, meta_grad_norm: 1.1e-02, mean_inner_loss: 9.240e-01, final_inner_loss: 7.826e-01, test_acc: 67.2
# step: 164, dt: 1.7s, meta_grad_norm: 6.3e-02, mean_inner_loss: 9.224e-01, final_inner_loss: 7.735e-01, test_acc: 66.8
# step: 165, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 9.225e-01, final_inner_loss: 7.837e-01, test_acc: 69.4
# step: 166, dt: 2.0s, meta_grad_norm: 4.2e-03, mean_inner_loss: 9.184e-01, final_inner_loss: 7.767e-01, test_acc: 68.6
# step: 167, dt: 2.0s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.183e-01, final_inner_loss: 7.893e-01, test_acc: 68.0
# step: 168, dt: 1.7s, meta_grad_norm: 6.8e-03, mean_inner_loss: 9.189e-01, final_inner_loss: 7.923e-01, test_acc: 67.6
# step: 169, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.147e-01, final_inner_loss: 8.032e-01, test_acc: 68.4
# step: 170, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 9.112e-01, final_inner_loss: 7.986e-01, test_acc: 66.6
# step: 171, dt: 1.7s, meta_grad_norm: 9.3e-02, mean_inner_loss: 8.971e-01, final_inner_loss: 8.192e-01, test_acc: 69.4
# step: 172, dt: 1.7s, meta_grad_norm: 5.8e-01, mean_inner_loss: 9.105e-01, final_inner_loss: 9.175e-01, test_acc: 68.2
# step: 173, dt: 2.0s, meta_grad_norm: 5.2e-03, mean_inner_loss: 9.176e-01, final_inner_loss: 7.565e-01, test_acc: 68.8
# step: 174, dt: 2.0s, meta_grad_norm: 4.8e-03, mean_inner_loss: 9.167e-01, final_inner_loss: 7.786e-01, test_acc: 69.2
# step: 175, dt: 1.7s, meta_grad_norm: 4.4e-02, mean_inner_loss: 9.171e-01, final_inner_loss: 7.600e-01, test_acc: 68.2
# step: 176, dt: 1.7s, meta_grad_norm: 4.6e-02, mean_inner_loss: 9.186e-01, final_inner_loss: 7.755e-01, test_acc: 68.4
# step: 177, dt: 1.7s, meta_grad_norm: 4.5e-03, mean_inner_loss: 9.169e-01, final_inner_loss: 7.994e-01, test_acc: 68.6
# step: 178, dt: 1.7s, meta_grad_norm: 2.7e-02, mean_inner_loss: 9.154e-01, final_inner_loss: 7.976e-01, test_acc: 68.0
# step: 179, dt: 1.7s, meta_grad_norm: 4.7e-02, mean_inner_loss: 9.145e-01, final_inner_loss: 7.966e-01, test_acc: 68.2
# step: 180, dt: 2.0s, meta_grad_norm: 1.5e-02, mean_inner_loss: 9.151e-01, final_inner_loss: 7.821e-01, test_acc: 68.0
# step: 181, dt: 1.9s, meta_grad_norm: 5.1e-02, mean_inner_loss: 9.178e-01, final_inner_loss: 7.683e-01, test_acc: 68.0
# step: 182, dt: 1.7s, meta_grad_norm: 3.1e-03, mean_inner_loss: 9.129e-01, final_inner_loss: 8.026e-01, test_acc: 67.8
# step: 183, dt: 1.7s, meta_grad_norm: 3.7e-02, mean_inner_loss: 9.123e-01, final_inner_loss: 7.944e-01, test_acc: 66.8
# step: 184, dt: 1.7s, meta_grad_norm: 1.7e-01, mean_inner_loss: 9.080e-01, final_inner_loss: 7.690e-01, test_acc: 67.6
# step: 185, dt: 1.7s, meta_grad_norm: 1.4e-02, mean_inner_loss: 8.964e-01, final_inner_loss: 8.511e-01, test_acc: 67.8
# step: 186, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 8.892e-01, final_inner_loss: 8.384e-01, test_acc: 67.4
# step: 187, dt: 2.2s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.056e-01, final_inner_loss: 8.178e-01, test_acc: 68.0
# step: 188, dt: 1.8s, meta_grad_norm: 7.6e-02, mean_inner_loss: 9.039e-01, final_inner_loss: 7.952e-01, test_acc: 65.4
# step: 189, dt: 1.7s, meta_grad_norm: 1.2e-02, mean_inner_loss: 9.015e-01, final_inner_loss: 8.241e-01, test_acc: 67.2
# step: 190, dt: 1.7s, meta_grad_norm: 9.0e-02, mean_inner_loss: 8.979e-01, final_inner_loss: 8.093e-01, test_acc: 67.8
# step: 191, dt: 1.7s, meta_grad_norm: 9.0e-02, mean_inner_loss: 8.898e-01, final_inner_loss: 8.212e-01, test_acc: 67.8
# step: 192, dt: 1.7s, meta_grad_norm: 5.8e-02, mean_inner_loss: 8.980e-01, final_inner_loss: 8.626e-01, test_acc: 64.8
# step: 193, dt: 1.8s, meta_grad_norm: 8.7e-01, mean_inner_loss: 8.926e-01, final_inner_loss: 8.140e-01, test_acc: 68.6
# step: 194, dt: 2.2s, meta_grad_norm: 2.0e-02, mean_inner_loss: 9.136e-01, final_inner_loss: 7.752e-01, test_acc: 69.2
# step: 195, dt: 1.7s, meta_grad_norm: 3.3e-01, mean_inner_loss: 9.132e-01, final_inner_loss: 7.662e-01, test_acc: 67.8
# step: 196, dt: 1.7s, meta_grad_norm: 7.3e-02, mean_inner_loss: 8.951e-01, final_inner_loss: 8.061e-01, test_acc: 69.0
# step: 197, dt: 1.7s, meta_grad_norm: 7.5e-03, mean_inner_loss: 8.930e-01, final_inner_loss: 8.285e-01, test_acc: 68.4
# step: 198, dt: 1.7s, meta_grad_norm: 8.8e-02, mean_inner_loss: 8.857e-01, final_inner_loss: 8.253e-01, test_acc: 70.8
# step: 199, dt: 1.8s, meta_grad_norm: 4.1e-02, mean_inner_loss: 8.968e-01, final_inner_loss: 7.983e-01, test_acc: 68.4
# step: 200, dt: 1.9s, meta_grad_norm: 5.7e-03, mean_inner_loss: 8.898e-01, final_inner_loss: 8.397e-01, test_acc: 67.2
# step: 201, dt: 2.0s, meta_grad_norm: 6.6e-02, mean_inner_loss: 8.911e-01, final_inner_loss: 8.356e-01, test_acc: 67.6
# step: 202, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 8.942e-01, final_inner_loss: 8.641e-01, test_acc: 67.8
# step: 203, dt: 1.7s, meta_grad_norm: 1.6e-01, mean_inner_loss: 8.985e-01, final_inner_loss: 8.244e-01, test_acc: 68.4
# step: 204, dt: 1.7s, meta_grad_norm: 6.8e-01, mean_inner_loss: 8.888e-01, final_inner_loss: 8.305e-01, test_acc: 68.2
# step: 205, dt: 1.7s, meta_grad_norm: 2.0e-01, mean_inner_loss: 9.121e-01, final_inner_loss: 7.696e-01, test_acc: 68.6
# step: 206, dt: 1.7s, meta_grad_norm: 6.0e-02, mean_inner_loss: 9.184e-01, final_inner_loss: 7.644e-01, test_acc: 66.6
# step: 207, dt: 2.0s, meta_grad_norm: 3.7e-02, mean_inner_loss: 9.085e-01, final_inner_loss: 7.859e-01, test_acc: 66.2
# step: 208, dt: 2.0s, meta_grad_norm: 1.6e-01, mean_inner_loss: 8.999e-01, final_inner_loss: 8.094e-01, test_acc: 66.4
# step: 209, dt: 1.7s, meta_grad_norm: 6.7e-02, mean_inner_loss: 8.932e-01, final_inner_loss: 8.759e-01, test_acc: 68.4
# step: 210, dt: 1.7s, meta_grad_norm: 2.8e-01, mean_inner_loss: 8.911e-01, final_inner_loss: 8.452e-01, test_acc: 68.2
# step: 211, dt: 1.7s, meta_grad_norm: 4.0e-01, mean_inner_loss: 9.399e-01, final_inner_loss: 8.771e-01, test_acc: 66.2
# step: 212, dt: 1.7s, meta_grad_norm: 1.7e-01, mean_inner_loss: 8.851e-01, final_inner_loss: 7.966e-01, test_acc: 68.4
# step: 213, dt: 1.7s, meta_grad_norm: 7.8e-02, mean_inner_loss: 8.960e-01, final_inner_loss: 8.200e-01, test_acc: 65.8
# step: 214, dt: 2.1s, meta_grad_norm: 4.3e-02, mean_inner_loss: 8.881e-01, final_inner_loss: 8.780e-01, test_acc: 66.8
# step: 215, dt: 1.9s, meta_grad_norm: 3.5e-01, mean_inner_loss: 8.896e-01, final_inner_loss: 8.397e-01, test_acc: 67.0
# step: 216, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.965e-01, final_inner_loss: 8.104e-01, test_acc: 68.6
# step: 217, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.960e-01, final_inner_loss: 8.018e-01, test_acc: 68.0
# step: 218, dt: 1.7s, meta_grad_norm: 9.6e-02, mean_inner_loss: 8.938e-01, final_inner_loss: 7.994e-01, test_acc: 66.8
# step: 219, dt: 1.7s, meta_grad_norm: 3.9e-02, mean_inner_loss: 8.889e-01, final_inner_loss: 8.559e-01, test_acc: 67.8
# step: 220, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.815e-01, final_inner_loss: 8.237e-01, test_acc: 69.6
# step: 221, dt: 2.2s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.867e-01, final_inner_loss: 8.428e-01, test_acc: 68.2
# step: 222, dt: 1.8s, meta_grad_norm: 3.7e-01, mean_inner_loss: 8.819e-01, final_inner_loss: 8.130e-01, test_acc: 69.8
# step: 223, dt: 1.7s, meta_grad_norm: 2.4e-02, mean_inner_loss: 9.304e-01, final_inner_loss: 8.887e-01, test_acc: 67.4
# step: 224, dt: 1.7s, meta_grad_norm: 6.8e-02, mean_inner_loss: 9.135e-01, final_inner_loss: 9.180e-01, test_acc: 70.2
# step: 225, dt: 1.7s, meta_grad_norm: 1.8e-01, mean_inner_loss: 8.998e-01, final_inner_loss: 9.186e-01, test_acc: 67.8
# step: 226, dt: 1.7s, meta_grad_norm: 1.5e-01, mean_inner_loss: 8.908e-01, final_inner_loss: 7.928e-01, test_acc: 67.2
# step: 227, dt: 1.7s, meta_grad_norm: 1.8e-02, mean_inner_loss: 8.799e-01, final_inner_loss: 8.101e-01, test_acc: 68.4
# step: 228, dt: 2.3s, meta_grad_norm: 8.6e-03, mean_inner_loss: 8.832e-01, final_inner_loss: 8.198e-01, test_acc: 67.0
# step: 229, dt: 1.7s, meta_grad_norm: 5.3e-03, mean_inner_loss: 8.833e-01, final_inner_loss: 7.965e-01, test_acc: 70.2
# step: 230, dt: 1.7s, meta_grad_norm: 7.9e-02, mean_inner_loss: 8.841e-01, final_inner_loss: 7.935e-01, test_acc: 69.0
# step: 231, dt: 1.7s, meta_grad_norm: 4.5e-01, mean_inner_loss: 8.939e-01, final_inner_loss: 8.542e-01, test_acc: 69.0
# step: 232, dt: 1.7s, meta_grad_norm: 2.1e-01, mean_inner_loss: 8.902e-01, final_inner_loss: 7.314e-01, test_acc: 69.2
# step: 233, dt: 1.7s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.972e-01, final_inner_loss: 8.063e-01, test_acc: 67.6
# step: 234, dt: 1.9s, meta_grad_norm: 6.4e-02, mean_inner_loss: 8.957e-01, final_inner_loss: 8.522e-01, test_acc: 67.6
# step: 235, dt: 2.1s, meta_grad_norm: 5.6e-01, mean_inner_loss: 8.842e-01, final_inner_loss: 8.762e-01, test_acc: 68.0
# step: 236, dt: 1.7s, meta_grad_norm: 4.0e-01, mean_inner_loss: 9.239e-01, final_inner_loss: 8.932e-01, test_acc: 67.0
# step: 237, dt: 1.7s, meta_grad_norm: 3.9e-01, mean_inner_loss: 8.764e-01, final_inner_loss: 8.135e-01, test_acc: 69.4
# step: 238, dt: 1.7s, meta_grad_norm: 8.6e-02, mean_inner_loss: 9.177e-01, final_inner_loss: 9.311e-01, test_acc: 65.4
# step: 239, dt: 1.8s, meta_grad_norm: 6.5e-01, mean_inner_loss: 9.039e-01, final_inner_loss: 8.750e-01, test_acc: 67.8
# step: 240, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 8.895e-01, final_inner_loss: 8.226e-01, test_acc: 66.2
# step: 241, dt: 2.0s, meta_grad_norm: 9.3e-02, mean_inner_loss: 8.895e-01, final_inner_loss: 7.782e-01, test_acc: 68.4
# step: 242, dt: 2.0s, meta_grad_norm: 2.6e-01, mean_inner_loss: 8.752e-01, final_inner_loss: 8.131e-01, test_acc: 67.6
# step: 243, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 9.111e-01, final_inner_loss: 9.165e-01, test_acc: 68.0
# step: 244, dt: 1.7s, meta_grad_norm: 1.6e-01, mean_inner_loss: 9.072e-01, final_inner_loss: 8.606e-01, test_acc: 66.4
# step: 245, dt: 1.7s, meta_grad_norm: 9.9e-02, mean_inner_loss: 8.943e-01, final_inner_loss: 8.396e-01, test_acc: 69.0
# step: 246, dt: 1.7s, meta_grad_norm: 1.0e-02, mean_inner_loss: 8.952e-01, final_inner_loss: 8.428e-01, test_acc: 67.8
# step: 247, dt: 1.7s, meta_grad_norm: 1.9e-02, mean_inner_loss: 8.932e-01, final_inner_loss: 8.376e-01, test_acc: 66.6
# step: 248, dt: 2.0s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.909e-01, final_inner_loss: 8.229e-01, test_acc: 68.0
# step: 249, dt: 1.9s, meta_grad_norm: 5.7e-01, mean_inner_loss: 8.818e-01, final_inner_loss: 8.375e-01, test_acc: 67.0
# step: 250, dt: 1.7s, meta_grad_norm: 8.1e-01, mean_inner_loss: 9.093e-01, final_inner_loss: 9.188e-01, test_acc: 64.8
# step: 251, dt: 1.7s, meta_grad_norm: 5.8e-02, mean_inner_loss: 8.862e-01, final_inner_loss: 8.114e-01, test_acc: 66.0
# step: 252, dt: 1.7s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.820e-01, final_inner_loss: 9.045e-01, test_acc: 67.6
# step: 253, dt: 1.8s, meta_grad_norm: 4.4e-01, mean_inner_loss: 8.899e-01, final_inner_loss: 9.082e-01, test_acc: 68.4
# step: 254, dt: 1.7s, meta_grad_norm: 2.8e-02, mean_inner_loss: 8.851e-01, final_inner_loss: 8.295e-01, test_acc: 66.0
# step: 255, dt: 2.1s, meta_grad_norm: 3.3e-02, mean_inner_loss: 8.865e-01, final_inner_loss: 8.562e-01, test_acc: 69.6
# step: 256, dt: 1.8s, meta_grad_norm: 2.2e-01, mean_inner_loss: 8.815e-01, final_inner_loss: 8.382e-01, test_acc: 68.2
# step: 257, dt: 1.7s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.967e-01, final_inner_loss: 7.498e-01, test_acc: 68.2
# step: 258, dt: 1.7s, meta_grad_norm: 5.7e-01, mean_inner_loss: 8.876e-01, final_inner_loss: 7.286e-01, test_acc: 69.0
# step: 259, dt: 1.7s, meta_grad_norm: 4.0e-01, mean_inner_loss: 8.829e-01, final_inner_loss: 8.288e-01, test_acc: 67.8
# step: 260, dt: 1.7s, meta_grad_norm: 6.9e-01, mean_inner_loss: 9.117e-01, final_inner_loss: 8.742e-01, test_acc: 67.0
# step: 261, dt: 1.7s, meta_grad_norm: 2.5e-01, mean_inner_loss: 8.820e-01, final_inner_loss: 8.600e-01, test_acc: 67.4
# step: 262, dt: 2.3s, meta_grad_norm: 1.7e-02, mean_inner_loss: 8.933e-01, final_inner_loss: 7.575e-01, test_acc: 67.2
# step: 263, dt: 1.7s, meta_grad_norm: 3.4e-02, mean_inner_loss: 8.855e-01, final_inner_loss: 7.682e-01, test_acc: 68.6
# step: 264, dt: 1.7s, meta_grad_norm: 1.3e-02, mean_inner_loss: 8.857e-01, final_inner_loss: 8.244e-01, test_acc: 69.6
# step: 265, dt: 1.7s, meta_grad_norm: 6.7e-03, mean_inner_loss: 8.830e-01, final_inner_loss: 7.846e-01, test_acc: 68.4
# step: 266, dt: 1.7s, meta_grad_norm: 7.5e-02, mean_inner_loss: 8.807e-01, final_inner_loss: 7.758e-01, test_acc: 68.8
# step: 267, dt: 1.8s, meta_grad_norm: 5.3e-02, mean_inner_loss: 8.819e-01, final_inner_loss: 7.727e-01, test_acc: 68.8
# step: 268, dt: 1.9s, meta_grad_norm: 1.3e-01, mean_inner_loss: 8.784e-01, final_inner_loss: 8.102e-01, test_acc: 69.4
# step: 269, dt: 2.1s, meta_grad_norm: 2.9e-02, mean_inner_loss: 8.846e-01, final_inner_loss: 7.740e-01, test_acc: 68.6
# step: 270, dt: 1.7s, meta_grad_norm: 2.5e-02, mean_inner_loss: 8.807e-01, final_inner_loss: 7.255e-01, test_acc: 68.0
# step: 271, dt: 1.7s, meta_grad_norm: 4.3e-02, mean_inner_loss: 8.798e-01, final_inner_loss: 8.055e-01, test_acc: 67.8
# step: 272, dt: 1.7s, meta_grad_norm: 4.4e-02, mean_inner_loss: 8.756e-01, final_inner_loss: 8.237e-01, test_acc: 67.6
# step: 273, dt: 1.7s, meta_grad_norm: 2.0e-02, mean_inner_loss: 8.859e-01, final_inner_loss: 8.468e-01, test_acc: 67.2
# step: 274, dt: 1.7s, meta_grad_norm: 1.6e-02, mean_inner_loss: 8.794e-01, final_inner_loss: 7.770e-01, test_acc: 69.0
# step: 275, dt: 2.0s, meta_grad_norm: 2.3e-01, mean_inner_loss: 8.768e-01, final_inner_loss: 8.233e-01, test_acc: 70.2
# step: 276, dt: 2.0s, meta_grad_norm: 1.8e-01, mean_inner_loss: 8.823e-01, final_inner_loss: 7.538e-01, test_acc: 67.6
# step: 277, dt: 1.7s, meta_grad_norm: 9.8e-02, mean_inner_loss: 8.769e-01, final_inner_loss: 8.314e-01, test_acc: 68.8
# step: 278, dt: 1.7s, meta_grad_norm: 3.2e-01, mean_inner_loss: 8.734e-01, final_inner_loss: 7.664e-01, test_acc: 68.4
# step: 279, dt: 1.8s, meta_grad_norm: 2.9e-01, mean_inner_loss: 9.107e-01, final_inner_loss: 8.849e-01, test_acc: 69.2
# step: 280, dt: 1.7s, meta_grad_norm: 3.4e-01, mean_inner_loss: 8.706e-01, final_inner_loss: 8.214e-01, test_acc: 67.8
# step: 281, dt: 1.7s, meta_grad_norm: 6.2e-02, mean_inner_loss: 8.756e-01, final_inner_loss: 8.080e-01, test_acc: 68.6
# step: 282, dt: 2.0s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.746e-01, final_inner_loss: 7.933e-01, test_acc: 68.6
# step: 283, dt: 1.9s, meta_grad_norm: 4.1e-02, mean_inner_loss: 8.825e-01, final_inner_loss: 8.474e-01, test_acc: 67.6
# step: 284, dt: 1.7s, meta_grad_norm: 1.5e-02, mean_inner_loss: 8.785e-01, final_inner_loss: 7.979e-01, test_acc: 68.0
# step: 285, dt: 1.7s, meta_grad_norm: 7.5e-03, mean_inner_loss: 8.786e-01, final_inner_loss: 7.815e-01, test_acc: 70.2
# step: 286, dt: 1.7s, meta_grad_norm: 9.5e-03, mean_inner_loss: 8.785e-01, final_inner_loss: 7.897e-01, test_acc: 68.6
# step: 287, dt: 1.8s, meta_grad_norm: 5.0e-02, mean_inner_loss: 8.778e-01, final_inner_loss: 7.660e-01, test_acc: 68.0
# step: 288, dt: 1.7s, meta_grad_norm: 7.2e-03, mean_inner_loss: 8.801e-01, final_inner_loss: 8.360e-01, test_acc: 67.6
# step: 289, dt: 2.1s, meta_grad_norm: 8.0e-02, mean_inner_loss: 8.826e-01, final_inner_loss: 8.390e-01, test_acc: 67.6
# step: 290, dt: 1.9s, meta_grad_norm: 2.0e-01, mean_inner_loss: 8.742e-01, final_inner_loss: 8.201e-01, test_acc: 67.2
# step: 291, dt: 1.7s, meta_grad_norm: 2.8e-02, mean_inner_loss: 8.800e-01, final_inner_loss: 7.448e-01, test_acc: 68.0
# step: 292, dt: 1.7s, meta_grad_norm: 3.6e-02, mean_inner_loss: 8.767e-01, final_inner_loss: 7.917e-01, test_acc: 66.8
# step: 293, dt: 1.7s, meta_grad_norm: 1.9e-01, mean_inner_loss: 8.747e-01, final_inner_loss: 7.852e-01, test_acc: 68.8
# step: 294, dt: 1.7s, meta_grad_norm: 3.3e-02, mean_inner_loss: 8.747e-01, final_inner_loss: 8.815e-01, test_acc: 68.2
# step: 295, dt: 1.7s, meta_grad_norm: 3.3e-01, mean_inner_loss: 8.767e-01, final_inner_loss: 8.611e-01, test_acc: 69.8
# step: 296, dt: 2.3s, meta_grad_norm: 3.7e-01, mean_inner_loss: 8.930e-01, final_inner_loss: 9.030e-01, test_acc: 67.0
# step: 297, dt: 1.7s, meta_grad_norm: 7.7e-01, mean_inner_loss: 9.583e-01, final_inner_loss: 9.606e-01, test_acc: 64.2
# step: 298, dt: 1.7s, meta_grad_norm: 1.5e+00, mean_inner_loss: 8.793e-01, final_inner_loss: 8.720e-01, test_acc: 67.6
# step: 299, dt: 1.7s, meta_grad_norm: 9.6e-02, mean_inner_loss: 9.898e-01, final_inner_loss: 1.002e+00, test_acc: 62.8
# step: 300, dt: 1.7s, meta_grad_norm: 2.4e-01, mean_inner_loss: 9.706e-01, final_inner_loss: 9.288e-01, test_acc: 64.2

# %%
import pickle

# Save results using pickle
with open('results_mu_3.pkl', 'wb') as f:
    pickle.dump(results_mu_3, f)

print("Results saved to 'results_mu_3.pkl'")
# Out:
# Results saved to 'results_mu_3.pkl'

# %%
# Load results from pickle file
with open('results_mu_3.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
results_mu_3['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    results_mu_3['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(results_mu_3['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 0.931828116657726
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [1.3359991, 1.3601627, 1.4714842, 1.641261, 1.5214025, 1.7493787]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(results_mu_3, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 66.0
