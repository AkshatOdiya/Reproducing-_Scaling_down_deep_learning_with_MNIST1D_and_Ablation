# %%
# !pip install mnist1d
# Out:
# Collecting mnist1d
#   Downloading mnist1d-0.0.2.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d) (1.16.0)
# Downloading mnist1d-0.0.2.post1-py3-none-any.whl (14 kB)
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import time, copy, os
import torch
import torch.nn.functional as F

import mnist1d

# %%
args = mnist1d.get_dataset_args()
args.num_samples = 10000
data = mnist1d.get_dataset(args=args, download=False, regenerate=True)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %%
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))

# %%
def get_functional_mlp(args):
  D, H, O = args.input_size, args.hidden_size, args.output_size
  linear1, linear2 = torch.nn.Linear(D,H), torch.nn.Linear(H,O)
  params = [linear1.weight, linear1.bias, linear2.weight, linear2.bias]
  params = [torch.Tensor(p.reshape(-1)) for p in params]
  param_vec = torch.cat(params).to(args.device)

  def forward_fn(x, param_vec, afunc):
    pointer = 0
    W1 = param_vec[pointer:pointer+D*H].reshape(H,D)
    pointer += D*H
    b1 = param_vec[pointer:pointer+H].reshape(1,-1)
    pointer += H
    W2 = param_vec[pointer:pointer+H*O].reshape(O,H)
    pointer += O*H
    b2 = param_vec[pointer:pointer+O].reshape(1,-1)

    h = afunc((W1 @ x.t()).t() + b1)
    h = h + .1*(2*torch.rand(*b1.shape).to(b1.device)-1)
    logits = (W2 @ h.t()).t() + b2
    return logits
  return param_vec, forward_fn

# %%
def accuracy(model, inputs, targets):
  preds = model(inputs).argmax(-1).cpu().numpy()
  targets = targets.cpu().numpy().astype(np.float32)
  return 100*sum(preds==targets)/len(targets)

def inner_optimization(model, args, data, afunc):
  torch.manual_seed(args.seed)
  (param_vec, fwd_fn) = model
  x_train, x_test = torch.Tensor(data['x']), torch.Tensor(data['x_test'])
  y_train, y_test = torch.LongTensor(data['y']), torch.LongTensor(data['y_test'])
  x_train, x_test, y_train, y_test = [v.to(args.device) for v in [x_train, x_test, y_train, y_test]]

  criterion = torch.nn.CrossEntropyLoss()
  results = {'train_losses': [], 'test_acc': []}
  avg_sq_grad = torch.ones_like(param_vec)

  for step in range(args.total_steps):
    bix = (args.batch_ix + (step*args.batch_size))%len(x_train)
    x, y = x_train[bix:bix+args.batch_size], y_train[bix:bix+args.batch_size]
    loss = criterion(fwd_fn(x, param_vec, afunc), y)

    grads = torch.autograd.grad(loss, param_vec, retain_graph=True, create_graph=True)[0]
    avg_sq_grad = avg_sq_grad * args.mu + grads**2 * (1 - args.mu)
    param_vec = param_vec - args.learning_rate * grads/(torch.sqrt(avg_sq_grad) + 1e-8)

    results['train_losses'].append(loss)
    if step % args.test_every:
      k = 500
      test_acc = accuracy(lambda x: fwd_fn(x, param_vec, afunc), x_test[:k], y_test[:k])
      results['test_acc'].append(test_acc)

  results['train_losses'] = torch.stack(results['train_losses'])
  results['test_acc'] = np.asarray(results['test_acc'])
  return results

# %%
base_activation = torch.nn.ELU()

def mlp_afunc(model, x):
  (param_vec, fwd_fn) = model
  x_hat = 0.2 * fwd_fn(x.reshape(-1, 1), param_vec, torch.tanh)
  x_hat = x_hat.reshape(*x.shape)
  return base_activation(x) + x_hat

def outer_optimization(inner_args, outer_args):
  torch.manual_seed(outer_args.seed)
  torch.cuda.manual_seed_all(outer_args.seed)
  (outer_param_vec, outer_fwd_fn) = outer_model = get_functional_mlp(outer_args)

  t0 = time.time()
  results = {'inner_test_accs':[], 'train_losses':[], 'inner_afunc':[], 'grad_norm':[]}
  momentum = torch.zeros_like(outer_param_vec)
  for step in range(outer_args.total_steps):
    inner_afunc = lambda x: mlp_afunc(outer_model, x)
    inner_model = get_functional_mlp(inner_args)
    inner_results = inner_optimization(inner_model, inner_args, data, inner_afunc)

    (outer_param_vec, outer_fwd_fn) = outer_model
    outer_loss = inner_results['train_losses'][-200:].mean()
    outer_grads = torch.autograd.grad(outer_loss, outer_param_vec)[0]
    outer_grads = outer_grads.clamp(-1e-1, 1e-1)

    momentum = outer_args.mu * momentum + outer_grads
    outer_param_vec = outer_param_vec - outer_args.learning_rate * momentum
    outer_model = (outer_param_vec, outer_fwd_fn)

    results['train_losses'].append(outer_loss.item())
    if step % outer_args.print_every == 0:
      t1 = time.time()
      grad_norm = outer_grads @ outer_grads
      results['grad_norm'].append(grad_norm.item())
      print('step: {}, dt: {:.1f}s, meta_grad_norm: {:.1e}, mean_inner_loss: {:.3e}, final_inner_loss: {:.3e}, test_acc: {:.1f}'
          .format(step, t1-t0, grad_norm.item(),
                  results['train_losses'][-1],
                  inner_results['train_losses'][-1],
                  inner_results['test_acc'][-1]))
      t0 = t1

    x_fn = torch.linspace(-5,5,steps=100).to(outer_args.device)
    x_fn, y_fn = x_fn.cpu().numpy(), inner_afunc(x_fn).detach().cpu().numpy()
    results['inner_afunc'].append([x_fn, y_fn])
    results['inner_test_accs'].append(inner_results['test_acc'])

  return results

# %%
class ObjectView(object):
    def __init__(self, d): self.__dict__ = d

def get_inner_args(as_dict=False):
  arg_dict = {'input_size': 40,
              'hidden_size': 128,
              'output_size': 10,
              'batch_size': 100,
              'total_steps': 301,
              'test_every': 400,
              'learning_rate': 1e-2,
              'seed': 0,
              'device': DEVICE,
              'mu': 1.0,
              'batch_ix': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)

def get_outer_args(as_dict=False):
  arg_dict = {'input_size': 1,
              'hidden_size': 100,
              'output_size': 1,
              'batch_size': 1,
              'learning_rate': 3e-1,
              'mu': 0.0,
              'total_steps': 301,
              'print_every': 1,
              'device': DEVICE,
              'seed': 0}
  return arg_dict if as_dict else ObjectView(arg_dict)
inner_args, outer_args = get_inner_args(), get_outer_args()
mnist1d.set_seed(outer_args.seed)

# %%
results_mu_1_one = outer_optimization(inner_args, outer_args)
# Out:
# step: 0, dt: 2.9s, meta_grad_norm: 6.8e-02, mean_inner_loss: 1.950e+00, final_inner_loss: 1.882e+00, test_acc: 24.8
# step: 1, dt: 1.8s, meta_grad_norm: 6.3e-02, mean_inner_loss: 1.950e+00, final_inner_loss: 1.859e+00, test_acc: 24.4
# step: 2, dt: 1.8s, meta_grad_norm: 5.4e-02, mean_inner_loss: 1.932e+00, final_inner_loss: 1.842e+00, test_acc: 25.2
# step: 3, dt: 2.0s, meta_grad_norm: 5.0e-02, mean_inner_loss: 1.916e+00, final_inner_loss: 1.826e+00, test_acc: 26.0
# step: 67, dt: 1.7s, meta_grad_norm: 2.5e-03, mean_inner_loss: 1.694e+00, final_inner_loss: 1.645e+00, test_acc: 34.2
# step: 68, dt: 1.8s, meta_grad_norm: 2.5e-03, mean_inner_loss: 1.693e+00, final_inner_loss: 1.645e+00, test_acc: 34.4
# step: 69, dt: 1.7s, meta_grad_norm: 2.4e-03, mean_inner_loss: 1.692e+00, final_inner_loss: 1.644e+00, test_acc: 34.6
# step: 70, dt: 2.1s, meta_grad_norm: 2.4e-03, mean_inner_loss: 1.691e+00, final_inner_loss: 1.644e+00, test_acc: 35.0
# step: 71, dt: 1.9s, meta_grad_norm: 2.3e-03, mean_inner_loss: 1.691e+00, final_inner_loss: 1.644e+00, test_acc: 35.0
# step: 72, dt: 1.8s, meta_grad_norm: 2.3e-03, mean_inner_loss: 1.690e+00, final_inner_loss: 1.643e+00, test_acc: 35.2
# step: 73, dt: 1.7s, meta_grad_norm: 2.2e-03, mean_inner_loss: 1.689e+00, final_inner_loss: 1.643e+00, test_acc: 35.0
# step: 74, dt: 1.7s, meta_grad_norm: 2.2e-03, mean_inner_loss: 1.689e+00, final_inner_loss: 1.643e+00, test_acc: 35.0
# step: 75, dt: 1.7s, meta_grad_norm: 2.2e-03, mean_inner_loss: 1.688e+00, final_inner_loss: 1.642e+00, test_acc: 35.0
# step: 76, dt: 1.8s, meta_grad_norm: 2.1e-03, mean_inner_loss: 1.687e+00, final_inner_loss: 1.642e+00, test_acc: 35.0
# step: 77, dt: 2.3s, meta_grad_norm: 2.1e-03, mean_inner_loss: 1.687e+00, final_inner_loss: 1.642e+00, test_acc: 35.0
# step: 78, dt: 1.8s, meta_grad_norm: 2.0e-03, mean_inner_loss: 1.686e+00, final_inner_loss: 1.641e+00, test_acc: 35.0
# step: 79, dt: 1.8s, meta_grad_norm: 2.0e-03, mean_inner_loss: 1.685e+00, final_inner_loss: 1.641e+00, test_acc: 35.0
# step: 80, dt: 1.8s, meta_grad_norm: 2.0e-03, mean_inner_loss: 1.685e+00, final_inner_loss: 1.641e+00, test_acc: 35.0
# step: 81, dt: 1.7s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.684e+00, final_inner_loss: 1.640e+00, test_acc: 35.0
# step: 82, dt: 1.8s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.684e+00, final_inner_loss: 1.640e+00, test_acc: 35.0
# step: 83, dt: 2.0s, meta_grad_norm: 1.9e-03, mean_inner_loss: 1.683e+00, final_inner_loss: 1.640e+00, test_acc: 35.0
# step: 84, dt: 2.1s, meta_grad_norm: 1.8e-03, mean_inner_loss: 1.683e+00, final_inner_loss: 1.640e+00, test_acc: 35.2
# step: 85, dt: 1.7s, meta_grad_norm: 1.8e-03, mean_inner_loss: 1.682e+00, final_inner_loss: 1.639e+00, test_acc: 35.0
# step: 86, dt: 1.8s, meta_grad_norm: 1.8e-03, mean_inner_loss: 1.681e+00, final_inner_loss: 1.639e+00, test_acc: 35.0
# step: 143, dt: 1.8s, meta_grad_norm: 9.2e-04, mean_inner_loss: 1.660e+00, final_inner_loss: 1.629e+00, test_acc: 36.0
# step: 144, dt: 2.1s, meta_grad_norm: 9.1e-04, mean_inner_loss: 1.660e+00, final_inner_loss: 1.629e+00, test_acc: 36.0
# step: 145, dt: 2.0s, meta_grad_norm: 9.1e-04, mean_inner_loss: 1.659e+00, final_inner_loss: 1.629e+00, test_acc: 36.0
# step: 146, dt: 1.8s, meta_grad_norm: 9.0e-04, mean_inner_loss: 1.659e+00, final_inner_loss: 1.629e+00, test_acc: 36.0
# step: 147, dt: 1.7s, meta_grad_norm: 8.9e-04, mean_inner_loss: 1.659e+00, final_inner_loss: 1.628e+00, test_acc: 36.0
# step: 148, dt: 1.8s, meta_grad_norm: 8.8e-04, mean_inner_loss: 1.659e+00, final_inner_loss: 1.628e+00, test_acc: 36.0
# step: 149, dt: 1.8s, meta_grad_norm: 8.8e-04, mean_inner_loss: 1.658e+00, final_inner_loss: 1.628e+00, test_acc: 36.2
# step: 150, dt: 1.7s, meta_grad_norm: 8.7e-04, mean_inner_loss: 1.658e+00, final_inner_loss: 1.628e+00, test_acc: 36.2
# step: 151, dt: 2.3s, meta_grad_norm: 8.7e-04, mean_inner_loss: 1.658e+00, final_inner_loss: 1.628e+00, test_acc: 36.2
# step: 152, dt: 1.8s, meta_grad_norm: 8.6e-04, mean_inner_loss: 1.658e+00, final_inner_loss: 1.628e+00, test_acc: 36.2
# step: 153, dt: 1.7s, meta_grad_norm: 8.5e-04, mean_inner_loss: 1.657e+00, final_inner_loss: 1.628e+00, test_acc: 36.4
# step: 154, dt: 1.7s, meta_grad_norm: 8.5e-04, mean_inner_loss: 1.657e+00, final_inner_loss: 1.628e+00, test_acc: 36.6
# step: 155, dt: 1.8s, meta_grad_norm: 8.4e-04, mean_inner_loss: 1.657e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 156, dt: 1.7s, meta_grad_norm: 8.4e-04, mean_inner_loss: 1.656e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 157, dt: 1.9s, meta_grad_norm: 8.3e-04, mean_inner_loss: 1.656e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 158, dt: 2.1s, meta_grad_norm: 8.2e-04, mean_inner_loss: 1.656e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 159, dt: 1.7s, meta_grad_norm: 8.2e-04, mean_inner_loss: 1.656e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 160, dt: 1.8s, meta_grad_norm: 8.1e-04, mean_inner_loss: 1.656e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 161, dt: 1.8s, meta_grad_norm: 8.1e-04, mean_inner_loss: 1.655e+00, final_inner_loss: 1.627e+00, test_acc: 36.8
# step: 162, dt: 1.7s, meta_grad_norm: 8.0e-04, mean_inner_loss: 1.655e+00, final_inner_loss: 1.627e+00, test_acc: 37.0
# step: 163, dt: 1.7s, meta_grad_norm: 8.0e-04, mean_inner_loss: 1.655e+00, final_inner_loss: 1.626e+00, test_acc: 37.0
# step: 164, dt: 2.0s, meta_grad_norm: 7.9e-04, mean_inner_loss: 1.655e+00, final_inner_loss: 1.626e+00, test_acc: 37.0
# step: 165, dt: 2.0s, meta_grad_norm: 7.9e-04, mean_inner_loss: 1.654e+00, final_inner_loss: 1.626e+00, test_acc: 37.0
# step: 166, dt: 1.7s, meta_grad_norm: 7.8e-04, mean_inner_loss: 1.654e+00, final_inner_loss: 1.626e+00, test_acc: 36.8
# step: 167, dt: 1.7s, meta_grad_norm: 7.8e-04, mean_inner_loss: 1.654e+00, final_inner_loss: 1.626e+00, test_acc: 36.8
# step: 168, dt: 1.7s, meta_grad_norm: 7.7e-04, mean_inner_loss: 1.654e+00, final_inner_loss: 1.626e+00, test_acc: 36.8
# step: 169, dt: 1.7s, meta_grad_norm: 7.7e-04, mean_inner_loss: 1.653e+00, final_inner_loss: 1.626e+00, test_acc: 36.8
# step: 170, dt: 1.7s, meta_grad_norm: 7.7e-04, mean_inner_loss: 1.653e+00, final_inner_loss: 1.626e+00, test_acc: 37.0
# step: 171, dt: 2.1s, meta_grad_norm: 7.6e-04, mean_inner_loss: 1.653e+00, final_inner_loss: 1.625e+00, test_acc: 37.0
# step: 172, dt: 1.9s, meta_grad_norm: 7.6e-04, mean_inner_loss: 1.653e+00, final_inner_loss: 1.625e+00, test_acc: 37.0
# step: 173, dt: 1.7s, meta_grad_norm: 7.5e-04, mean_inner_loss: 1.652e+00, final_inner_loss: 1.625e+00, test_acc: 37.0
# step: 174, dt: 1.8s, meta_grad_norm: 7.5e-04, mean_inner_loss: 1.652e+00, final_inner_loss: 1.625e+00, test_acc: 37.0
# step: 175, dt: 1.7s, meta_grad_norm: 7.4e-04, mean_inner_loss: 1.652e+00, final_inner_loss: 1.625e+00, test_acc: 36.8
# step: 176, dt: 1.7s, meta_grad_norm: 7.4e-04, mean_inner_loss: 1.652e+00, final_inner_loss: 1.625e+00, test_acc: 36.8
# step: 177, dt: 1.7s, meta_grad_norm: 7.4e-04, mean_inner_loss: 1.652e+00, final_inner_loss: 1.625e+00, test_acc: 36.8
# step: 178, dt: 2.2s, meta_grad_norm: 7.3e-04, mean_inner_loss: 1.651e+00, final_inner_loss: 1.625e+00, test_acc: 36.8
# step: 179, dt: 1.8s, meta_grad_norm: 7.3e-04, mean_inner_loss: 1.651e+00, final_inner_loss: 1.624e+00, test_acc: 36.8
# step: 180, dt: 1.7s, meta_grad_norm: 7.3e-04, mean_inner_loss: 1.651e+00, final_inner_loss: 1.624e+00, test_acc: 36.8
# step: 181, dt: 1.8s, meta_grad_norm: 7.2e-04, mean_inner_loss: 1.651e+00, final_inner_loss: 1.624e+00, test_acc: 36.8
# step: 182, dt: 1.7s, meta_grad_norm: 7.2e-04, mean_inner_loss: 1.650e+00, final_inner_loss: 1.624e+00, test_acc: 36.8
# step: 183, dt: 1.8s, meta_grad_norm: 7.1e-04, mean_inner_loss: 1.650e+00, final_inner_loss: 1.624e+00, test_acc: 36.6
# step: 184, dt: 1.9s, meta_grad_norm: 7.1e-04, mean_inner_loss: 1.650e+00, final_inner_loss: 1.624e+00, test_acc: 36.6
# step: 185, dt: 2.2s, meta_grad_norm: 7.1e-04, mean_inner_loss: 1.650e+00, final_inner_loss: 1.624e+00, test_acc: 36.6
# step: 186, dt: 1.7s, meta_grad_norm: 7.0e-04, mean_inner_loss: 1.650e+00, final_inner_loss: 1.624e+00, test_acc: 36.6
# step: 187, dt: 1.7s, meta_grad_norm: 7.0e-04, mean_inner_loss: 1.649e+00, final_inner_loss: 1.624e+00, test_acc: 36.6
# step: 188, dt: 1.7s, meta_grad_norm: 7.0e-04, mean_inner_loss: 1.649e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 189, dt: 1.7s, meta_grad_norm: 7.0e-04, mean_inner_loss: 1.649e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 190, dt: 1.7s, meta_grad_norm: 6.9e-04, mean_inner_loss: 1.649e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 191, dt: 2.0s, meta_grad_norm: 6.9e-04, mean_inner_loss: 1.649e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 192, dt: 2.0s, meta_grad_norm: 6.9e-04, mean_inner_loss: 1.648e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 193, dt: 1.7s, meta_grad_norm: 6.8e-04, mean_inner_loss: 1.648e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 194, dt: 1.8s, meta_grad_norm: 6.8e-04, mean_inner_loss: 1.648e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 195, dt: 1.7s, meta_grad_norm: 6.8e-04, mean_inner_loss: 1.648e+00, final_inner_loss: 1.623e+00, test_acc: 36.6
# step: 196, dt: 1.7s, meta_grad_norm: 6.8e-04, mean_inner_loss: 1.648e+00, final_inner_loss: 1.622e+00, test_acc: 36.6
# step: 197, dt: 1.7s, meta_grad_norm: 6.7e-04, mean_inner_loss: 1.647e+00, final_inner_loss: 1.622e+00, test_acc: 36.6
# step: 198, dt: 2.1s, meta_grad_norm: 6.7e-04, mean_inner_loss: 1.647e+00, final_inner_loss: 1.622e+00, test_acc: 36.6
# step: 199, dt: 1.9s, meta_grad_norm: 6.7e-04, mean_inner_loss: 1.647e+00, final_inner_loss: 1.622e+00, test_acc: 36.6
# step: 200, dt: 1.8s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.647e+00, final_inner_loss: 1.622e+00, test_acc: 36.4
# step: 201, dt: 1.7s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.647e+00, final_inner_loss: 1.622e+00, test_acc: 36.4
# step: 202, dt: 1.7s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.646e+00, final_inner_loss: 1.622e+00, test_acc: 36.4
# step: 203, dt: 1.7s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.646e+00, final_inner_loss: 1.622e+00, test_acc: 36.4
# step: 204, dt: 1.7s, meta_grad_norm: 6.6e-04, mean_inner_loss: 1.646e+00, final_inner_loss: 1.622e+00, test_acc: 36.4
# step: 205, dt: 2.2s, meta_grad_norm: 6.5e-04, mean_inner_loss: 1.646e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 206, dt: 1.8s, meta_grad_norm: 6.5e-04, mean_inner_loss: 1.646e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 207, dt: 1.7s, meta_grad_norm: 6.5e-04, mean_inner_loss: 1.645e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 208, dt: 1.7s, meta_grad_norm: 6.5e-04, mean_inner_loss: 1.645e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 209, dt: 1.8s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.645e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 210, dt: 1.7s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.645e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 211, dt: 1.9s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.645e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 212, dt: 2.1s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.644e+00, final_inner_loss: 1.621e+00, test_acc: 36.4
# step: 213, dt: 1.7s, meta_grad_norm: 6.4e-04, mean_inner_loss: 1.644e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 214, dt: 1.8s, meta_grad_norm: 6.3e-04, mean_inner_loss: 1.644e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 215, dt: 1.7s, meta_grad_norm: 6.3e-04, mean_inner_loss: 1.644e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 216, dt: 1.7s, meta_grad_norm: 6.3e-04, mean_inner_loss: 1.644e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 217, dt: 1.8s, meta_grad_norm: 6.3e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 218, dt: 2.0s, meta_grad_norm: 6.3e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 219, dt: 2.0s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 220, dt: 1.8s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.620e+00, test_acc: 36.2
# step: 221, dt: 1.7s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.619e+00, test_acc: 36.2
# step: 222, dt: 1.7s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.643e+00, final_inner_loss: 1.619e+00, test_acc: 36.2
# step: 223, dt: 1.8s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.642e+00, final_inner_loss: 1.619e+00, test_acc: 36.2
# step: 224, dt: 1.7s, meta_grad_norm: 6.2e-04, mean_inner_loss: 1.642e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 225, dt: 2.1s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.642e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 226, dt: 1.9s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.642e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 227, dt: 1.8s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.642e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 228, dt: 1.8s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.641e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 229, dt: 1.7s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.641e+00, final_inner_loss: 1.619e+00, test_acc: 36.0
# step: 230, dt: 1.7s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.641e+00, final_inner_loss: 1.618e+00, test_acc: 36.2
# step: 231, dt: 1.7s, meta_grad_norm: 6.1e-04, mean_inner_loss: 1.641e+00, final_inner_loss: 1.618e+00, test_acc: 36.2
# step: 232, dt: 2.3s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.641e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 233, dt: 1.8s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 234, dt: 1.8s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 235, dt: 1.8s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 236, dt: 1.8s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 237, dt: 1.7s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.618e+00, test_acc: 36.4
# step: 238, dt: 1.9s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.640e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 239, dt: 2.1s, meta_grad_norm: 6.0e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 240, dt: 1.8s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 241, dt: 1.8s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 242, dt: 1.7s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 243, dt: 1.7s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 244, dt: 1.8s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.639e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 245, dt: 2.1s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.638e+00, final_inner_loss: 1.617e+00, test_acc: 36.4
# step: 246, dt: 2.0s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.638e+00, final_inner_loss: 1.616e+00, test_acc: 36.4
# step: 247, dt: 1.7s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.638e+00, final_inner_loss: 1.616e+00, test_acc: 36.4
# step: 248, dt: 1.7s, meta_grad_norm: 5.9e-04, mean_inner_loss: 1.638e+00, final_inner_loss: 1.616e+00, test_acc: 36.4
# step: 249, dt: 1.7s, meta_grad_norm: 5.8e-04, mean_inner_loss: 1.638e+00, final_inner_loss: 1.616e+00, test_acc: 36.4
# step: 250, dt: 1.8s, meta_grad_norm: 5.8e-04, mean_inner_loss: 1.637e+00, final_inner_loss: 1.616e+00, test_acc: 36.4
# step: 251, dt: 1.8s, meta_grad_norm: 5.8e-04, mean_inner_loss: 1
, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.611e+00, test_acc: 37.2
# step: 286, dt: 2.1s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.611e+00, test_acc: 37.2
# step: 287, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.611e+00, test_acc: 37.2
# step: 288, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.611e+00, test_acc: 37.2
# step: 289, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.611e+00, test_acc: 37.2
# step: 290, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.631e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 291, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 292, dt: 2.0s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 293, dt: 2.0s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 294, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 295, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 296, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.630e+00, final_inner_loss: 1.610e+00, test_acc: 37.2
# step: 297, dt: 1.7s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.629e+00, final_inner_loss: 1.609e+00, test_acc: 37.2
# step: 298, dt: 1.8s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.629e+00, final_inner_loss: 1.609e+00, test_acc: 37.2
# step: 299, dt: 2.1s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.629e+00, final_inner_loss: 1.609e+00, test_acc: 37.2
# step: 300, dt: 1.9s, meta_grad_norm: 5.6e-04, mean_inner_loss: 1.629e+00, final_inner_loss: 1.609e+00, test_acc: 37.2

# %%
import pickle

# Save results using pickle
with open('results_mu_1_one.pkl', 'wb') as f:
    pickle.dump(results_mu_1_one, f)

print("Results saved to 'results_mu_1_one.pkl'")
# Out:
# Results saved to 'results_mu_1_one.pkl'

# %%
# Load results from pickle file
with open('results_mu_1_one.pkl', 'rb') as f:
    loaded_results = pickle.load(f)

print("Results loaded successfully!")
# Out:
# Results loaded successfully!

# %%
afuncs = [torch.relu, lambda x: x * torch.sigmoid(x), torch.nn.ELU(),
          torch.nn.Softplus(), torch.tanh, torch.sigmoid]
afunc_names = ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
afunc_colors = ['yellow', 'orange', 'red', 'purple', 'blue', 'green']

baseline_results = []
results_mu_1_one['baselines'] = []

for i, f in enumerate(afuncs):
    torch.manual_seed(inner_args.seed)
    inner_model = get_functional_mlp(inner_args)
    r = inner_optimization(inner_model, inner_args, data, afunc=f)
    baseline_results.append(r)
    results_mu_1_one['baselines'] += [(afunc_names[i], r['test_acc'][-1], afunc_colors[i])]

# %%
print(np.mean(results_mu_1_one['train_losses']))
print(afunc_names)
[r['train_losses'].detach().cpu().numpy().mean() for r in baseline_results]
# Out:
# 1.677164197760167
# ['relu', 'swish', 'elu', 'softplus', 'tanh', 'sigmoid']
# [2.132469, 2.1324844, 2.0295122, 2.1502216, 2.0580742, 2.2666633]

# %%
# saving
run_tag = 'steps{:.0f}_seed{:.0f}_lr{:.0e}_elu_init' \
        .format(outer_args.total_steps, outer_args.seed,
                outer_args.learning_rate)
mnist1d.to_pickle(results_mu_1_one, path='/content' + run_tag)
print('saved: {}'.format(run_tag))
# Out:
# saved: steps301_seed0_lr3e-01_elu_init

# %%
# loading
run_tag = run_tag
results = mnist1d.from_pickle(path='/content' + run_tag)
print('loaded: {}'.format(run_tag))
# Out:
# loaded: steps301_seed0_lr3e-01_elu_init

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12, 4), dpi=200)
t = range(0, outer_args.total_steps, outer_args.print_every)

# Subplot 1: Outer objective (last 200 inner losses)
plt.subplot(1, 3, 1)
plt.plot(results['train_losses'], 'k-', label='Final Training Loss', linewidth=2)
plt.title('Outer Objective (Last 200 Inner Losses)', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Loss", fontsize=10)
plt.grid(True)
plt.tight_layout()

# Subplot 2: MNIST-1D test accuracy
plt.subplot(1, 3, 2)
meta_test_acc = [r[-1] for r in results['inner_test_accs']]
for (name, acc, color) in results['baselines']:
    plt.plot(t, [acc] * len(t), '-', color=color, label=name, linewidth=2)
plt.plot(t, meta_test_acc, 'k-', label='Learned', linewidth=2)
plt.title('MNIST-1D Test Accuracy', fontsize=12)
plt.xlabel("Outer Training Step", fontsize=10)
plt.ylabel("Accuracy (%)", fontsize=10)
plt.ylim(0, 80)
plt.legend(fontsize=8, ncol=4)
plt.grid(True)

# Subplot 3: Learned activation function
plt.subplot(1, 3, 3)
plt.axhline(0, color='gray', linewidth=1)
plt.axvline(0, color='gray', linewidth=1)

N = len(results['inner_afunc'])
colors = plt.cm.viridis(np.linspace(0, 1, N))
for i, (x, y) in enumerate(results['inner_afunc']):
    if i % (N // 50) == 0 or i == len(results['inner_afunc']):
        l, m = 0, 100
        label = 'Step {}'.format(i * outer_args.print_every) if i % (N // 10) == 0 or i == len(results['inner_afunc']) else None
        plt.plot(x[l:m], y[l:m], color=colors[i], label=label)

plt.legend(fontsize=8, ncol=3)
plt.title("Learned Activation Function", fontsize=12)
plt.xlim(-5, 5)
plt.ylim(-1.5, 4)
plt.xlabel("x", fontsize=10)
plt.ylabel("y", fontsize=10)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
def polyfunc(coeffs):
  def f(x):
    r = 0.*x
    for i, c in enumerate(coeffs[::-1]):
      r += c * x**i
    return r
  return f

def get_approx_afun():
  def f(x):
    seg0, seg1, seg2, seg3, seg4, seg5 = [.15, .9], [-.25, 0.1], [-1.2, -.85], [-.5, -.75], [0.2, -.85], [1.2, -1.4]
    y = (x < -2) * polyfunc(seg0)(x) + \
        (x > -2) * (x < -1) * polyfunc(seg1)(x) + \
        (x > -1) * (x < -0.25) * polyfunc(seg2)(x) + \
        (x > -0.25) * (x < 0.1) * polyfunc(seg3)(x) + \
        (x > 0.1) * (x < .6) * polyfunc(seg4)(x) + \
        (x > .6) * polyfunc(seg5)(x)
    return y
  return f

# %%
fig = pl.figure(figsize=[3,3],dpi=120)

approx_afunc = get_approx_afun()
x, y = results['inner_afunc'][-1]
plt.plot(x[::3], y[::3], 'y-', label='mlp')
x_ = np.linspace(-5,5,100)
plt.plot(x_, approx_afunc(x_), 'k-', label='approx_fit', linewidth=1)
plt.legend() ; plt.xlim(-5,5) ; plt.ylim(-2,4) ; plt.show()

# %%
torch.manual_seed(inner_args.seed)
inner_model = get_functional_mlp(inner_args)
poly_results = inner_optimization(inner_model, inner_args, data, afunc=approx_afunc)
results['baselines'] += [('approx_fit', poly_results['test_acc'][-1], 'grey')]
poly_results['test_acc'][-1]
# Out:
# 30.4
